# %%
import pandas as pd
import numpy as np
import os
from scipy.stats import fisher_exact
from statsmodels.stats.multitest import multipletests
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
# path
human_goslim_up_path = '../data/human_annotation/human_annotation_up.tsv'
rice_goslim_up_path = '../data/rice_annotation/rice_annotation_up.tsv'

human_goslim_all_path = '../data/biomart_goslim/biomart_human_goslim_R110.tsv'
rice_goslim_all_path = '../data/biomart_goslim/biomart_rice_goslim_R56.tsv'

# %%
human_goslim_up = pd.read_csv(human_goslim_up_path, sep='\t')
rice_goslim_up = pd.read_csv(rice_goslim_up_path, sep='\t')
human_goslim_all = pd.read_csv(human_goslim_all_path, sep='\t')
rice_goslim_all = pd.read_csv(rice_goslim_all_path, sep='\t')

human_goslim_all = human_goslim_all.drop_duplicates(subset=['Gene stable ID', 'GOSlim GOA Accession(s)', 'GOSlim GOA Description'], keep='first').copy()
rice_goslim_all = rice_goslim_all.drop_duplicates(subset=['Gene stable ID', 'GOSlim GOA Accession(s)', 'GOSlim GOA Description'], keep='first').copy()

display(human_goslim_up)
display(rice_goslim_up)
display(human_goslim_all)
display(rice_goslim_all)
# Out:
# /var/folders/7w/6nt3szxj44xdr5xs8y9g8lhw0000gn/T/ipykernel_14622/269868789.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   human_goslim_all = pd.read_csv(human_goslim_all_path, sep='\t')
# /var/folders/7w/6nt3szxj44xdr5xs8y9g8lhw0000gn/T/ipykernel_14622/269868789.py:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   rice_goslim_all = pd.read_csv(rice_goslim_all_path, sep='\t')
#        Gene stable ID Chromosome/scaffold name  Gene start(bp)  Gene end(bp)  \
# 0     ENSG00000173110                        1       161524540     161526894
# 1     ENSG00000173110                        1       161524540     161526894
# 2     ENSG00000173110                        1       161524540     161526894
# 3     ENSG00000173110                        1       161524540     161526894
# 4     ENSG00000173110                        1       161524540     161526894
# ...               ...                      ...             ...           ...
# 1722  ENSG00000184205                        X        53082367      53088540
# 1723  ENSG00000184205                        X        53082367      53088540
# 1724  ENSG00000184205                        X        53082367      53088540
# 1725  ENSG00000184205                        X        53082367      53088540
# 1726  ENSG00000174226                        8       100572889     100663415
#
#      GOSlim GOA Accession(s)  GOSlim GOA Description  HN-score(HN5)    name
# 0                 GO:0003824      catalytic activity            245   HSPA6
# 1                 GO:0005576    extracellular region            245   HSPA6
# 2                 GO:0140657  ATP-dependent activity            245   HSPA6
# 3                 GO:0043226               organelle            245   HSPA6
# 4                 GO:0005856            cytoskeleton            245   HSPA6
# ...                      ...                     ...            ...     ...
# 1722              GO:0005730               nucleolus             51  TSPYL2
# 1723              GO:0023052               signaling             51  TSPYL2
# 1724              GO:0042393         histone binding             51  TSPYL2
# 1725              GO:0005694              chromosome             51  TSPYL2
# 1726              GO:0008289           lipid binding             51   SNX31
#
# [1727 rows x 8 columns]
#      Gene stable ID  Chromosome/scaffold name  Gene start(bp)  Gene end(bp)  \
# 0      Os04g0107900                         4          483234        485978
# 1      Os04g0107900                         4          483234        485978
# 2      Os04g0107900                         4          483234        485978
# 3      Os04g0107900                         4          483234        485978
# 4      Os04g0107900                         4          483234        485978
# ...             ...                       ...             ...           ...
# 2522   Os01g0971800                         1        42874273      42875515
# 2523   Os01g0971800                         1        42874273      42875515
# 2524   Os01g0971800                         1        42874273      42875515
# 2525   Os01g0971800                         1        42874273      42875515
# 2526   Os08g0374701                         8        17559580      17560192
#
#      GOSlim GOA Accession(s) GOSlim GOA Description  HN-score(HN5)
# 0                 GO:0016787     hydrolase activity            253
# 1                 GO:0005886        plasma membrane            253
# 2                 GO:0005515        protein binding            253
# 3                 GO:0005488                binding            253
# 4                 GO:0008150     biological_process            253
# ...                      ...                    ...            ...
# 2522              GO:0008152      metabolic process             42
# 2523              GO:0009987       cellular process             42
# 2524              GO:0008150     biological_process             42
# 2525              GO:0005634                nucleus             42
# 2526              GO:0009987       cellular process             42
#
# [2527 rows x 7 columns]
#          Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 0       ENSG00000243485                        1        29554      31109
# 1       ENSG00000284332                        1        30366      30503
# 2       ENSG00000186092                        1        65419      71585
# 3       ENSG00000186092                        1        65419      71585
# 4       ENSG00000186092                        1        65419      71585
# ...                 ...                      ...          ...        ...
# 581396  ENSG00000292372                        Y     57207346   57212230
# 581397  ENSG00000292372                        Y     57207346   57212230
# 581398  ENSG00000292372                        Y     57207346   57212230
# 581399  ENSG00000292372                        Y     57207346   57212230
# 581400  ENSG00000292372                        Y     57207346   57212230
#
#        GOSlim GOA Accession(s)         GOSlim GOA Description
# 0                   GO:0031047          gene silencing by RNA
# 1                   GO:0031047          gene silencing by RNA
# 2                   GO:0023052                      signaling
# 3                   GO:0060089  molecular transducer activity
# 4                   GO:0005886                plasma membrane
# ...                        ...                            ...
# 581396              GO:0007010      cytoskeleton organization
# 581397              GO:0008092   cytoskeletal protein binding
# 581398              GO:0031410            cytoplasmic vesicle
# 581399              GO:0043226                      organelle
# 581400              GO:0005768                       endosome
#
# [193928 rows x 6 columns]
#        Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0        Os01g0100100                        1         2983      10815
# 1        Os01g0100100                        1         2983      10815
# 2        Os01g0100100                        1         2983      10815
# 3        Os01g0100100                        1         2983      10815
# 4        Os01g0100100                        1         2983      10815
# ...               ...                      ...          ...        ...
# 258565     gene-rps19                       Pt       134200     134481
# 258566     gene-rps19                       Pt       134200     134481
# 258567     gene-rps19                       Pt       134200     134481
# 258568     gene-rps19                       Pt       134200     134481
# 258569     gene-rps19                       Pt       134200     134481
#
#        GOSlim GOA Accession(s)        GOSlim GOA Description
# 0                   GO:0006810                     transport
# 1                   GO:0008150            biological_process
# 2                   GO:0009987              cellular process
# 3                   GO:0003674            molecular_function
# 4                   GO:0030234     enzyme regulator activity
# ...                        ...                           ...
# 258565              GO:0003674            molecular_function
# 258566              GO:0005198  structural molecule activity
# 258567              GO:0005488                       binding
# 258568              GO:0003723                   RNA binding
# 258569              GO:0003676          nucleic acid binding
#
# [219499 rows x 6 columns]

# %% [markdown]
# ## Fold enrichment
#
# 1. GOSlimの数をカウントする （遺伝子とタームが1対1の関係になっているので実質遺伝子数のカウント）
# 2. Fold enrichmentを計算する

# %%
def count_goslim(df, file_name: str):
    unique_gene_term_pairs = df.drop_duplicates(subset=['Gene stable ID', 'GOSlim GOA Accession(s)']) # for debugging
    goslim_counts = unique_gene_term_pairs.groupby(['GOSlim GOA Accession(s)', 'GOSlim GOA Description'])['Gene stable ID'].nunique().reset_index(name='counts')
    goslim_counts = goslim_counts.sort_values(by='counts', ascending=False).copy() # sort by counts
    results_directory = './goslim_counts'
    os.makedirs(results_directory, exist_ok=True)
    goslim_counts.to_csv(f'{results_directory}/{file_name}', sep='\t', index=False)
    return goslim_counts

human_goslim_up_counts = count_goslim(human_goslim_up, 'human_goslim_up_counts.tsv')
human_goslim_all_counts = count_goslim(human_goslim_all, 'human_goslim_all_counts.tsv')
rice_goslim_up_counts = count_goslim(rice_goslim_up, 'rice_goslim_up_counts.tsv')
rice_goslim_all_counts = count_goslim(rice_goslim_all, 'rice_goslim_all_counts.tsv')

display(human_goslim_up_counts)
display(human_goslim_all_counts)
display(rice_goslim_up_counts)
display(rice_goslim_all_counts)
# Out:
#    GOSlim GOA Accession(s)            GOSlim GOA Description  counts
# 87              GO:0043226                         organelle     128
# 15              GO:0005634                           nucleus      71
# 72              GO:0023052                         signaling      68
# 92              GO:0048856  anatomical structure development      63
# 13              GO:0005576              extracellular region      60
# ..                     ...                               ...     ...
# 85              GO:0042254               ribosome biogenesis       1
# 78              GO:0031047             gene silencing by RNA       1
# 71              GO:0022600          digestive system process       1
# 59              GO:0009975                  cyclase activity       1
# 0               GO:0000228                nuclear chromosome       1
#
# [116 rows x 3 columns]
#     GOSlim GOA Accession(s)                GOSlim GOA Description  counts
# 99               GO:0043226                             organelle   18493
# 19               GO:0005634                               nucleus   11009
# 83               GO:0023052                             signaling    7321
# 36               GO:0005886                       plasma membrane    6799
# 13               GO:0003824                    catalytic activity    6372
# ..                      ...                                   ...     ...
# 117              GO:0071941      nitrogen cycle metabolic process      13
# 90               GO:0031386                           protein tag      13
# 123              GO:0120274             virus coreceptor activity       1
# 66               GO:0007568                                 aging       1
# 116              GO:0071554  cell wall organization or biogenesis       1
#
# [137 rows x 3 columns]
#    GOSlim GOA Accession(s)                    GOSlim GOA Description  counts
# 2               GO:0003674                        molecular_function     204
# 12              GO:0005575                        cellular_component     203
# 41              GO:0008150                        biological_process     197
# 59              GO:0009987                          cellular process     153
# 14              GO:0005622        intracellular anatomical structure     152
# ..                     ...                                       ...     ...
# 70              GO:0030154                      cell differentiation       1
# 57              GO:0009856                               pollination       1
# 74              GO:0040007                                    growth       1
# 76              GO:0045182            translation regulator activity       1
# 40              GO:0008135  translation factor activity, RNA binding       1
#
# [80 rows x 3 columns]
#    GOSlim GOA Accession(s) GOSlim GOA Description  counts
# 2               GO:0003674     molecular_function   18866
# 16              GO:0005575     cellular_component   17584
# 51              GO:0008150     biological_process   16773
# 72              GO:0009987       cellular process   13761
# 14              GO:0005488                binding   12683
# ..                     ...                    ...     ...
# 49              GO:0007623       circadian rhythm      38
# 47              GO:0007267    cell-cell signaling      12
# 69              GO:0009838             abscission      10
# 83              GO:0019825         oxygen binding       6
# 68              GO:0009835         fruit ripening       2
#
# [97 rows x 3 columns]

# %%
# 全ての遺伝子数を取得
human_unique_genes_all = human_goslim_all['Gene stable ID'].nunique()
rice_unique_genes_all = rice_goslim_all['Gene stable ID'].nunique()

# 抽出した遺伝子数を取得
human_unique_genes_up = pd.read_csv('../data/human_annotation/human_position_up.tsv', sep='\t')['Gene stable ID'].nunique()
rice_unique_genes_up = pd.read_csv('../data/rice_annotation/rice_position_up.tsv', sep='\t')['Gene stable ID'].nunique()

print(f'human unique genes all: {human_unique_genes_all}')
print(f'rice unique genes all: {rice_unique_genes_all}')
print(f'human unique genes up: {human_unique_genes_up}')
print(f'rice unique genes up: {rice_unique_genes_up}')
# Out:
# human unique genes all: 25259
# rice unique genes all: 23623
# human unique genes up: 200
# rice unique genes up: 389

# %%
def fold_enrichment(df_goslim_up_counts, df_goslim_all_counts, unique_genes_up, unique_genes_all, file_name: str):
    """_summary_
    Args:
        df_goslim_up_counts (dataframe): _description_
        df_goslim_all_counts (dataframe): _description_
        unique_genes_up (dataframe): _description_
        unique_genes_all (dataframe): _description_
        file_name (str): _description_

    Returns:
        dataframe : _description_
    """
    merged_df = pd.merge(df_goslim_up_counts, 
                         df_goslim_all_counts,
                         on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], 
                         how='right', # if there is no match, fill with NaN or 0
                         suffixes=('_up', '_all'))
    
    merged_df['counts_up'] = merged_df['counts_up'].fillna(0)
    merged_df['counts_all'] = merged_df['counts_all'].fillna(0)
    merged_df['up_ratio'] = merged_df['counts_up'] / unique_genes_up
    merged_df['all_ratio'] = merged_df['counts_all'] / unique_genes_all
    merged_df['fold_enrichment'] = merged_df['up_ratio'] / merged_df['all_ratio']
    merged_df.replace([np.inf, -np.inf], np.nan, inplace=True) # inf -> nan
    results_directory = './goslim_fold_enrichment'
    os.makedirs(results_directory, exist_ok=True)
    merged_df.to_csv(f'{results_directory}/{file_name}', sep='\t', index=False)
    
    return merged_df


human_goslim_enrichment = fold_enrichment(human_goslim_up_counts, human_goslim_all_counts, human_unique_genes_up, human_unique_genes_all, 'human_goslim_enrichment.tsv')
rice_goslim_enrichment = fold_enrichment(rice_goslim_up_counts, rice_goslim_all_counts, rice_unique_genes_up, rice_unique_genes_all, 'rice_goslim_enrichment.tsv')

display(human_goslim_enrichment)
display(rice_goslim_enrichment)
# Out:
#     GOSlim GOA Accession(s)                GOSlim GOA Description  counts_up  \
# 0                GO:0043226                             organelle      128.0
# 1                GO:0005634                               nucleus       71.0
# 2                GO:0023052                             signaling       68.0
# 3                GO:0005886                       plasma membrane       52.0
# 4                GO:0003824                    catalytic activity       47.0
# ..                      ...                                   ...        ...
# 132              GO:0071941      nitrogen cycle metabolic process        0.0
# 133              GO:0031386                           protein tag        2.0
# 134              GO:0120274             virus coreceptor activity        0.0
# 135              GO:0007568                                 aging        0.0
# 136              GO:0071554  cell wall organization or biogenesis        0.0
#
#      counts_all  up_ratio  all_ratio  fold_enrichment
# 0         18493     0.640   0.732135         0.874156
# 1         11009     0.355   0.435845         0.814510
# 2          7321     0.340   0.289837         1.173072
# 3          6799     0.260   0.269171         0.965927
# 4          6372     0.235   0.252267         0.931554
# ..          ...       ...        ...              ...
# 132          13     0.000   0.000515         0.000000
# 133          13     0.010   0.000515        19.430000
# 134           1     0.000   0.000040         0.000000
# 135           1     0.000   0.000040         0.000000
# 136           1     0.000   0.000040         0.000000
#
# [137 rows x 7 columns]
#    GOSlim GOA Accession(s) GOSlim GOA Description  counts_up  counts_all  \
# 0               GO:0003674     molecular_function      204.0       18866
# 1               GO:0005575     cellular_component      203.0       17584
# 2               GO:0008150     biological_process      197.0       16773
# 3               GO:0009987       cellular process      153.0       13761
# 4               GO:0005488                binding      149.0       12683
# ..                     ...                    ...        ...         ...
# 92              GO:0007623       circadian rhythm        0.0          38
# 93              GO:0007267    cell-cell signaling        0.0          12
# 94              GO:0009838             abscission        0.0          10
# 95              GO:0019825         oxygen binding        0.0           6
# 96              GO:0009835         fruit ripening        0.0           2
#
#     up_ratio  all_ratio  fold_enrichment
# 0   0.524422   0.798628         0.656653
# 1   0.521851   0.744359         0.701074
# 2   0.506427   0.710028         0.713249
# 3   0.393316   0.582526         0.675191
# 4   0.383033   0.536892         0.713427
# ..       ...        ...              ...
# 92  0.000000   0.001609         0.000000
# 93  0.000000   0.000508         0.000000
# 94  0.000000   0.000423         0.000000
# 95  0.000000   0.000254         0.000000
# 96  0.000000   0.000085         0.000000
#
# [97 rows x 7 columns]

# %% [markdown]
# ## False discovery rate
#
# 1. calculate p-value
# 2. calculate FDR
# 3. calculate q-value

# %%
def calculate_p_q_values(df_enrichment, unique_genes_up, unique_genes_all, file_name: str):
    p_values = []
    df_enrichment['counts_up'] = df_enrichment['counts_up'].astype(int) # float(0.0) to int(0)
    # 観測された発現上昇遺伝子とGOタームの関連が偶然によるものでないという証拠の強さを表している
    for index, row in df_enrichment.iterrows():
        if row['counts_up'] == 0:
            p_values.append(1.0)
        else:
            observed_up_genes = row['counts_up'] # create contingency table
            observed_all_genes = row['counts_all']
            observed_not_up_genes = observed_all_genes - observed_up_genes
            total_not_up_genes = unique_genes_all - unique_genes_up
            table = [
            [observed_up_genes, unique_genes_up - observed_up_genes],
            [observed_not_up_genes, total_not_up_genes - observed_not_up_genes]
            ]
            _, p_value = fisher_exact(table, alternative='greater')
            p_values.append(p_value)
    
    _, q_values, _, _ = multipletests(p_values, 
                                      alpha=0.05, 
                                      method='fdr_bh')
    
    df_enrichment['p_value'] = p_values
    df_enrichment['q_value'] = q_values

    results_directory = './goslim_q_values'
    os.makedirs(results_directory, exist_ok=True)
    df_enrichment.to_csv(f'{results_directory}/{file_name}', sep='\t', index=False)

    return df_enrichment


human_goslim_enrichment_with_p_q = calculate_p_q_values(human_goslim_enrichment, human_unique_genes_up, human_unique_genes_all, 'human_goslim_enrichment_with_p_q.tsv')
rice_goslim_enrichment_with_p_q = calculate_p_q_values(rice_goslim_enrichment, rice_unique_genes_up, rice_unique_genes_all, 'rice_goslim_enrichment_with_p_q.tsv')

display(human_goslim_enrichment_with_p_q)
display(rice_goslim_enrichment_with_p_q)
# Out:
#     GOSlim GOA Accession(s)                GOSlim GOA Description  counts_up  \
# 0                GO:0043226                             organelle        128
# 1                GO:0005634                               nucleus         71
# 2                GO:0023052                             signaling         68
# 3                GO:0005886                       plasma membrane         52
# 4                GO:0003824                    catalytic activity         47
# ..                      ...                                   ...        ...
# 132              GO:0071941      nitrogen cycle metabolic process          0
# 133              GO:0031386                           protein tag          2
# 134              GO:0120274             virus coreceptor activity          0
# 135              GO:0007568                                 aging          0
# 136              GO:0071554  cell wall organization or biogenesis          0
#
#      counts_all  up_ratio  all_ratio  fold_enrichment   p_value   q_value
# 0         18493     0.640   0.732135         0.874156  0.998417  1.000000
# 1         11009     0.355   0.435845         0.814510  0.991931  1.000000
# 2          7321     0.340   0.289837         1.173072  0.069456  0.352423
# 3          6799     0.260   0.269171         0.965927  0.641695  1.000000
# 4          6372     0.235   0.252267         0.931554  0.738350  1.000000
# ..          ...       ...        ...              ...       ...       ...
# 132          13     0.000   0.000515         0.000000  1.000000  1.000000
# 133          13     0.010   0.000515        19.430000  0.004594  0.062940
# 134           1     0.000   0.000040         0.000000  1.000000  1.000000
# 135           1     0.000   0.000040         0.000000  1.000000  1.000000
# 136           1     0.000   0.000040         0.000000  1.000000  1.000000
#
# [137 rows x 9 columns]
#    GOSlim GOA Accession(s) GOSlim GOA Description  counts_up  counts_all  \
# 0               GO:0003674     molecular_function        204       18866
# 1               GO:0005575     cellular_component        203       17584
# 2               GO:0008150     biological_process        197       16773
# 3               GO:0009987       cellular process        153       13761
# 4               GO:0005488                binding        149       12683
# ..                     ...                    ...        ...         ...
# 92              GO:0007623       circadian rhythm          0          38
# 93              GO:0007267    cell-cell signaling          0          12
# 94              GO:0009838             abscission          0          10
# 95              GO:0019825         oxygen binding          0           6
# 96              GO:0009835         fruit ripening          0           2
#
#     up_ratio  all_ratio  fold_enrichment  p_value  q_value
# 0   0.524422   0.798628         0.656653      1.0      1.0
# 1   0.521851   0.744359         0.701074      1.0      1.0
# 2   0.506427   0.710028         0.713249      1.0      1.0
# 3   0.393316   0.582526         0.675191      1.0      1.0
# 4   0.383033   0.536892         0.713427      1.0      1.0
# ..       ...        ...              ...      ...      ...
# 92  0.000000   0.001609         0.000000      1.0      1.0
# 93  0.000000   0.000508         0.000000      1.0      1.0
# 94  0.000000   0.000423         0.000000      1.0      1.0
# 95  0.000000   0.000254         0.000000      1.0      1.0
# 96  0.000000   0.000085         0.000000      1.0      1.0
#
# [97 rows x 9 columns]

# %%
human_goslim_enrichment_with_p_q_up = human_goslim_enrichment_with_p_q[human_goslim_enrichment_with_p_q['counts_up'] > 0]
rice_goslim_enrichment_with_p_q_up = rice_goslim_enrichment_with_p_q[rice_goslim_enrichment_with_p_q['counts_up'] > 0]

common_enrichment = pd.merge(human_goslim_enrichment_with_p_q_up, rice_goslim_enrichment_with_p_q_up, 
                             on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], 
                             how='inner', 
                             suffixes=('_human', '_rice'))

display(human_goslim_enrichment_with_p_q_up)
display(rice_goslim_enrichment_with_p_q_up)
display(common_enrichment)
# Out:
#     GOSlim GOA Accession(s)     GOSlim GOA Description  counts_up  counts_all  \
# 0                GO:0043226                  organelle        128       18493
# 1                GO:0005634                    nucleus         71       11009
# 2                GO:0023052                  signaling         68        7321
# 3                GO:0005886            plasma membrane         52        6799
# 4                GO:0003824         catalytic activity         47        6372
# ..                      ...                        ...        ...         ...
# 122              GO:0016209       antioxidant activity          2          93
# 123              GO:0044183  protein folding chaperone         11          75
# 126              GO:0016073    snRNA metabolic process          1          59
# 131              GO:0009975           cyclase activity          1          23
# 133              GO:0031386                protein tag          2          13
#
#      up_ratio  all_ratio  fold_enrichment       p_value       q_value
# 0       0.640   0.732135         0.874156  9.984174e-01  1.000000e+00
# 1       0.355   0.435845         0.814510  9.919309e-01  1.000000e+00
# 2       0.340   0.289837         1.173072  6.945563e-02  3.524230e-01
# 3       0.260   0.269171         0.965927  6.416947e-01  1.000000e+00
# 4       0.235   0.252267         0.931554  7.383501e-01  1.000000e+00
# ..        ...        ...              ...           ...           ...
# 122     0.010   0.003682         2.716022  1.679910e-01  5.352270e-01
# 123     0.055   0.002969        18.523267  1.831697e-11  1.254712e-09
# 126     0.005   0.002336         2.140593  3.747233e-01  7.898014e-01
# 131     0.005   0.000911         5.491087  1.671636e-01  5.352270e-01
# 133     0.010   0.000515        19.430000  4.594190e-03  6.294040e-02
#
# [116 rows x 9 columns]
#    GOSlim GOA Accession(s) GOSlim GOA Description  counts_up  counts_all  \
# 0               GO:0003674     molecular_function        204       18866
# 1               GO:0005575     cellular_component        203       17584
# 2               GO:0008150     biological_process        197       16773
# 3               GO:0009987       cellular process        153       13761
# 4               GO:0005488                binding        149       12683
# ..                     ...                    ...        ...         ...
# 81              GO:0005777             peroxisome          2         118
# 82              GO:0009790     embryo development          3         101
# 84              GO:0016049            cell growth          1          87
# 86              GO:0008219             cell death          3          61
# 91              GO:0009856            pollination          1          46
#
#     up_ratio  all_ratio  fold_enrichment   p_value  q_value
# 0   0.524422   0.798628         0.656653  1.000000      1.0
# 1   0.521851   0.744359         0.701074  1.000000      1.0
# 2   0.506427   0.710028         0.713249  1.000000      1.0
# 3   0.393316   0.582526         0.675191  1.000000      1.0
# 4   0.383033   0.536892         0.713427  1.000000      1.0
# ..       ...        ...              ...       ...      ...
# 81  0.005141   0.004995         1.029280  0.581207      1.0
# 82  0.007712   0.004275         1.803787  0.232143      1.0
# 84  0.002571   0.003683         0.698017  0.764775      1.0
# 86  0.007712   0.002582         2.986599  0.079351      1.0
# 91  0.002571   0.001947         1.320163  0.534444      1.0
#
# [80 rows x 9 columns]
#    GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0               GO:0005634                                         nucleus
# 1               GO:0005886                                 plasma membrane
# 2               GO:0003824                              catalytic activity
# 3               GO:0048856                anatomical structure development
# 4               GO:0005829                                         cytosol
# 5               GO:0005576                            extracellular region
# 6               GO:0005654                                     nucleoplasm
# 7               GO:0030154                            cell differentiation
# 8               GO:0036211                    protein modification process
# 9               GO:0003723                                     RNA binding
# 10              GO:0003677                                     DNA binding
# 11              GO:0016787                              hydrolase activity
# 12              GO:0016740                            transferase activity
# 13              GO:0005856                                    cytoskeleton
# 14              GO:0005783                           endoplasmic reticulum
# 15              GO:0005730                                       nucleolus
# 16              GO:0140110                transcription regulator activity
# 17              GO:0005794                                 Golgi apparatus
# 18              GO:0005739                                   mitochondrion
# 19              GO:0006629                         lipid metabolic process
# 20              GO:0005215                            transporter activity
# 21              GO:0005198                    structural molecule activity
# 22              GO:0005773                                         vacuole
# 23              GO:0008289                                   lipid binding
# 24              GO:0005975                  carbohydrate metabolic process
# 25              GO:0005840                                        ribosome
# 26              GO:0006091  generation of precursor metabolites and energy
# 27              GO:0045182                  translation regulator activity
# 28              GO:0005777                                      peroxisome
#
#     counts_up_human  counts_all_human  up_ratio_human  all_ratio_human  \
# 0                71             11009           0.355         0.435845
# 1                52              6799           0.260         0.269171
# 2                47              6372           0.235         0.252267
# 3                63              6243           0.315         0.247159
# 4                48              5922           0.240         0.234451
# 5                60              4886           0.300         0.193436
# 6                40              4670           0.200         0.184885
# 7                49              4610           0.245         0.182509
# 8                38              3739           0.190         0.148026
# 9                17              3432           0.085         0.135872
# 10               26              2731           0.130         0.108120
# 11               24              2727           0.120         0.107962
# 12               12              2599           0.060         0.102894
# 13               30              2592           0.150         0.102617
# 14               21              2274           0.105         0.090027
# 15               13              2197           0.065         0.086979
# 16               22              1859           0.110         0.073598
# 17               13              1839           0.065         0.072806
# 18               20              1827           0.100         0.072331
# 19               17              1533           0.085         0.060691
# 20                8              1361           0.040         0.053882
# 21                6              1227           0.030         0.048577
# 22                4               991           0.020         0.039234
# 23                7               873           0.035         0.034562
# 24                7               613           0.035         0.024269
# 25                1               601           0.005         0.023793
# 26                5               541           0.025         0.021418
# 27                1               195           0.005         0.007720
# 28                1               154           0.005         0.006097
#
#     fold_enrichment_human  p_value_human  q_value_human  counts_up_rice  \
# 0                0.814510       0.991931       1.000000              50
# 1                0.965927       0.641695       1.000000              13
# 2                0.931554       0.738350       1.000000              88
# 3                1.274481       0.017525       0.171491              13
# 4                1.023668       0.453585       0.887730              26
# 5                1.550901       0.000190       0.006495              10
# 6                1.081756       0.316992       0.700451               2
# 7                1.342398       0.016100       0.169669               1
# 8                1.283554       0.060746       0.332742              11
# 9                0.625587       0.990156       1.000000              10
# 10               1.202369       0.185890       0.565932              21
# 11               1.111507       0.322742       0.701836              38
# 12               0.583124       0.988066       1.000000              17
# 13               1.461748       0.021984       0.191413               1
# 14               1.166313       0.261309       0.654463              28
# 15               0.747308       0.895439       1.000000               1
# 16               1.494615       0.038370       0.250319              18
# 17               0.892787       0.704120       1.000000               3
# 18               1.382540       0.088200       0.411826              14
# 19               1.400532       0.101227       0.433380               6
# 20               0.742366       0.850061       1.000000              10
# 21               0.617579       0.927150       1.000000               2
# 22               0.509768       0.956583       1.000000               8
# 23               1.012675       0.540115       0.999942               7
# 24               1.442194       0.214077       0.598541              12
# 25               0.210141       0.992058       1.000000               1
# 26               1.167237       0.427188       0.857444              11
# 27               0.647667       0.789055       1.000000               1
# 28               0.820097       0.707110       1.000000               2
#
#     counts_all_rice  up_ratio_rice  all_ratio_rice  fold_enrichment_rice  \
# 0              4595       0.128535        0.194514              0.660800
# 1              2077       0.033419        0.087923              0.380095
# 2              9861       0.226221        0.417432              0.541935
# 3              1156       0.033419        0.048935              0.682922
# 4              1319       0.066838        0.055835              1.197055
# 5               787       0.025707        0.033315              0.771633
# 6               326       0.005141        0.013800              0.372561
# 7               276       0.002571        0.011684              0.220027
# 8              3013       0.028278        0.127545              0.221707
# 9              1306       0.025707        0.055285              0.464989
# 10             2131       0.053985        0.090209              0.598441
# 11             3181       0.097686        0.134657              0.725446
# 12             4177       0.043702        0.176819              0.247155
# 13              280       0.002571        0.011853              0.216884
# 14              844       0.071979        0.035728              2.014657
# 15              258       0.002571        0.010922              0.235378
# 16             1214       0.046272        0.051391              0.900408
# 17              850       0.007712        0.035982              0.214332
# 18             1068       0.035990        0.045210              0.796053
# 19              990       0.015424        0.041908              0.368045
# 20             1418       0.025707        0.060026              0.428262
# 21              530       0.005141        0.022436              0.229160
# 22              426       0.020566        0.018033              1.140423
# 23              295       0.017995        0.012488              1.440992
# 24             1103       0.030848        0.046692              0.660680
# 25              420       0.002571        0.017779              0.144589
# 26              491       0.028278        0.020785              1.360494
# 27              156       0.002571        0.006604              0.389279
# 28              118       0.005141        0.004995              1.029280
#
#     p_value_rice  q_value_rice
# 0       0.999800      1.000000
# 1       0.999995      1.000000
# 2       1.000000      1.000000
# 3       0.946193      1.000000
# 4       0.197205      1.000000
# 5       0.838147      1.000000
# 6       0.971945      1.000000
# 7       0.990047      1.000000
# 8       1.000000      1.000000
# 9       0.998471      1.000000
# 10      0.997242      1.000000
# 11      0.989572      1.000000
# 12      1.000000      1.000000
# 13      0.990694      1.000000
# 14      0.000387      0.009387
# 15      0.986533      1.000000
# 16      0.710201      1.000000
# 17      0.999929      1.000000
# 18      0.843284      1.000000
# 19      0.999127      1.000000
# 20      0.999553      1.000000
# 21      0.998627      1.000000
# 22      0.403522      1.000000
# 23      0.214934      1.000000
# 24      0.954133      1.000000
# 25      0.999121      1.000000
# 26      0.188981      1.000000
# 27      0.925641      1.000000
# 28      0.581207      1.000000

# %%
common_goslim_path = '../data/common_term_up.tsv'
common_goslim_df = pd.read_csv(common_goslim_path, sep='\t')


human_common = human_goslim_enrichment_with_p_q_up[human_goslim_enrichment_with_p_q_up['GOSlim GOA Accession(s)'].isin(common_goslim_df['Unique GOSlim GOA Accession(s)'])]
human_common.sort_values(by='fold_enrichment', ascending=False, inplace=True)
human_common['GOSlim'] = human_common['GOSlim GOA Accession(s)'] + ': ' + human_common['GOSlim GOA Description']
cols = ['GOSlim'] + [col for col in human_common.columns if col != 'GOSlim']
human_common = human_common[cols]
human_common.drop(['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], axis=1, inplace=True)

rice_common = rice_goslim_enrichment_with_p_q_up[rice_goslim_enrichment_with_p_q_up['GOSlim GOA Accession(s)'].isin(common_goslim_df['Unique GOSlim GOA Accession(s)'])]
rice_common.sort_values(by='fold_enrichment', ascending=False, inplace=True)
rice_common['GOSlim'] = rice_common['GOSlim GOA Accession(s)'] + ': ' + rice_common['GOSlim GOA Description']
cols = ['GOSlim'] + [col for col in rice_common.columns if col != 'GOSlim']
rice_common = rice_common[cols]
rice_common.drop(['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], axis=1, inplace=True)

display(human_common)
display(rice_common)
# Out:
# /var/folders/7w/6nt3szxj44xdr5xs8y9g8lhw0000gn/T/ipykernel_14622/1564112306.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_common.sort_values(by='fold_enrichment', ascending=False, inplace=True)
# /var/folders/7w/6nt3szxj44xdr5xs8y9g8lhw0000gn/T/ipykernel_14622/1564112306.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_common['GOSlim'] = human_common['GOSlim GOA Accession(s)'] + ': ' + human_common['GOSlim GOA Description']
# /var/folders/7w/6nt3szxj44xdr5xs8y9g8lhw0000gn/T/ipykernel_14622/1564112306.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rice_common.sort_values(by='fold_enrichment', ascending=False, inplace=True)
# /var/folders/7w/6nt3szxj44xdr5xs8y9g8lhw0000gn/T/ipykernel_14622/1564112306.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rice_common['GOSlim'] = rice_common['GOSlim GOA Accession(s)'] + ': ' + rice_common['GOSlim GOA Description']
#                                                 GOSlim  counts_up  counts_all  \
# 7                     GO:0005576: extracellular region         60        4886
# 30        GO:0140110: transcription regulator activity         22        1859
# 21                            GO:0005856: cytoskeleton         30        2592
# 65          GO:0005975: carbohydrate metabolic process          7         613
# 40                 GO:0006629: lipid metabolic process         17        1533
# 32                           GO:0005739: mitochondrion         20        1827
# 9                     GO:0030154: cell differentiation         49        4610
# 12            GO:0036211: protein modification process         38        3739
# 5         GO:0048856: anatomical structure development         63        6243
# 18                             GO:0003677: DNA binding         26        2731
# 74   GO:0006091: generation of precursor metabolite...          5         541
# 25                   GO:0005783: endoplasmic reticulum         21        2274
# 19                      GO:0016787: hydrolase activity         24        2727
# 8                              GO:0005654: nucleoplasm         40        4670
# 6                                  GO:0005829: cytosol         48        5922
# 54                           GO:0008289: lipid binding          7         873
# 3                          GO:0005886: plasma membrane         52        6799
# 4                       GO:0003824: catalytic activity         47        6372
# 31                         GO:0005794: Golgi apparatus         13        1839
# 110                             GO:0005777: peroxisome          1         154
# 1                                  GO:0005634: nucleus         71       11009
# 26                               GO:0005730: nucleolus         13        2197
# 42                    GO:0005215: transporter activity          8        1361
# 104         GO:0045182: translation regulator activity          1         195
# 16                             GO:0003723: RNA binding         17        3432
# 44            GO:0005198: structural molecule activity          6        1227
# 20                    GO:0016740: transferase activity         12        2599
# 49                                 GO:0005773: vacuole          4         991
# 68                                GO:0005840: ribosome          1         601
#
#      up_ratio  all_ratio  fold_enrichment   p_value   q_value
# 7       0.300   0.193436         1.550901  0.000190  0.006495
# 30      0.110   0.073598         1.494615  0.038370  0.250319
# 21      0.150   0.102617         1.461748  0.021984  0.191413
# 65      0.035   0.024269         1.442194  0.214077  0.598541
# 40      0.085   0.060691         1.400532  0.101227  0.433380
# 32      0.100   0.072331         1.382540  0.088200  0.411826
# 9       0.245   0.182509         1.342398  0.016100  0.169669
# 12      0.190   0.148026         1.283554  0.060746  0.332742
# 5       0.315   0.247159         1.274481  0.017525  0.171491
# 18      0.130   0.108120         1.202369  0.185890  0.565932
# 74      0.025   0.021418         1.167237  0.427188  0.857444
# 25      0.105   0.090027         1.166313  0.261309  0.654463
# 19      0.120   0.107962         1.111507  0.322742  0.701836
# 8       0.200   0.184885         1.081756  0.316992  0.700451
# 6       0.240   0.234451         1.023668  0.453585  0.887730
# 54      0.035   0.034562         1.012675  0.540115  0.999942
# 3       0.260   0.269171         0.965927  0.641695  1.000000
# 4       0.235   0.252267         0.931554  0.738350  1.000000
# 31      0.065   0.072806         0.892787  0.704120  1.000000
# 110     0.005   0.006097         0.820097  0.707110  1.000000
# 1       0.355   0.435845         0.814510  0.991931  1.000000
# 26      0.065   0.086979         0.747308  0.895439  1.000000
# 42      0.040   0.053882         0.742366  0.850061  1.000000
# 104     0.005   0.007720         0.647667  0.789055  1.000000
# 16      0.085   0.135872         0.625587  0.990156  1.000000
# 44      0.030   0.048577         0.617579  0.927150  1.000000
# 20      0.060   0.102894         0.583124  0.988066  1.000000
# 49      0.020   0.039234         0.509768  0.956583  1.000000
# 68      0.005   0.023793         0.210141  0.992058  1.000000
#                                                GOSlim  counts_up  counts_all  \
# 43                  GO:0005783: endoplasmic reticulum         28         844
# 66                          GO:0008289: lipid binding          7         295
# 56  GO:0006091: generation of precursor metabolite...         11         491
# 33                                GO:0005829: cytosol         26        1319
# 58                                GO:0005773: vacuole          8         426
# 81                             GO:0005777: peroxisome          2         118
# 35       GO:0140110: transcription regulator activity         18        1214
# 39                          GO:0005739: mitochondrion         14        1068
# 45                   GO:0005576: extracellular region         10         787
# 18                     GO:0016787: hydrolase activity         38        3181
# 36       GO:0048856: anatomical structure development         13        1156
# 11                                GO:0005634: nucleus         50        4595
# 37         GO:0005975: carbohydrate metabolic process         12        1103
# 23                            GO:0003677: DNA binding         21        2131
# 7                      GO:0003824: catalytic activity         88        9861
# 34                            GO:0003723: RNA binding         10        1306
# 30                   GO:0005215: transporter activity         10        1418
# 78         GO:0045182: translation regulator activity          1         156
# 24                        GO:0005886: plasma membrane         13        2077
# 65                            GO:0005654: nucleoplasm          2         326
# 40                GO:0006629: lipid metabolic process          6         990
# 15                   GO:0016740: transferase activity         17        4177
# 72                              GO:0005730: nucleolus          1         258
# 52           GO:0005198: structural molecule activity          2         530
# 19           GO:0036211: protein modification process         11        3013
# 70                   GO:0030154: cell differentiation          1         276
# 68                           GO:0005856: cytoskeleton          1         280
# 42                        GO:0005794: Golgi apparatus          3         850
# 59                               GO:0005840: ribosome          1         420
#
#     up_ratio  all_ratio  fold_enrichment   p_value   q_value
# 43  0.071979   0.035728         2.014657  0.000387  0.009387
# 66  0.017995   0.012488         1.440992  0.214934  1.000000
# 56  0.028278   0.020785         1.360494  0.188981  1.000000
# 33  0.066838   0.055835         1.197055  0.197205  1.000000
# 58  0.020566   0.018033         1.140423  0.403522  1.000000
# 81  0.005141   0.004995         1.029280  0.581207  1.000000
# 35  0.046272   0.051391         0.900408  0.710201  1.000000
# 39  0.035990   0.045210         0.796053  0.843284  1.000000
# 45  0.025707   0.033315         0.771633  0.838147  1.000000
# 18  0.097686   0.134657         0.725446  0.989572  1.000000
# 36  0.033419   0.048935         0.682922  0.946193  1.000000
# 11  0.128535   0.194514         0.660800  0.999800  1.000000
# 37  0.030848   0.046692         0.660680  0.954133  1.000000
# 23  0.053985   0.090209         0.598441  0.997242  1.000000
# 7   0.226221   0.417432         0.541935  1.000000  1.000000
# 34  0.025707   0.055285         0.464989  0.998471  1.000000
# 30  0.025707   0.060026         0.428262  0.999553  1.000000
# 78  0.002571   0.006604         0.389279  0.925641  1.000000
# 24  0.033419   0.087923         0.380095  0.999995  1.000000
# 65  0.005141   0.013800         0.372561  0.971945  1.000000
# 40  0.015424   0.041908         0.368045  0.999127  1.000000
# 15  0.043702   0.176819         0.247155  1.000000  1.000000
# 72  0.002571   0.010922         0.235378  0.986533  1.000000
# 52  0.005141   0.022436         0.229160  0.998627  1.000000
# 19  0.028278   0.127545         0.221707  1.000000  1.000000
# 70  0.002571   0.011684         0.220027  0.990047  1.000000
# 68  0.002571   0.011853         0.216884  0.990694  1.000000
# 42  0.007712   0.035982         0.214332  0.999929  1.000000
# 59  0.002571   0.017779         0.144589  0.999121  1.000000

# %% [markdown]
# ## Visualization

# %%
color = sns.color_palette("flare_r", as_cmap=True)

human_common['-log10(q-value)'] = -np.log10(human_common['q_value'])

plt.figure(figsize=(6, 9))

dotplot = sns.scatterplot(
    data=human_common,
    x='fold_enrichment',
    y='GOSlim',
    size='counts_up', 
    hue='-log10(q-value)',     
    palette=color, 
    legend='brief'
)

plt.grid(color='b', linestyle=':', linewidth=0.1)

plt.xlabel('Fold Enrichment')
plt.ylabel('Common GOSlim Terms')

plt.show()

# %%
color = sns.color_palette("flare_r", as_cmap=True)

rice_common['-log10(q-value)'] = -np.log10(rice_common['q_value'])

plt.figure(figsize=(6, 9))

dotplot = sns.scatterplot(
    data=rice_common,
    x='fold_enrichment',
    y='GOSlim',
    size='counts_up', 
    hue='-log10(q-value)',     
    palette=color, 
    legend='brief'
)

plt.grid(color='b', linestyle=':', linewidth=0.1)

plt.xlabel('Fold Enrichment')
plt.ylabel('Common GOSlim Terms')

plt.show()
