# %%
import pandas as pd
import numpy as np
import os
from scipy.stats import fisher_exact
from statsmodels.stats.multitest import multipletests
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
# path
human_goslim_up_path = '../data/human_annotation/human_annotation_up.tsv'
rice_goslim_up_path = '../data/rice_annotation/rice_annotation_up.tsv'

human_goslim_all_path = '../data/biomart_goslim/biomart_human_goslim_R110.tsv'
rice_goslim_all_path = '../data/biomart_goslim/biomart_rice_goslim_R56.tsv'

# %%
human_goslim_up = pd.read_csv(human_goslim_up_path, sep='\t')
rice_goslim_up = pd.read_csv(rice_goslim_up_path, sep='\t')
human_goslim_all = pd.read_csv(human_goslim_all_path, sep='\t')
rice_goslim_all = pd.read_csv(rice_goslim_all_path, sep='\t')

display(human_goslim_up)
display(rice_goslim_up)
display(human_goslim_all)
display(rice_goslim_all)
# Out:
# /tmp/ipykernel_17708/2801169671.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   human_goslim_all = pd.read_csv(human_goslim_all_path, sep='\t')
# /tmp/ipykernel_17708/2801169671.py:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   rice_goslim_all = pd.read_csv(rice_goslim_all_path, sep='\t')
#        Gene stable ID Chromosome/scaffold name  Gene start(bp)  Gene end(bp)  \
# 0     ENSG00000173110                        1       161524540     161526894
# 1     ENSG00000173110                        1       161524540     161526894
# 2     ENSG00000173110                        1       161524540     161526894
# 3     ENSG00000173110                        1       161524540     161526894
# 4     ENSG00000173110                        1       161524540     161526894
# ...               ...                      ...             ...           ...
# 4843  ENSG00000184205                        X        53082367      53088540
# 4844  ENSG00000184205                        X        53082367      53088540
# 4845  ENSG00000184205                        X        53082367      53088540
# 4846  ENSG00000184205                        X        53082367      53088540
# 4847  ENSG00000174226                        8       100572889     100663415
#
#      GOSlim GOA Accession(s)               GOSlim GOA Description  \
# 0                 GO:0006457                      protein folding
# 1                 GO:0005856                         cytoskeleton
# 2                 GO:0005829                              cytosol
# 3                 GO:0005634                              nucleus
# 4                 GO:0043226                            organelle
# ...                      ...                                  ...
# 4843              GO:0005634                              nucleus
# 4844              GO:0065003  protein-containing complex assembly
# 4845              GO:0006325               chromatin organization
# 4846              GO:0005730                            nucleolus
# 4847              GO:0006886      intracellular protein transport
#
#       HN-score(HN5)    name
# 0               245   HSPA6
# 1               245   HSPA6
# 2               245   HSPA6
# 3               245   HSPA6
# 4               245   HSPA6
# ...             ...     ...
# 4843             51  TSPYL2
# 4844             51  TSPYL2
# 4845             51  TSPYL2
# 4846             51  TSPYL2
# 4847             51   SNX31
#
# [4848 rows x 8 columns]
#      Gene stable ID  Chromosome/scaffold name  Gene start(bp)  Gene end(bp)  \
# 0      Os04g0107900                         4          483234        485978
# 1      Os04g0107900                         4          483234        485978
# 2      Os04g0107900                         4          483234        485978
# 3      Os04g0107900                         4          483234        485978
# 4      Os04g0107900                         4          483234        485978
# ...             ...                       ...             ...           ...
# 2930   Os03g0289800                         3        10039387      10044161
# 2931   Os03g0289800                         3        10039387      10044161
# 2932   Os03g0289800                         3        10039387      10044161
# 2933   Os03g0289800                         3        10039387      10044161
# 2934   Os05g0373900                         5        18016742      18020353
#
#      GOSlim GOA Accession(s) GOSlim GOA Description  HN-score(HN5)
# 0                 GO:0005488                binding            253
# 1                 GO:0009987       cellular process            253
# 2                 GO:0016787     hydrolase activity            253
# 3                 GO:0003824     catalytic activity            253
# 4                 GO:0000166     nucleotide binding            253
# ...                      ...                    ...            ...
# 2930              GO:0016787     hydrolase activity             42
# 2931              GO:0003824     catalytic activity             42
# 2932              GO:0005488                binding             42
# 2933              GO:0003674     molecular_function             42
# 2934              GO:0008152      metabolic process             42
#
# [2935 rows x 7 columns]
#          Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 0       ENSG00000243485                        1        29554      31109
# 1       ENSG00000284332                        1        30366      30503
# 2       ENSG00000186092                        1        65419      71585
# 3       ENSG00000186092                        1        65419      71585
# 4       ENSG00000186092                        1        65419      71585
# ...                 ...                      ...          ...        ...
# 581396  ENSG00000292372                        Y     57207346   57212230
# 581397  ENSG00000292372                        Y     57207346   57212230
# 581398  ENSG00000292372                        Y     57207346   57212230
# 581399  ENSG00000292372                        Y     57207346   57212230
# 581400  ENSG00000292372                        Y     57207346   57212230
#
#        GOSlim GOA Accession(s)         GOSlim GOA Description
# 0                   GO:0031047          gene silencing by RNA
# 1                   GO:0031047          gene silencing by RNA
# 2                   GO:0023052                      signaling
# 3                   GO:0060089  molecular transducer activity
# 4                   GO:0005886                plasma membrane
# ...                        ...                            ...
# 581396              GO:0007010      cytoskeleton organization
# 581397              GO:0008092   cytoskeletal protein binding
# 581398              GO:0031410            cytoplasmic vesicle
# 581399              GO:0043226                      organelle
# 581400              GO:0005768                       endosome
#
# [581401 rows x 6 columns]
#        Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0        Os01g0100100                        1         2983      10815
# 1        Os01g0100100                        1         2983      10815
# 2        Os01g0100100                        1         2983      10815
# 3        Os01g0100100                        1         2983      10815
# 4        Os01g0100100                        1         2983      10815
# ...               ...                      ...          ...        ...
# 258565     gene-rps19                       Pt       134200     134481
# 258566     gene-rps19                       Pt       134200     134481
# 258567     gene-rps19                       Pt       134200     134481
# 258568     gene-rps19                       Pt       134200     134481
# 258569     gene-rps19                       Pt       134200     134481
#
#        GOSlim GOA Accession(s)        GOSlim GOA Description
# 0                   GO:0006810                     transport
# 1                   GO:0008150            biological_process
# 2                   GO:0009987              cellular process
# 3                   GO:0003674            molecular_function
# 4                   GO:0030234     enzyme regulator activity
# ...                        ...                           ...
# 258565              GO:0003674            molecular_function
# 258566              GO:0005198  structural molecule activity
# 258567              GO:0005488                       binding
# 258568              GO:0003723                   RNA binding
# 258569              GO:0003676          nucleic acid binding
#
# [258570 rows x 6 columns]

# %% [markdown]
# ## Fold enrichment

# %%
def count_goslim(df):
    goslim_counts = df.groupby(['GOSlim GOA Accession(s)', 'GOSlim GOA Description']).size().reset_index(name='counts')
    return goslim_counts

# %%
human_goslim_up_counts = count_goslim(human_goslim_up)
rice_goslim_up_counts = count_goslim(rice_goslim_up)
human_goslim_all_counts = count_goslim(human_goslim_all)
rice_goslim_all_counts = count_goslim(rice_goslim_all)

results_directory = './counts'
os.makedirs(results_directory, exist_ok=True)

# sort
human_goslim_up_counts = human_goslim_up_counts.sort_values(by='counts', ascending=False).copy()
rice_goslim_up_counts = rice_goslim_up_counts.sort_values(by='counts', ascending=False).copy()
human_goslim_all_counts = human_goslim_all_counts.sort_values(by='counts', ascending=False).copy()
rice_goslim_all_counts = rice_goslim_all_counts.sort_values(by='counts', ascending=False).copy()

human_goslim_up_counts.to_csv(f'{results_directory}/human_goslim_up_counts.tsv', sep='\t', index=False)
rice_goslim_up_counts.to_csv(f'{results_directory}/rice_goslim_up_counts.tsv', sep='\t', index=False)
human_goslim_all_counts.to_csv(f'{results_directory}/human_goslim_all_counts.tsv', sep='\t', index=False)
rice_goslim_all_counts.to_csv(f'{results_directory}/rice_goslim_all_counts.tsv', sep='\t', index=False)

display(human_goslim_up_counts)
display(rice_goslim_up_counts)
display(human_goslim_all_counts)
display(rice_goslim_all_counts)
# Out:
#     GOSlim GOA Accession(s)            GOSlim GOA Description  counts
# 87               GO:0043226                         organelle     373
# 15               GO:0005634                           nucleus     221
# 72               GO:0023052                         signaling     219
# 13               GO:0005576              extracellular region     175
# 92               GO:0048856  anatomical structure development     160
# ..                      ...                               ...     ...
# 29               GO:0005840                          ribosome       1
# 109              GO:0140053     mitochondrial gene expression       1
# 90               GO:0045182    translation regulator activity       1
# 86               GO:0042393                   histone binding       1
# 85               GO:0042254               ribosome biogenesis       1
#
# [116 rows x 3 columns]
#    GOSlim GOA Accession(s)                    GOSlim GOA Description  counts
# 2               GO:0003674                        molecular_function     243
# 41              GO:0008150                        biological_process     232
# 12              GO:0005575                        cellular_component     231
# 59              GO:0009987                          cellular process     183
# 10              GO:0005488                                   binding     181
# ..                     ...                                       ...     ...
# 25              GO:0005840                                  ribosome       1
# 76              GO:0045182            translation regulator activity       1
# 57              GO:0009856                               pollination       1
# 26              GO:0005856                              cytoskeleton       1
# 40              GO:0008135  translation factor activity, RNA binding       1
#
# [80 rows x 3 columns]
#     GOSlim GOA Accession(s)                GOSlim GOA Description  counts
# 99               GO:0043226                             organelle   56768
# 19               GO:0005634                               nucleus   32321
# 13               GO:0003824                    catalytic activity   27759
# 83               GO:0023052                             signaling   21244
# 36               GO:0005886                       plasma membrane   19067
# ..                      ...                                   ...     ...
# 117              GO:0071941      nitrogen cycle metabolic process      36
# 90               GO:0031386                           protein tag      36
# 66               GO:0007568                                 aging       3
# 116              GO:0071554  cell wall organization or biogenesis       3
# 123              GO:0120274             virus coreceptor activity       1
#
# [137 rows x 3 columns]
#    GOSlim GOA Accession(s)      GOSlim GOA Description  counts
# 2               GO:0003674          molecular_function   22786
# 16              GO:0005575          cellular_component   20356
# 51              GO:0008150          biological_process   20063
# 72              GO:0009987            cellular process   16446
# 14              GO:0005488                     binding   15214
# ..                     ...                         ...     ...
# 11              GO:0005102  signaling receptor binding      47
# 47              GO:0007267         cell-cell signaling      13
# 69              GO:0009838                  abscission      10
# 83              GO:0019825              oxygen binding       6
# 68              GO:0009835              fruit ripening       2
#
# [97 rows x 3 columns]

# %%
def fold_enrichment(df_up_counts, df_all_counts):
    # Get the total number of terms in dataframes
    total_terms_up = df_up_counts['counts'].sum()
    total_terms_all = df_all_counts['counts'].sum()

    merged_df = pd.merge(df_up_counts,
                         df_all_counts, 
                         on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], 
                         how='right', # if there is no match, fill with NaN or 0
                         suffixes=('_up', '_all'))
    
    merged_df['counts_up'] = merged_df['counts_up'].fillna(0)
    merged_df['up_ratio'] = (merged_df['counts_up'] / total_terms_up)
    merged_df['all_ratio'] = (merged_df['counts_all'] / total_terms_all)
    merged_df['fold_enrichment'] = (merged_df['counts_up'] / total_terms_up) / (merged_df['counts_all'] / total_terms_all)
    return merged_df

# %%
human_goslim_enrichment = fold_enrichment(human_goslim_up_counts, human_goslim_all_counts)
rice_goslim_enrichment = fold_enrichment(rice_goslim_up_counts, rice_goslim_all_counts)

human_goslim_enrichment.to_csv(f'{results_directory}/human_goslim_enrichment.tsv', sep='\t', index=False)
rice_goslim_enrichment.to_csv(f'{results_directory}/rice_goslim_enrichment.tsv', sep='\t', index=False)

display(human_goslim_enrichment)
display(rice_goslim_enrichment)
# Out:
#     GOSlim GOA Accession(s)                GOSlim GOA Description  counts_up  \
# 0                GO:0043226                             organelle      373.0
# 1                GO:0005634                               nucleus      221.0
# 2                GO:0003824                    catalytic activity      148.0
# 3                GO:0023052                             signaling      219.0
# 4                GO:0005886                       plasma membrane      154.0
# ..                      ...                                   ...        ...
# 132              GO:0071941      nitrogen cycle metabolic process        0.0
# 133              GO:0031386                           protein tag        5.0
# 134              GO:0007568                                 aging        0.0
# 135              GO:0071554  cell wall organization or biogenesis        0.0
# 136              GO:0120274             virus coreceptor activity        0.0
#
#      counts_all  up_ratio  all_ratio  fold_enrichment
# 0         56768  0.076939   0.097640         0.787986
# 1         32321  0.045586   0.055592         0.820013
# 2         27759  0.030528   0.047745         0.639398
# 3         21244  0.045173   0.036539         1.236292
# 4         19067  0.031766   0.032795         0.968616
# ..          ...       ...        ...              ...
# 132          36  0.000000   0.000062         0.000000
# 133          36  0.001031   0.000062        16.656382
# 134           3  0.000000   0.000005         0.000000
# 135           3  0.000000   0.000005         0.000000
# 136           1  0.000000   0.000002         0.000000
#
# [137 rows x 7 columns]
#    GOSlim GOA Accession(s)      GOSlim GOA Description  counts_up  counts_all  \
# 0               GO:0003674          molecular_function      243.0       22786
# 1               GO:0005575          cellular_component      231.0       20356
# 2               GO:0008150          biological_process      232.0       20063
# 3               GO:0009987            cellular process      183.0       16446
# 4               GO:0005488                     binding      181.0       15214
# ..                     ...                         ...        ...         ...
# 92              GO:0005102  signaling receptor binding        0.0          47
# 93              GO:0007267         cell-cell signaling        0.0          13
# 94              GO:0009838                  abscission        0.0          10
# 95              GO:0019825              oxygen binding        0.0           6
# 96              GO:0009835              fruit ripening        0.0           2
#
#     up_ratio  all_ratio  fold_enrichment
# 0   0.082794   0.088123         0.939525
# 1   0.078705   0.078725         0.999746
# 2   0.079046   0.077592         1.018737
# 3   0.062351   0.063604         0.980304
# 4   0.061670   0.058839         1.048106
# ..       ...        ...              ...
# 92  0.000000   0.000182         0.000000
# 93  0.000000   0.000050         0.000000
# 94  0.000000   0.000039         0.000000
# 95  0.000000   0.000023         0.000000
# 96  0.000000   0.000008         0.000000
#
# [97 rows x 7 columns]

# %% [markdown]
# ## False discovery rate
#
# 1. calculate p-value
# 2. calculate FDR
# 3. calculate q-value

# %%
def calculate_p_q_values(df_enrichment):
    p_values = []
    df_enrichment['counts_up'] = df_enrichment['counts_up'].astype(int) # float(0.0) to int(0)
    total_all_genes = df_enrichment['counts_all'].sum()
    total_up_genes = df_enrichment['counts_up'].sum()

    for index, row in df_enrichment.iterrows():
        if row['counts_up'] == 0:
            p_values.append(1.0)
        else:
            observed_up = row['counts_up']
            observed_all = row['counts_all']
            observed_not_up = observed_all - observed_up
            total_not_up_genes = total_all_genes - total_up_genes

            _, p_value = fisher_exact([[observed_up, total_up_genes - observed_up], 
                                        [observed_not_up, total_not_up_genes - observed_not_up]], 
                                        alternative='greater')
            p_values.append(p_value)
    
    _, q_values, _, _ = multipletests(p_values, 
                                      alpha=0.05, 
                                      method='fdr_bh')
    
    df_enrichment['p_value'] = p_values
    df_enrichment['q_value'] = q_values

    return df_enrichment

# %%
human_goslim_enrichment_with_p_q = calculate_p_q_values(human_goslim_enrichment)
rice_goslim_enrichment_with_p_q = calculate_p_q_values(rice_goslim_enrichment)

human_goslim_enrichment_with_p_q.to_csv(f'{results_directory}/human_goslim_enrichment_with_p_q.tsv', sep='\t', index=False)
rice_goslim_enrichment_with_p_q.to_csv(f'{results_directory}/rice_goslim_enrichment_with_p_q.tsv', sep='\t', index=False)

display(human_goslim_enrichment_with_p_q)
display(rice_goslim_enrichment_with_p_q)
# Out:
#     GOSlim GOA Accession(s)                GOSlim GOA Description  counts_up  \
# 0                GO:0043226                             organelle        373
# 1                GO:0005634                               nucleus        221
# 2                GO:0003824                    catalytic activity        148
# 3                GO:0023052                             signaling        219
# 4                GO:0005886                       plasma membrane        154
# ..                      ...                                   ...        ...
# 132              GO:0071941      nitrogen cycle metabolic process          0
# 133              GO:0031386                           protein tag          5
# 134              GO:0007568                                 aging          0
# 135              GO:0071554  cell wall organization or biogenesis          0
# 136              GO:0120274             virus coreceptor activity          0
#
#      counts_all  up_ratio  all_ratio  fold_enrichment   p_value   q_value
# 0         56768  0.076939   0.097640         0.787986  1.000000  1.000000
# 1         32321  0.045586   0.055592         0.820013  0.999238  1.000000
# 2         27759  0.030528   0.047745         0.639398  1.000000  1.000000
# 3         21244  0.045173   0.036539         1.236292  0.001026  0.009373
# 4         19067  0.031766   0.032795         0.968616  0.668058  1.000000
# ..          ...       ...        ...              ...       ...       ...
# 132          36  0.000000   0.000062         0.000000  1.000000  1.000000
# 133          36  0.001031   0.000062        16.656382  0.000012  0.000168
# 134           3  0.000000   0.000005         0.000000  1.000000  1.000000
# 135           3  0.000000   0.000005         0.000000  1.000000  1.000000
# 136           1  0.000000   0.000002         0.000000  1.000000  1.000000
#
# [137 rows x 9 columns]
#    GOSlim GOA Accession(s)      GOSlim GOA Description  counts_up  counts_all  \
# 0               GO:0003674          molecular_function        243       22786
# 1               GO:0005575          cellular_component        231       20356
# 2               GO:0008150          biological_process        232       20063
# 3               GO:0009987            cellular process        183       16446
# 4               GO:0005488                     binding        181       15214
# ..                     ...                         ...        ...         ...
# 92              GO:0005102  signaling receptor binding          0          47
# 93              GO:0007267         cell-cell signaling          0          13
# 94              GO:0009838                  abscission          0          10
# 95              GO:0019825              oxygen binding          0           6
# 96              GO:0009835              fruit ripening          0           2
#
#     up_ratio  all_ratio  fold_enrichment   p_value   q_value
# 0   0.082794   0.088123         0.939525  0.855030  1.000000
# 1   0.078705   0.078725         0.999746  0.511592  1.000000
# 2   0.079046   0.077592         1.018737  0.393474  1.000000
# 3   0.062351   0.063604         0.980304  0.620941  1.000000
# 4   0.061670   0.058839         1.048106  0.266659  0.994845
# ..       ...        ...              ...       ...       ...
# 92  0.000000   0.000182         0.000000  1.000000  1.000000
# 93  0.000000   0.000050         0.000000  1.000000  1.000000
# 94  0.000000   0.000039         0.000000  1.000000  1.000000
# 95  0.000000   0.000023         0.000000  1.000000  1.000000
# 96  0.000000   0.000008         0.000000  1.000000  1.000000
#
# [97 rows x 9 columns]

# %%
human_goslim_enrichment_with_p_q_up = human_goslim_enrichment_with_p_q[human_goslim_enrichment_with_p_q['counts_up'] > 0]
rice_goslim_enrichment_with_p_q_up = rice_goslim_enrichment_with_p_q[rice_goslim_enrichment_with_p_q['counts_up'] > 0]

common_enrichment = pd.merge(human_goslim_enrichment_with_p_q_up, rice_goslim_enrichment_with_p_q_up, 
                             on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], 
                             how='inner', 
                             suffixes=('_human', '_rice'))

display(human_goslim_enrichment_with_p_q_up)
display(rice_goslim_enrichment_with_p_q_up)
display(common_enrichment)
# Out:
#     GOSlim GOA Accession(s)    GOSlim GOA Description  counts_up  counts_all  \
# 0                GO:0043226                 organelle        373       56768
# 1                GO:0005634                   nucleus        221       32321
# 2                GO:0003824        catalytic activity        148       27759
# 3                GO:0023052                 signaling        219       21244
# 4                GO:0005886           plasma membrane        154       19067
# ..                      ...                       ...        ...         ...
# 124              GO:0022600  digestive system process          2         215
# 126              GO:0050886         endocrine process          2         187
# 127              GO:0016073   snRNA metabolic process          2         165
# 129              GO:0009975          cyclase activity          3          89
# 133              GO:0031386               protein tag          5          36
#
#      up_ratio  all_ratio  fold_enrichment   p_value   q_value
# 0    0.076939   0.097640         0.787986  1.000000  1.000000
# 1    0.045586   0.055592         0.820013  0.999238  1.000000
# 2    0.030528   0.047745         0.639398  1.000000  1.000000
# 3    0.045173   0.036539         1.236292  0.001026  0.009373
# 4    0.031766   0.032795         0.968616  0.668058  1.000000
# ..        ...        ...              ...       ...       ...
# 124  0.000413   0.000370         1.115590  0.536044  1.000000
# 126  0.000413   0.000322         1.282630  0.462618  1.000000
# 127  0.000413   0.000284         1.453648  0.400366  1.000000
# 129  0.000619   0.000153         4.042448  0.038762  0.183116
# 133  0.001031   0.000062        16.656382  0.000012  0.000168
#
# [116 rows x 9 columns]
#    GOSlim GOA Accession(s) GOSlim GOA Description  counts_up  counts_all  \
# 0               GO:0003674     molecular_function        243       22786
# 1               GO:0005575     cellular_component        231       20356
# 2               GO:0008150     biological_process        232       20063
# 3               GO:0009987       cellular process        183       16446
# 4               GO:0005488                binding        181       15214
# ..                     ...                    ...        ...         ...
# 81              GO:0005777             peroxisome          2         144
# 83              GO:0009790     embryo development          3         110
# 84              GO:0016049            cell growth          1          95
# 86              GO:0008219             cell death          5          72
# 89              GO:0009856            pollination          1          54
#
#     up_ratio  all_ratio  fold_enrichment   p_value   q_value
# 0   0.082794   0.088123         0.939525  0.855030  1.000000
# 1   0.078705   0.078725         0.999746  0.511592  1.000000
# 2   0.079046   0.077592         1.018737  0.393474  1.000000
# 3   0.062351   0.063604         0.980304  0.620941  1.000000
# 4   0.061670   0.058839         1.048106  0.266659  0.994845
# ..       ...        ...              ...       ...       ...
# 81  0.000681   0.000557         1.223595  0.487360  1.000000
# 83  0.001022   0.000425         2.402695  0.130217  0.631554
# 84  0.000341   0.000367         0.927356  0.661997  1.000000
# 86  0.001704   0.000278         6.117973  0.001400  0.022629
# 89  0.000341   0.000209         1.631459  0.460179  1.000000
#
# [80 rows x 9 columns]
#    GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0               GO:0005634                                         nucleus
# 1               GO:0003824                              catalytic activity
# 2               GO:0005886                                 plasma membrane
# 3               GO:0005829                                         cytosol
# 4               GO:0005654                                     nucleoplasm
# 5               GO:0048856                anatomical structure development
# 6               GO:0036211                    protein modification process
# 7               GO:0005576                            extracellular region
# 8               GO:0016787                              hydrolase activity
# 9               GO:0016740                            transferase activity
# 10              GO:0030154                            cell differentiation
# 11              GO:0003677                                     DNA binding
# 12              GO:0005856                                    cytoskeleton
# 13              GO:0003723                                     RNA binding
# 14              GO:0005783                           endoplasmic reticulum
# 15              GO:0140110                transcription regulator activity
# 16              GO:0005794                                 Golgi apparatus
# 17              GO:0005739                                   mitochondrion
# 18              GO:0005215                            transporter activity
# 19              GO:0005730                                       nucleolus
# 20              GO:0006629                         lipid metabolic process
# 21              GO:0005198                    structural molecule activity
# 22              GO:0008289                                   lipid binding
# 23              GO:0005773                                         vacuole
# 24              GO:0005975                  carbohydrate metabolic process
# 25              GO:0006091  generation of precursor metabolites and energy
# 26              GO:0005840                                        ribosome
# 27              GO:0045182                  translation regulator activity
# 28              GO:0005777                                      peroxisome
#
#     counts_up_human  counts_all_human  up_ratio_human  all_ratio_human  \
# 0               221             32321        0.045586         0.055592
# 1               148             27759        0.030528         0.047745
# 2               154             19067        0.031766         0.032795
# 3               123             18510        0.025371         0.031837
# 4               136             16444        0.028053         0.028283
# 5               160             14715        0.033003         0.025310
# 6                88             12775        0.018152         0.021973
# 7               175             12225        0.036097         0.021027
# 8                60             11509        0.012376         0.019795
# 9                62             10983        0.012789         0.018891
# 10               95             10821        0.019596         0.018612
# 11              100              9223        0.020627         0.015863
# 12               61              8683        0.012583         0.014935
# 13               37              7930        0.007632         0.013639
# 14               48              7018        0.009901         0.012071
# 15               90              5927        0.018564         0.010194
# 16               35              5910        0.007219         0.010165
# 17               54              5876        0.011139         0.010107
# 18               52              5587        0.010726         0.009610
# 19               44              5043        0.009076         0.008674
# 20               56              4614        0.011551         0.007936
# 21               19              2978        0.003919         0.005122
# 22               41              2938        0.008457         0.005053
# 23               19              2866        0.003919         0.004929
# 24                7              2017        0.001444         0.003469
# 25                8              1644        0.001650         0.002828
# 26                1              1398        0.000206         0.002405
# 27                1               781        0.000206         0.001343
# 28                1               497        0.000206         0.000855
#
#     fold_enrichment_human  p_value_human  q_value_human  counts_up_rice  \
# 0                0.820013   9.992377e-01   1.000000e+00              60
# 1                0.639398   1.000000e+00   1.000000e+00             107
# 2                0.968616   6.680577e-01   1.000000e+00              13
# 3                0.796915   9.965083e-01   1.000000e+00              30
# 4                0.991847   5.507402e-01   1.000000e+00               3
# 5                1.303986   5.826264e-04   6.651652e-03              15
# 6                0.826104   9.722008e-01   1.000000e+00              12
# 7                1.716731   1.457294e-11   3.327487e-10              10
# 8                0.625211   9.999730e-01   1.000000e+00              50
# 9                0.676993   9.996205e-01   1.000000e+00              19
# 10               1.052857   3.195742e-01   9.729258e-01               1
# 11               1.300292   5.966111e-03   4.086786e-02              26
# 12               0.842506   9.245792e-01   1.000000e+00               1
# 13               0.559554   9.999682e-01   1.000000e+00              11
# 14               0.820240   9.308418e-01   1.000000e+00              34
# 15               1.821045   1.034321e-07   2.024314e-06              21
# 16               0.710221   9.868112e-01   1.000000e+00               3
# 17               1.102110   2.537439e-01   7.900663e-01              15
# 18               1.116189   2.303486e-01   7.339013e-01              11
# 19               1.046350   4.016456e-01   1.000000e+00               1
# 20               1.455538   4.379783e-03   3.333502e-02               6
# 21               0.765142   9.040509e-01   1.000000e+00               2
# 22               1.673575   1.322817e-03   1.132662e-02               7
# 23               0.795043   8.691275e-01   1.000000e+00              11
# 24               0.416203   9.977689e-01   1.000000e+00              15
# 25               0.583581   9.636748e-01   1.000000e+00              12
# 26               0.085784   9.999919e-01   1.000000e+00               1
# 27               0.153554   9.985614e-01   1.000000e+00               1
# 28               0.241300   9.844451e-01   1.000000e+00               2
#
#     counts_all_rice  up_ratio_rice  all_ratio_rice  fold_enrichment_rice  \
# 0              5273       0.020443        0.020393              1.002452
# 1             12023       0.036457        0.046498              0.784045
# 2              2276       0.004429        0.008802              0.503201
# 3              1465       0.010221        0.005666              1.804071
# 4               374       0.001022        0.001446              0.706675
# 5              1282       0.005111        0.004958              1.030797
# 6              3538       0.004089        0.013683              0.298809
# 7               848       0.003407        0.003280              1.038901
# 8              3869       0.017036        0.014963              1.138522
# 9              5028       0.006474        0.019445              0.332911
# 10              308       0.000341        0.001191              0.286035
# 11             2486       0.008859        0.009614              0.921387
# 12              316       0.000341        0.001222              0.278794
# 13             1552       0.003748        0.006002              0.624412
# 14              986       0.011584        0.003813              3.037890
# 15             1391       0.007155        0.005380              1.330032
# 16              994       0.001022        0.003844              0.265892
# 17             1184       0.005111        0.004579              1.116117
# 18             1720       0.003748        0.006652              0.563423
# 19              282       0.000341        0.001091              0.312407
# 20             1165       0.002044        0.004506              0.453728
# 21              599       0.000681        0.002317              0.294153
# 22              357       0.002385        0.001381              1.727428
# 23              469       0.003748        0.001814              2.066283
# 24             1397       0.005111        0.005403              0.945943
# 25              609       0.004089        0.002355              1.735937
# 26              474       0.000341        0.001833              0.185862
# 27              205       0.000341        0.000793              0.429750
# 28              144       0.000681        0.000557              1.223595
#
#     p_value_rice  q_value_rice
# 0   5.103143e-01  1.000000e+00
# 1   9.968277e-01  1.000000e+00
# 2   9.981747e-01  1.000000e+00
# 3   1.816219e-03  2.516760e-02
# 4   7.975360e-01  1.000000e+00
# 5   4.883171e-01  1.000000e+00
# 6   1.000000e+00  1.000000e+00
# 7   4.950302e-01  1.000000e+00
# 8   1.946921e-01  8.210927e-01
# 9   1.000000e+00  1.000000e+00
# 10  9.703463e-01  1.000000e+00
# 11  6.895404e-01  1.000000e+00
# 12  9.729375e-01  1.000000e+00
# 13  9.645399e-01  1.000000e+00
# 14  2.212317e-08  5.364868e-07
# 15  1.184750e-01  6.219626e-01
# 16  9.990995e-01  1.000000e+00
# 17  3.699017e-01  1.000000e+00
# 18  9.866859e-01  1.000000e+00
# 19  9.600856e-01  1.000000e+00
# 20  9.911203e-01  1.000000e+00
# 21  9.916041e-01  1.000000e+00
# 22  1.148557e-01  6.219626e-01
# 23  1.981971e-02  1.602093e-01
# 24  6.205531e-01  1.000000e+00
# 25  4.829983e-02  3.346488e-01
# 26  9.955554e-01  1.000000e+00
# 27  9.037849e-01  1.000000e+00
# 28  4.873605e-01  1.000000e+00

# %%
common_goslim_path = '../data/common_term_up.tsv'
common_goslim_df = pd.read_csv(common_goslim_path, sep='\t')


human_common = human_goslim_enrichment_with_p_q_up[human_goslim_enrichment_with_p_q_up['GOSlim GOA Accession(s)'].isin(common_goslim_df['Unique GOSlim GOA Accession(s)'])]
human_common.sort_values(by='fold_enrichment', ascending=False, inplace=True)
human_common['GOSlim'] = human_common['GOSlim GOA Accession(s)'] + ': ' + human_common['GOSlim GOA Description']
cols = ['GOSlim'] + [col for col in human_common.columns if col != 'GOSlim']
human_common = human_common[cols]
human_common.drop(['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], axis=1, inplace=True)

rice_common = rice_goslim_enrichment_with_p_q_up[rice_goslim_enrichment_with_p_q_up['GOSlim GOA Accession(s)'].isin(common_goslim_df['Unique GOSlim GOA Accession(s)'])]
rice_common.sort_values(by='fold_enrichment', ascending=False, inplace=True)
rice_common['GOSlim'] = rice_common['GOSlim GOA Accession(s)'] + ': ' + rice_common['GOSlim GOA Description']
cols = ['GOSlim'] + [col for col in rice_common.columns if col != 'GOSlim']
rice_common = rice_common[cols]
rice_common.drop(['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], axis=1, inplace=True)

display(human_common)
display(rice_common)
# Out:
# /tmp/ipykernel_17708/1564112306.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_common.sort_values(by='fold_enrichment', ascending=False, inplace=True)
# /tmp/ipykernel_17708/1564112306.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_common['GOSlim'] = human_common['GOSlim GOA Accession(s)'] + ': ' + human_common['GOSlim GOA Description']
# /tmp/ipykernel_17708/1564112306.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rice_common.sort_values(by='fold_enrichment', ascending=False, inplace=True)
# /tmp/ipykernel_17708/1564112306.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rice_common['GOSlim'] = rice_common['GOSlim GOA Accession(s)'] + ': ' + rice_common['GOSlim GOA Description']
#                                                 GOSlim  counts_up  counts_all  \
# 28        GO:0140110: transcription regulator activity         90        5927
# 11                    GO:0005576: extracellular region        175       12225
# 52                           GO:0008289: lipid binding         41        2938
# 37                 GO:0006629: lipid metabolic process         56        4614
# 7         GO:0048856: anatomical structure development        160       14715
# 16                             GO:0003677: DNA binding        100        9223
# 31                    GO:0005215: transporter activity         52        5587
# 30                           GO:0005739: mitochondrion         54        5876
# 15                    GO:0030154: cell differentiation         95       10821
# 34                               GO:0005730: nucleolus         44        5043
# 6                              GO:0005654: nucleoplasm        136       16444
# 4                          GO:0005886: plasma membrane        154       19067
# 19                            GO:0005856: cytoskeleton         61        8683
# 9             GO:0036211: protein modification process         88       12775
# 24                   GO:0005783: endoplasmic reticulum         48        7018
# 1                                  GO:0005634: nucleus        221       32321
# 5                                  GO:0005829: cytosol        123       18510
# 53                                 GO:0005773: vacuole         19        2866
# 51            GO:0005198: structural molecule activity         19        2978
# 29                         GO:0005794: Golgi apparatus         35        5910
# 14                    GO:0016740: transferase activity         62       10983
# 2                       GO:0003824: catalytic activity        148       27759
# 12                      GO:0016787: hydrolase activity         60       11509
# 68   GO:0006091: generation of precursor metabolite...          8        1644
# 21                             GO:0003723: RNA binding         37        7930
# 62          GO:0005975: carbohydrate metabolic process          7        2017
# 110                             GO:0005777: peroxisome          1         497
# 99          GO:0045182: translation regulator activity          1         781
# 73                                GO:0005840: ribosome          1        1398
#
#      up_ratio  all_ratio  fold_enrichment       p_value       q_value
# 28   0.018564   0.010194         1.821045  1.034321e-07  2.024314e-06
# 11   0.036097   0.021027         1.716731  1.457294e-11  3.327487e-10
# 52   0.008457   0.005053         1.673575  1.322817e-03  1.132662e-02
# 37   0.011551   0.007936         1.455538  4.379783e-03  3.333502e-02
# 7    0.033003   0.025310         1.303986  5.826264e-04  6.651652e-03
# 16   0.020627   0.015863         1.300292  5.966111e-03  4.086786e-02
# 31   0.010726   0.009610         1.116189  2.303486e-01  7.339013e-01
# 30   0.011139   0.010107         1.102110  2.537439e-01  7.900663e-01
# 15   0.019596   0.018612         1.052857  3.195742e-01  9.729258e-01
# 34   0.009076   0.008674         1.046350  4.016456e-01  1.000000e+00
# 6    0.028053   0.028283         0.991847  5.507402e-01  1.000000e+00
# 4    0.031766   0.032795         0.968616  6.680577e-01  1.000000e+00
# 19   0.012583   0.014935         0.842506  9.245792e-01  1.000000e+00
# 9    0.018152   0.021973         0.826104  9.722008e-01  1.000000e+00
# 24   0.009901   0.012071         0.820240  9.308418e-01  1.000000e+00
# 1    0.045586   0.055592         0.820013  9.992377e-01  1.000000e+00
# 5    0.025371   0.031837         0.796915  9.965083e-01  1.000000e+00
# 53   0.003919   0.004929         0.795043  8.691275e-01  1.000000e+00
# 51   0.003919   0.005122         0.765142  9.040509e-01  1.000000e+00
# 29   0.007219   0.010165         0.710221  9.868112e-01  1.000000e+00
# 14   0.012789   0.018891         0.676993  9.996205e-01  1.000000e+00
# 2    0.030528   0.047745         0.639398  1.000000e+00  1.000000e+00
# 12   0.012376   0.019795         0.625211  9.999730e-01  1.000000e+00
# 68   0.001650   0.002828         0.583581  9.636748e-01  1.000000e+00
# 21   0.007632   0.013639         0.559554  9.999682e-01  1.000000e+00
# 62   0.001444   0.003469         0.416203  9.977689e-01  1.000000e+00
# 110  0.000206   0.000855         0.241300  9.844451e-01  1.000000e+00
# 99   0.000206   0.001343         0.153554  9.985614e-01  1.000000e+00
# 73   0.000206   0.002405         0.085784  9.999919e-01  1.000000e+00
#                                                GOSlim  counts_up  counts_all  \
# 43                  GO:0005783: endoplasmic reticulum         34         986
# 59                                GO:0005773: vacuole         11         469
# 34                                GO:0005829: cytosol         30        1465
# 51  GO:0006091: generation of precursor metabolite...         12         609
# 66                          GO:0008289: lipid binding          7         357
# 36       GO:0140110: transcription regulator activity         21        1391
# 81                             GO:0005777: peroxisome          2         144
# 18                     GO:0016787: hydrolase activity         50        3869
# 39                          GO:0005739: mitochondrion         15        1184
# 48                   GO:0005576: extracellular region         10         848
# 37       GO:0048856: anatomical structure development         15        1282
# 12                                GO:0005634: nucleus         60        5273
# 35         GO:0005975: carbohydrate metabolic process         15        1397
# 23                            GO:0003677: DNA binding         26        2486
# 7                      GO:0003824: catalytic activity        107       12023
# 63                            GO:0005654: nucleoplasm          3         374
# 32                            GO:0003723: RNA binding         11        1552
# 29                   GO:0005215: transporter activity         11        1720
# 24                        GO:0005886: plasma membrane         13        2276
# 40                GO:0006629: lipid metabolic process          6        1165
# 77         GO:0045182: translation regulator activity          1         205
# 15                   GO:0016740: transferase activity         19        5028
# 73                              GO:0005730: nucleolus          1         282
# 19           GO:0036211: protein modification process         12        3538
# 53           GO:0005198: structural molecule activity          2         599
# 71                   GO:0030154: cell differentiation          1         308
# 69                           GO:0005856: cytoskeleton          1         316
# 42                        GO:0005794: Golgi apparatus          3         994
# 58                               GO:0005840: ribosome          1         474
#
#     up_ratio  all_ratio  fold_enrichment       p_value       q_value
# 43  0.011584   0.003813         3.037890  2.212317e-08  5.364868e-07
# 59  0.003748   0.001814         2.066283  1.981971e-02  1.602093e-01
# 34  0.010221   0.005666         1.804071  1.816219e-03  2.516760e-02
# 51  0.004089   0.002355         1.735937  4.829983e-02  3.346488e-01
# 66  0.002385   0.001381         1.727428  1.148557e-01  6.219626e-01
# 36  0.007155   0.005380         1.330032  1.184750e-01  6.219626e-01
# 81  0.000681   0.000557         1.223595  4.873605e-01  1.000000e+00
# 18  0.017036   0.014963         1.138522  1.946921e-01  8.210927e-01
# 39  0.005111   0.004579         1.116117  3.699017e-01  1.000000e+00
# 48  0.003407   0.003280         1.038901  4.950302e-01  1.000000e+00
# 37  0.005111   0.004958         1.030797  4.883171e-01  1.000000e+00
# 12  0.020443   0.020393         1.002452  5.103143e-01  1.000000e+00
# 35  0.005111   0.005403         0.945943  6.205531e-01  1.000000e+00
# 23  0.008859   0.009614         0.921387  6.895404e-01  1.000000e+00
# 7   0.036457   0.046498         0.784045  9.968277e-01  1.000000e+00
# 63  0.001022   0.001446         0.706675  7.975360e-01  1.000000e+00
# 32  0.003748   0.006002         0.624412  9.645399e-01  1.000000e+00
# 29  0.003748   0.006652         0.563423  9.866859e-01  1.000000e+00
# 24  0.004429   0.008802         0.503201  9.981747e-01  1.000000e+00
# 40  0.002044   0.004506         0.453728  9.911203e-01  1.000000e+00
# 77  0.000341   0.000793         0.429750  9.037849e-01  1.000000e+00
# 15  0.006474   0.019445         0.332911  1.000000e+00  1.000000e+00
# 73  0.000341   0.001091         0.312407  9.600856e-01  1.000000e+00
# 19  0.004089   0.013683         0.298809  1.000000e+00  1.000000e+00
# 53  0.000681   0.002317         0.294153  9.916041e-01  1.000000e+00
# 71  0.000341   0.001191         0.286035  9.703463e-01  1.000000e+00
# 69  0.000341   0.001222         0.278794  9.729375e-01  1.000000e+00
# 42  0.001022   0.003844         0.265892  9.990995e-01  1.000000e+00
# 58  0.000341   0.001833         0.185862  9.955554e-01  1.000000e+00

# %% [markdown]
# ## Visualization

# %%
color = sns.color_palette("flare_r", as_cmap=True)

plt.figure(figsize=(6, 9))

dotplot = sns.scatterplot(
    data=human_common,
    x='fold_enrichment',
    y='GOSlim',
    size='counts_up', 
    hue='q_value',     
    palette=color, 
    legend=False
)

plt.grid(color='b', linestyle=':', linewidth=0.1)

plt.xlabel('Fold Enrichment')
plt.ylabel('Common GOSlim Terms')

plt.show()
