# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
import os
from scipy.stats import fisher_exact
from statsmodels.stats.multitest import multipletests
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
def count_goslim(df, file_name: str):
    unique_gene_pairs = df.drop_duplicates(subset=['GOSlim GOA Accession(s)', 'Gene stable ID_human', 'Gene stable ID_rice'])
    goslim_counts = unique_gene_pairs.groupby(['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain']).size().reset_index(name='counts')
    goslim_counts = goslim_counts.sort_values(by='counts', ascending=False).copy()
    goslim_counts.reset_index(drop=True, inplace=True)
    results_directory = '../data/goslim_correspondence_counts'
    os.makedirs(results_directory, exist_ok=True)
    goslim_counts.to_csv(f'{results_directory}/{file_name}', sep='\t', index=False)
    return goslim_counts

# %%
merged_df_goslim_pd = pd.read_csv('../data/GOslim_merge/GOslim_merge_common_goslim_correspondence_all_up.tsv', 
                                  sep='\t',
                                  low_memory=False)
merged_df_up = pd.read_csv('../data/circos_hr_UP_2311/combined_goslim_UP.tsv', sep='\t')

display(merged_df_goslim_pd)
display(merged_df_up)
# Out:
#           GOSlim GOA Accession(s)          GOSlim GOA Description  \
# 0                      GO:0005886                 plasma membrane
# 1                      GO:0005886                 plasma membrane
# 2                      GO:0005886                 plasma membrane
# 3                      GO:0005886                 plasma membrane
# 4                      GO:0005886                 plasma membrane
# ...                           ...                             ...
# 205962886              GO:0045182  translation regulator activity
# 205962887              GO:0045182  translation regulator activity
# 205962888              GO:0045182  translation regulator activity
# 205962889              GO:0045182  translation regulator activity
# 205962890              GO:0045182  translation regulator activity
#
#                 GOSlim_domain Gene stable ID_human Gene stable ID_rice
# 0          cellular_component         Os01g0100400     ENSG00000186092
# 1          cellular_component         Os01g0103600     ENSG00000186092
# 2          cellular_component         Os01g0104000     ENSG00000186092
# 3          cellular_component         Os01g0108000     ENSG00000186092
# 4          cellular_component         Os01g0110100     ENSG00000186092
# ...                       ...                  ...                 ...
# 205962886  molecular_function         Os12g0507200     ENSG00000205916
# 205962887  molecular_function         Os12g0541500     ENSG00000205916
# 205962888  molecular_function         Os12g0607100     ENSG00000205916
# 205962889  molecular_function         Os12g0617100     ENSG00000205916
# 205962890  molecular_function            gene-infA     ENSG00000205916
#
# [205962891 rows x 5 columns]
#       GOSlim GOA Accession(s)          GOSlim GOA Description  \
# 0                  GO:0003824              catalytic activity
# 1                  GO:0003824              catalytic activity
# 2                  GO:0003824              catalytic activity
# 3                  GO:0003824              catalytic activity
# 4                  GO:0003824              catalytic activity
# ...                       ...                             ...
# 15167              GO:0005198    structural molecule activity
# 15168              GO:0005777                      peroxisome
# 15169              GO:0005777                      peroxisome
# 15170              GO:0045182  translation regulator activity
# 15171              GO:0005840                        ribosome
#
#             GOSlim_domain Gene stable ID_rice Gene stable ID_human  \
# 0      molecular_function        Os04g0167875      ENSG00000178297
# 1      molecular_function        Os05g0135400      ENSG00000143199
# 2      molecular_function        Os02g0164000      ENSG00000143199
# 3      molecular_function        Os08g0473900      ENSG00000143199
# 4      molecular_function        Os09g0315700      ENSG00000143199
# ...                   ...                 ...                  ...
# 15167  molecular_function        Os01g0105800      ENSG00000184697
# 15168  cellular_component        Os07g0529000      ENSG00000165507
# 15169  cellular_component        Os06g0253100      ENSG00000165507
# 15170  molecular_function        Os05g0373900      ENSG00000183655
# 15171  cellular_component        Os11g0303800      ENSG00000112110
#
#       Chromosome/scaffold name_rice  start1 (bp)  end1 (bp)  \
# 0                               R_4      4644736    4644996
# 1                               R_5      2073613    2075302
# 2                               R_2      3441185    3446850
# 3                               R_8     23341289   23343299
# 4                               R_9      8692296    8697399
# ...                             ...          ...        ...
# 15167                           R_1       306871     308842
# 15168                           R_7     20691213   20693521
# 15169                           R_6      7940956    7941680
# 15170                           R_5     18016742   18020353
# 15171                          R_11     11436951   11446262
#
#       Chromosome/scaffold name_human  start2 (bp)  end2 (bp)  \
# 0                               H_19      2360238    2426261
# 1                                H_1    167809386  167914215
# 2                                H_1    167809386  167914215
# 3                                H_1    167809386  167914215
# 4                                H_1    167809386  167914215
# ...                              ...          ...        ...
# 15167                           H_16      3014712    3020071
# 15168                           H_10     44970981   44978809
# 15169                           H_10     44970981   44978809
# 15170                           H_15     85759326   85794925
# 15171                            H_6    159789812  159798436
#
#        HN-score(HN5)_rice  HN-score(HN5)_human
# 0                      57                   72
# 1                      61                   97
# 2                      48                   97
# 3                      48                   97
# 4                      49                   97
# ...                   ...                  ...
# 15167                  53                   65
# 15168                  59                   70
# 15169                 129                   70
# 15170                  42                   74
# 15171                  65                   63
#
# [15172 rows x 13 columns]

# %%
gosilm_correspondence_up_counts = count_goslim(merged_df_up, 'goslim_correspondence_counts_UP.tsv')
goslim_correspondence_all_counts = count_goslim(merged_df_goslim_pd, 'goslim_correspondence_counts_all.tsv')

display(gosilm_correspondence_up_counts, goslim_correspondence_all_counts)
# Out:
#    GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0               GO:0003824                              catalytic activity
# 1               GO:0005634                                         nucleus
# 2               GO:0005829                                         cytosol
# 3               GO:0016787                              hydrolase activity
# 4               GO:0048856                anatomical structure development
# 5               GO:0005886                                 plasma membrane
# 6               GO:0005576                            extracellular region
# 7               GO:0005783                           endoplasmic reticulum
# 8               GO:0003677                                     DNA binding
# 9               GO:0036211                    protein modification process
# 10              GO:0140110                transcription regulator activity
# 11              GO:0005739                                   mitochondrion
# 12              GO:0016740                            transferase activity
# 13              GO:0003723                                     RNA binding
# 14              GO:0006629                         lipid metabolic process
# 15              GO:0005975                  carbohydrate metabolic process
# 16              GO:0005215                            transporter activity
# 17              GO:0005654                                     nucleoplasm
# 18              GO:0006091  generation of precursor metabolites and energy
# 19              GO:0008289                                   lipid binding
# 20              GO:0030154                            cell differentiation
# 21              GO:0005794                                 Golgi apparatus
# 22              GO:0005773                                         vacuole
# 23              GO:0005856                                    cytoskeleton
# 24              GO:0005730                                       nucleolus
# 25              GO:0005198                    structural molecule activity
# 26              GO:0005777                                      peroxisome
# 27              GO:0005840                                        ribosome
# 28              GO:0045182                  translation regulator activity
#
#          GOSlim_domain  counts
# 0   molecular_function    4136
# 1   cellular_component    3550
# 2   cellular_component    1248
# 3   molecular_function     912
# 4   biological_process     819
# 5   cellular_component     676
# 6   cellular_component     600
# 7   cellular_component     588
# 8   molecular_function     546
# 9   biological_process     418
# 10  molecular_function     396
# 11  cellular_component     280
# 12  molecular_function     204
# 13  molecular_function     170
# 14  biological_process     102
# 15  biological_process      84
# 16  molecular_function      80
# 17  cellular_component      80
# 18  biological_process      55
# 19  molecular_function      49
# 20  biological_process      49
# 21  cellular_component      39
# 22  cellular_component      32
# 23  cellular_component      30
# 24  cellular_component      13
# 25  molecular_function      12
# 26  cellular_component       2
# 27  cellular_component       1
# 28  molecular_function       1
#    GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0               GO:0003824                              catalytic activity
# 1               GO:0005634                                         nucleus
# 2               GO:0005886                                 plasma membrane
# 3               GO:0036211                    protein modification process
# 4               GO:0016740                            transferase activity
# 5               GO:0016787                              hydrolase activity
# 6               GO:0005829                                         cytosol
# 7               GO:0048856                anatomical structure development
# 8               GO:0003677                                     DNA binding
# 9               GO:0003723                                     RNA binding
# 10              GO:0005576                            extracellular region
# 11              GO:0140110                transcription regulator activity
# 12              GO:0005739                                   mitochondrion
# 13              GO:0005215                            transporter activity
# 14              GO:0005783                           endoplasmic reticulum
# 15              GO:0005794                                 Golgi apparatus
# 16              GO:0005654                                     nucleoplasm
# 17              GO:0006629                         lipid metabolic process
# 18              GO:0030154                            cell differentiation
# 19              GO:0005856                                    cytoskeleton
# 20              GO:0005975                  carbohydrate metabolic process
# 21              GO:0005198                    structural molecule activity
# 22              GO:0005730                                       nucleolus
# 23              GO:0005773                                         vacuole
# 24              GO:0005768                                        endosome
# 25              GO:0006091  generation of precursor metabolites and energy
# 26              GO:0008289                                   lipid binding
# 27              GO:0005840                                        ribosome
# 28              GO:0030312                external encapsulating structure
# 29              GO:0005635                                nuclear envelope
# 30              GO:0005764                                        lysosome
# 31              GO:0045182                  translation regulator activity
# 32              GO:0005777                                      peroxisome
# 33              GO:0003774                     cytoskeletal motor activity
#
#          GOSlim_domain    counts
# 0   molecular_function  62834292
# 1   cellular_component  50586355
# 2   cellular_component  14121523
# 3   biological_process  11265607
# 4   molecular_function  10856023
# 5   molecular_function   8674587
# 6   cellular_component   7811118
# 7   biological_process   7216908
# 8   molecular_function   5819761
# 9   molecular_function   4482192
# 10  cellular_component   3845282
# 11  molecular_function   2256826
# 12  cellular_component   1951236
# 13  molecular_function   1929898
# 14  cellular_component   1919256
# 15  cellular_component   1563150
# 16  cellular_component   1522420
# 17  biological_process   1517670
# 18  biological_process   1272360
# 19  cellular_component    725760
# 20  biological_process    676139
# 21  molecular_function    650310
# 22  cellular_component    566826
# 23  cellular_component    422166
# 24  cellular_component    342792
# 25  biological_process    265631
# 26  molecular_function    257535
# 27  cellular_component    252420
# 28  cellular_component    203467
# 29  cellular_component     50592
# 30  cellular_component     45237
# 31  molecular_function     30420
# 32  cellular_component     18172
# 33  molecular_function      8960

# %%
# for debugging purpose
total_counts_up = gosilm_correspondence_up_counts['counts'].sum()
total_counts_all = goslim_correspondence_all_counts['counts'].sum()


unique_rows_up = merged_df_up.drop_duplicates(subset=['GOSlim GOA Accession(s)', 'Gene stable ID_human', 'Gene stable ID_rice']).shape[0]
unique_rows_all = merged_df_goslim_pd.drop_duplicates(subset=['GOSlim GOA Accession(s)', 'Gene stable ID_human', 'Gene stable ID_rice']).shape[0]

print(f"Total counts: {unique_rows_all}")
print(f"up counts: {unique_rows_up}")
print(f"Counts match rows: {unique_rows_up == total_counts_up}")
# Out:
# Total counts: 205962891
# up counts: 15172
# Counts match rows: True

# %%
def fold_enrichment(df_goslim_up_counts, df_goslim_all_counts, unique_genes_up, unique_genes_all, file_name: str):
    """_summary_
    Args:
        df_goslim_up_counts (dataframe): _description_
        df_goslim_all_counts (dataframe): _description_
        unique_genes_up (): _description_
        unique_genes_all (dataframe): _description_
        file_name (str): _description_

    Returns:
        dataframe : _description_
    """
    merged_df = pd.merge(df_goslim_up_counts, 
                         df_goslim_all_counts,
                         on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'], 
                         how='right', # if there is no match, fill with NaN or 0
                         suffixes=('_up', '_all'))
    
    merged_df['counts_up'] = merged_df['counts_up'].fillna(0)
    merged_df['counts_all'] = merged_df['counts_all'].fillna(0)
    merged_df['up_ratio'] = merged_df['counts_up'] / unique_genes_up
    merged_df['all_ratio'] = merged_df['counts_all'] / unique_genes_all
    merged_df['fold_enrichment'] = merged_df['up_ratio'] / merged_df['all_ratio']
    merged_df.replace([np.inf, -np.inf], np.nan, inplace=True) # inf -> nan
    results_directory = '../data/goslim_fold_enrichment_correspondence'
    os.makedirs(results_directory, exist_ok=True)
    merged_df.to_csv(f'{results_directory}/{file_name}', sep='\t', index=False)
    
    return merged_df


goslim_correspondence_enrichment = fold_enrichment(gosilm_correspondence_up_counts, goslim_correspondence_all_counts, unique_rows_up, unique_rows_all, 'goslim_correspondence_fold_enrichment.tsv')
display(goslim_correspondence_enrichment)
# Out:
#    GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0               GO:0003824                              catalytic activity
# 1               GO:0005634                                         nucleus
# 2               GO:0005886                                 plasma membrane
# 3               GO:0036211                    protein modification process
# 4               GO:0016740                            transferase activity
# 5               GO:0016787                              hydrolase activity
# 6               GO:0005829                                         cytosol
# 7               GO:0048856                anatomical structure development
# 8               GO:0003677                                     DNA binding
# 9               GO:0003723                                     RNA binding
# 10              GO:0005576                            extracellular region
# 11              GO:0140110                transcription regulator activity
# 12              GO:0005739                                   mitochondrion
# 13              GO:0005215                            transporter activity
# 14              GO:0005783                           endoplasmic reticulum
# 15              GO:0005794                                 Golgi apparatus
# 16              GO:0005654                                     nucleoplasm
# 17              GO:0006629                         lipid metabolic process
# 18              GO:0030154                            cell differentiation
# 19              GO:0005856                                    cytoskeleton
# 20              GO:0005975                  carbohydrate metabolic process
# 21              GO:0005198                    structural molecule activity
# 22              GO:0005730                                       nucleolus
# 23              GO:0005773                                         vacuole
# 24              GO:0005768                                        endosome
# 25              GO:0006091  generation of precursor metabolites and energy
# 26              GO:0008289                                   lipid binding
# 27              GO:0005840                                        ribosome
# 28              GO:0030312                external encapsulating structure
# 29              GO:0005635                                nuclear envelope
# 30              GO:0005764                                        lysosome
# 31              GO:0045182                  translation regulator activity
# 32              GO:0005777                                      peroxisome
# 33              GO:0003774                     cytoskeletal motor activity
#
#          GOSlim_domain  counts_up  counts_all  up_ratio  all_ratio  \
# 0   molecular_function     4136.0    62834292  0.272607   0.305076
# 1   cellular_component     3550.0    50586355  0.233984   0.245609
# 2   cellular_component      676.0    14121523  0.044556   0.068563
# 3   biological_process      418.0    11265607  0.027551   0.054697
# 4   molecular_function      204.0    10856023  0.013446   0.052709
# 5   molecular_function      912.0     8674587  0.060111   0.042117
# 6   cellular_component     1248.0     7811118  0.082257   0.037925
# 7   biological_process      819.0     7216908  0.053981   0.035040
# 8   molecular_function      546.0     5819761  0.035987   0.028256
# 9   molecular_function      170.0     4482192  0.011205   0.021762
# 10  cellular_component      600.0     3845282  0.039547   0.018670
# 11  molecular_function      396.0     2256826  0.026101   0.010957
# 12  cellular_component      280.0     1951236  0.018455   0.009474
# 13  molecular_function       80.0     1929898  0.005273   0.009370
# 14  cellular_component      588.0     1919256  0.038756   0.009318
# 15  cellular_component       39.0     1563150  0.002571   0.007589
# 16  cellular_component       80.0     1522420  0.005273   0.007392
# 17  biological_process      102.0     1517670  0.006723   0.007369
# 18  biological_process       49.0     1272360  0.003230   0.006178
# 19  cellular_component       30.0      725760  0.001977   0.003524
# 20  biological_process       84.0      676139  0.005537   0.003283
# 21  molecular_function       12.0      650310  0.000791   0.003157
# 22  cellular_component       13.0      566826  0.000857   0.002752
# 23  cellular_component       32.0      422166  0.002109   0.002050
# 24  cellular_component        0.0      342792  0.000000   0.001664
# 25  biological_process       55.0      265631  0.003625   0.001290
# 26  molecular_function       49.0      257535  0.003230   0.001250
# 27  cellular_component        1.0      252420  0.000066   0.001226
# 28  cellular_component        0.0      203467  0.000000   0.000988
# 29  cellular_component        0.0       50592  0.000000   0.000246
# 30  cellular_component        0.0       45237  0.000000   0.000220
# 31  molecular_function        1.0       30420  0.000066   0.000148
# 32  cellular_component        2.0       18172  0.000132   0.000088
# 33  molecular_function        0.0        8960  0.000000   0.000044
#
#     fold_enrichment
# 0          0.893573
# 1          0.952667
# 2          0.649847
# 3          0.503695
# 4          0.255097
# 5          1.427224
# 6          2.168940
# 7          1.540561
# 8          1.273602
# 9          0.514878
# 10         2.118211
# 11         2.382008
# 12         1.948024
# 13         0.562732
# 14         4.159016
# 15         0.338696
# 16         0.713348
# 17         0.912366
# 18         0.522796
# 19         0.561144
# 20         1.686512
# 21         0.250500
# 22         0.311343
# 23         1.028994
# 24         0.000000
# 25         2.810801
# 26         2.582890
# 27         0.053780
# 28         0.000000
# 29         0.000000
# 30         0.000000
# 31         0.446259
# 32         1.494078
# 33         0.000000

# %% [markdown]
# ## Q-value

# %%
def calculate_p_q_values(df_enrichment, unique_correspondence_up, unique_correspondence_all, file_name: str):
    p_values = []
    df_enrichment['counts_up'] = df_enrichment['counts_up'].astype(int) # float(0.0) to int(0)
    for index, row in df_enrichment.iterrows():
        if row['counts_up'] == 0:
            p_values.append(1.0)
        else:
            observed_up_correspondence = row['counts_up'] # create contingency table
            observed_all_correspondence = row['counts_all']
            observed_not_up_correspondence = observed_all_correspondence - observed_up_correspondence
            total_not_up_correspondence = unique_correspondence_all - unique_correspondence_up
            table = [
            [observed_up_correspondence, unique_correspondence_up - observed_up_correspondence],
            [observed_not_up_correspondence, total_not_up_correspondence - observed_not_up_correspondence]
            ]
            _, p_value = fisher_exact(table, alternative='greater') # Fisher's exact test
            p_values.append(p_value)
    
    _, q_values, _, _ = multipletests(p_values, 
                                      alpha=0.05, 
                                      method='fdr_bh') # Benjamini/Hochberg method
    
    df_enrichment['p_value'] = p_values
    df_enrichment['q_value'] = q_values

    results_directory = '../data/goslim_correspondence_q_values'
    os.makedirs(results_directory, exist_ok=True)
    df_enrichment['GOSlim'] = df_enrichment['GOSlim GOA Accession(s)'] + ": " + df_enrichment['GOSlim GOA Description']
    cols = df_enrichment.columns.tolist()
    cols = [cols[-1]] + cols[:-1]
    df_enrichment = df_enrichment[cols]
    df_enrichment.drop(['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], axis=1, inplace=True)
    df_enrichment = df_enrichment[df_enrichment['counts_up'] != 0]
    df_enrichment = df_enrichment.sort_values(by='fold_enrichment', ascending=False)
    df_enrichment.reset_index(drop=True, inplace=True)
    df_enrichment.to_csv(f'{results_directory}/{file_name}', sep='\t', index=False)

    return df_enrichment

goslim_correspondence_with_p_q = calculate_p_q_values(goslim_correspondence_enrichment,
                                                      unique_rows_up,
                                                      unique_rows_all, 
                                                      'goslim_correspondence_fold_enrichment_p_q.tsv')


display(goslim_correspondence_with_p_q)
# Out:
# /var/folders/7w/6nt3szxj44xdr5xs8y9g8lhw0000gn/T/ipykernel_84489/1993391490.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_enrichment.drop(['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], axis=1, inplace=True)
#                                                GOSlim       GOSlim_domain  \
# 0                   GO:0005783: endoplasmic reticulum  cellular_component
# 1   GO:0006091: generation of precursor metabolite...  biological_process
# 2                           GO:0008289: lipid binding  molecular_function
# 3        GO:0140110: transcription regulator activity  molecular_function
# 4                                 GO:0005829: cytosol  cellular_component
# 5                    GO:0005576: extracellular region  cellular_component
# 6                           GO:0005739: mitochondrion  cellular_component
# 7          GO:0005975: carbohydrate metabolic process  biological_process
# 8        GO:0048856: anatomical structure development  biological_process
# 9                              GO:0005777: peroxisome  cellular_component
# 10                     GO:0016787: hydrolase activity  molecular_function
# 11                            GO:0003677: DNA binding  molecular_function
# 12                                GO:0005773: vacuole  cellular_component
# 13                                GO:0005634: nucleus  cellular_component
# 14                GO:0006629: lipid metabolic process  biological_process
# 15                     GO:0003824: catalytic activity  molecular_function
# 16                            GO:0005654: nucleoplasm  cellular_component
# 17                        GO:0005886: plasma membrane  cellular_component
# 18                   GO:0005215: transporter activity  molecular_function
# 19                           GO:0005856: cytoskeleton  cellular_component
# 20                   GO:0030154: cell differentiation  biological_process
# 21                            GO:0003723: RNA binding  molecular_function
# 22           GO:0036211: protein modification process  biological_process
# 23         GO:0045182: translation regulator activity  molecular_function
# 24                        GO:0005794: Golgi apparatus  cellular_component
# 25                              GO:0005730: nucleolus  cellular_component
# 26                   GO:0016740: transferase activity  molecular_function
# 27           GO:0005198: structural molecule activity  molecular_function
# 28                               GO:0005840: ribosome  cellular_component
#
#     counts_up  counts_all  up_ratio  all_ratio  fold_enrichment  \
# 0         588     1919256  0.038756   0.009318         4.159016
# 1          55      265631  0.003625   0.001290         2.810801
# 2          49      257535  0.003230   0.001250         2.582890
# 3         396     2256826  0.026101   0.010957         2.382008
# 4        1248     7811118  0.082257   0.037925         2.168940
# 5         600     3845282  0.039547   0.018670         2.118211
# 6         280     1951236  0.018455   0.009474         1.948024
# 7          84      676139  0.005537   0.003283         1.686512
# 8         819     7216908  0.053981   0.035040         1.540561
# 9           2       18172  0.000132   0.000088         1.494078
# 10        912     8674587  0.060111   0.042117         1.427224
# 11        546     5819761  0.035987   0.028256         1.273602
# 12         32      422166  0.002109   0.002050         1.028994
# 13       3550    50586355  0.233984   0.245609         0.952667
# 14        102     1517670  0.006723   0.007369         0.912366
# 15       4136    62834292  0.272607   0.305076         0.893573
# 16         80     1522420  0.005273   0.007392         0.713348
# 17        676    14121523  0.044556   0.068563         0.649847
# 18         80     1929898  0.005273   0.009370         0.562732
# 19         30      725760  0.001977   0.003524         0.561144
# 20         49     1272360  0.003230   0.006178         0.522796
# 21        170     4482192  0.011205   0.021762         0.514878
# 22        418    11265607  0.027551   0.054697         0.503695
# 23          1       30420  0.000066   0.000148         0.446259
# 24         39     1563150  0.002571   0.007589         0.338696
# 25         13      566826  0.000857   0.002752         0.311343
# 26        204    10856023  0.013446   0.052709         0.255097
# 27         12      650310  0.000791   0.003157         0.250500
# 28          1      252420  0.000066   0.001226         0.053780
#
#           p_value        q_value
# 0   2.539107e-175  8.632965e-174
# 1    3.966800e-11   1.685890e-10
# 2    6.223319e-09   2.351032e-08
# 3    1.889550e-52   1.606117e-51
# 4   8.805413e-137  1.496920e-135
# 5    9.704598e-62   1.099854e-60
# 6    3.221263e-24   1.564614e-23
# 7    5.992973e-06   1.852373e-05
# 8    2.844564e-32   1.934304e-31
# 9    3.868057e-01   1.000000e+00
# 10   1.506186e-25   8.535052e-25
# 11   1.870129e-08   6.358439e-08
# 12   4.594621e-01   1.000000e+00
# 13   9.996001e-01   1.000000e+00
# 14   8.357564e-01   1.000000e+00
# 15   1.000000e+00   1.000000e+00
# 16   9.994202e-01   1.000000e+00
# 17   1.000000e+00   1.000000e+00
# 18   1.000000e+00   1.000000e+00
# 19   9.998176e-01   1.000000e+00
# 20   9.999999e-01   1.000000e+00
# 21   1.000000e+00   1.000000e+00
# 22   1.000000e+00   1.000000e+00
# 23   8.936585e-01   1.000000e+00
# 24   1.000000e+00   1.000000e+00
# 25   9.999999e-01   1.000000e+00
# 26   1.000000e+00   1.000000e+00
# 27   1.000000e+00   1.000000e+00
# 28   1.000000e+00   1.000000e+00

# %%
cc = goslim_correspondence_with_p_q.loc[goslim_correspondence_with_p_q['GOSlim_domain'] == 'cellular_component']
bp = goslim_correspondence_with_p_q.loc[goslim_correspondence_with_p_q['GOSlim_domain'] == 'biological_process']
mf = goslim_correspondence_with_p_q.loc[goslim_correspondence_with_p_q['GOSlim_domain'] == 'molecular_function']

cc.reset_index(drop=True, inplace=True)
bp.reset_index(drop=True, inplace=True)
mf.reset_index(drop=True, inplace=True)

display(cc, bp, mf)
# Out:
#                                GOSlim       GOSlim_domain  counts_up  \
# 0   GO:0005783: endoplasmic reticulum  cellular_component        588
# 1                 GO:0005829: cytosol  cellular_component       1248
# 2    GO:0005576: extracellular region  cellular_component        600
# 3           GO:0005739: mitochondrion  cellular_component        280
# 4              GO:0005777: peroxisome  cellular_component          2
# 5                 GO:0005773: vacuole  cellular_component         32
# 6                 GO:0005634: nucleus  cellular_component       3550
# 7             GO:0005654: nucleoplasm  cellular_component         80
# 8         GO:0005886: plasma membrane  cellular_component        676
# 9            GO:0005856: cytoskeleton  cellular_component         30
# 10        GO:0005794: Golgi apparatus  cellular_component         39
# 11              GO:0005730: nucleolus  cellular_component         13
# 12               GO:0005840: ribosome  cellular_component          1
#
#     counts_all  up_ratio  all_ratio  fold_enrichment        p_value  \
# 0      1919256  0.038756   0.009318         4.159016  2.539107e-175
# 1      7811118  0.082257   0.037925         2.168940  8.805413e-137
# 2      3845282  0.039547   0.018670         2.118211   9.704598e-62
# 3      1951236  0.018455   0.009474         1.948024   3.221263e-24
# 4        18172  0.000132   0.000088         1.494078   3.868057e-01
# 5       422166  0.002109   0.002050         1.028994   4.594621e-01
# 6     50586355  0.233984   0.245609         0.952667   9.996001e-01
# 7      1522420  0.005273   0.007392         0.713348   9.994202e-01
# 8     14121523  0.044556   0.068563         0.649847   1.000000e+00
# 9       725760  0.001977   0.003524         0.561144   9.998176e-01
# 10     1563150  0.002571   0.007589         0.338696   1.000000e+00
# 11      566826  0.000857   0.002752         0.311343   9.999999e-01
# 12      252420  0.000066   0.001226         0.053780   1.000000e+00
#
#           q_value
# 0   8.632965e-174
# 1   1.496920e-135
# 2    1.099854e-60
# 3    1.564614e-23
# 4    1.000000e+00
# 5    1.000000e+00
# 6    1.000000e+00
# 7    1.000000e+00
# 8    1.000000e+00
# 9    1.000000e+00
# 10   1.000000e+00
# 11   1.000000e+00
# 12   1.000000e+00
#                                               GOSlim       GOSlim_domain  \
# 0  GO:0006091: generation of precursor metabolite...  biological_process
# 1         GO:0005975: carbohydrate metabolic process  biological_process
# 2       GO:0048856: anatomical structure development  biological_process
# 3                GO:0006629: lipid metabolic process  biological_process
# 4                   GO:0030154: cell differentiation  biological_process
# 5           GO:0036211: protein modification process  biological_process
#
#    counts_up  counts_all  up_ratio  all_ratio  fold_enrichment       p_value  \
# 0         55      265631  0.003625   0.001290         2.810801  3.966800e-11
# 1         84      676139  0.005537   0.003283         1.686512  5.992973e-06
# 2        819     7216908  0.053981   0.035040         1.540561  2.844564e-32
# 3        102     1517670  0.006723   0.007369         0.912366  8.357564e-01
# 4         49     1272360  0.003230   0.006178         0.522796  9.999999e-01
# 5        418    11265607  0.027551   0.054697         0.503695  1.000000e+00
#
#         q_value
# 0  1.685890e-10
# 1  1.852373e-05
# 2  1.934304e-31
# 3  1.000000e+00
# 4  1.000000e+00
# 5  1.000000e+00
#                                          GOSlim       GOSlim_domain  \
# 0                     GO:0008289: lipid binding  molecular_function
# 1  GO:0140110: transcription regulator activity  molecular_function
# 2                GO:0016787: hydrolase activity  molecular_function
# 3                       GO:0003677: DNA binding  molecular_function
# 4                GO:0003824: catalytic activity  molecular_function
# 5              GO:0005215: transporter activity  molecular_function
# 6                       GO:0003723: RNA binding  molecular_function
# 7    GO:0045182: translation regulator activity  molecular_function
# 8              GO:0016740: transferase activity  molecular_function
# 9      GO:0005198: structural molecule activity  molecular_function
#
#    counts_up  counts_all  up_ratio  all_ratio  fold_enrichment       p_value  \
# 0         49      257535  0.003230   0.001250         2.582890  6.223319e-09
# 1        396     2256826  0.026101   0.010957         2.382008  1.889550e-52
# 2        912     8674587  0.060111   0.042117         1.427224  1.506186e-25
# 3        546     5819761  0.035987   0.028256         1.273602  1.870129e-08
# 4       4136    62834292  0.272607   0.305076         0.893573  1.000000e+00
# 5         80     1929898  0.005273   0.009370         0.562732  1.000000e+00
# 6        170     4482192  0.011205   0.021762         0.514878  1.000000e+00
# 7          1       30420  0.000066   0.000148         0.446259  8.936585e-01
# 8        204    10856023  0.013446   0.052709         0.255097  1.000000e+00
# 9         12      650310  0.000791   0.003157         0.250500  1.000000e+00
#
#         q_value
# 0  2.351032e-08
# 1  1.606117e-51
# 2  8.535052e-25
# 3  6.358439e-08
# 4  1.000000e+00
# 5  1.000000e+00
# 6  1.000000e+00
# 7  1.000000e+00
# 8  1.000000e+00
# 9  1.000000e+00

# %%
def plot_goslim_dotplot_with_lines(data, x_col, y_col, size_col, hue_col, ylabel_suffix='', figsize=(6, 9), palette="flare"):
    # add -log10(q-value) column
    data['-log10(q-value)'] = -np.log10(data[hue_col]).copy()
    # color palette
    color_palette = sns.color_palette(palette, as_cmap=True)
    norm = mcolors.Normalize(vmin=data['-log10(q-value)'].min(), vmax=data['-log10(q-value)'].max())
    
    # plotting
    plt.figure(figsize=figsize)
    ax = sns.scatterplot(
        data=data,
        x=x_col,
        y=y_col,
        size=size_col, 
        hue='-log10(q-value)',     
        palette=palette, 
        legend='brief'
    )
    # lines 
    for index, row in data.iterrows():
        plt.plot([0, row[x_col]], [row[y_col], row[y_col]], color=color_palette(norm(row['-log10(q-value)'])), lw=1)
    
    plt.grid(color='b', linestyle=':', linewidth=0.1)
    plt.xlabel('Fold Enrichment')
    ylabel_text = 'Common GOSlim Terms' + ylabel_suffix  if ylabel_suffix else ''
    plt.ylabel(ylabel_text)

    plt.show()

# %%
plot_goslim_dotplot_with_lines(goslim_correspondence_with_p_q.copy(), 'fold_enrichment', 'GOSlim', 'counts_up', 'q_value', ylabel_suffix='') # add copy() to avoid SettingWithCopyWarning
plot_goslim_dotplot_with_lines(cc.copy(), 'fold_enrichment', 'GOSlim', 'counts_up', 'q_value', ylabel_suffix=' (Cellular Component)', figsize=(5, 6))
plot_goslim_dotplot_with_lines(bp.copy(), 'fold_enrichment', 'GOSlim', 'counts_up', 'q_value', ylabel_suffix=' (Biological Process)', figsize=(5, 6))
plot_goslim_dotplot_with_lines(mf.copy(), 'fold_enrichment', 'GOSlim', 'counts_up', 'q_value', ylabel_suffix=' (Molecular Function)', figsize=(5, 6))
