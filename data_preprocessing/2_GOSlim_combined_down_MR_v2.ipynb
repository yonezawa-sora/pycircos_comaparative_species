# %% [markdown]
# ## Discription
#
# ### Background
# Circos plotの描画の処理内で行われている結合をこちらのファイルで行うことを目的に作成しました

# %%
import collections
import csv
import datetime
import os
import pandas as pd
import numpy as np
from collections import Counter

# %%
# output directory
organism1_vs_organism2 = "MR" # human vs rice
direction = "down"
now = datetime.datetime.now()
circos_dir = f'../data/circos_{direction}_{organism1_vs_organism2}_{now.strftime("%y%m")}'
no_annotation = f'../data/{circos_dir}/no_annotation_{direction}'
os.makedirs(circos_dir, exist_ok=True)
os.makedirs(no_annotation, exist_ok=True)

# %% [markdown]
# ## MOUSE_DOWN
#
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#
# 2. Extract GOSlim corresponding to the list of up-regulated genes

# %%
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#organism = "human" (H)
df_m_score = pd.read_csv(f"../data/mouse_annotation/mouse_position_{direction}.tsv", sep='\t')
df_m_score_subset = df_m_score[['Gene stable ID', # create a subset
                        'Chromosome/scaffold name', 
                        'start2 (bp)',
                        'end2 (bp)',
                        'HN-score(HN5)']].copy()
df_m_score_subset['Chromosome/scaffold name'] = 'M_' + df_m_score_subset['Chromosome/scaffold name'].astype(str)
df_m_score_subset['organism'] = 'mouse'# assign the tag

df_m_score_subset.to_csv(f"../data/{circos_dir}/mouse_position_{direction}_assign.tsv", sep='\t', index=False)

display(df_m_score_subset)
# Out:
#          Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 0    ENSMUSG00000039936                      M_4    149733625  149787028
# 1    ENSMUSG00000047671                      M_4    116983991  116985935
# 2    ENSMUSG00000051378                     M_11    102796355  102815950
# 3    ENSMUSG00000000440                      M_6    115337912  115467360
# 4    ENSMUSG00000046949                     M_13     34148670   34172426
# ..                  ...                      ...          ...        ...
# 254  ENSMUSG00000074141                      M_7     44465811   44490233
# 255  ENSMUSG00000025652                      M_9    108743687  108744631
# 256  ENSMUSG00000057072                      M_1    190768836  190775139
# 257  ENSMUSG00000030858                      M_7    130927673  130931245
# 258  ENSMUSG00000089798                      M_5    107682575  107699408
#
#      HN-score(HN5) organism
# 0              -15    mouse
# 1              -15    mouse
# 2              -15    mouse
# 3              -15    mouse
# 4              -15    mouse
# ..             ...      ...
# 254            -30    mouse
# 255            -31    mouse
# 256            -31    mouse
# 257            -33    mouse
# 258            -35    mouse
#
# [259 rows x 6 columns]

# %%
# 2. Extract GOSlim corresponding to the list of up-regulated genes
goslim_all_mouse = pd.read_csv('../data/biomart_goslim/biomart_mouse_goslim_R110_domain.tsv', sep='\t',
                               dtype={'Gene stable ID': 'object'}, 
                               low_memory=False)
columns_of_interest_mouse = ['Gene stable ID', 
                             'GOSlim GOA Accession(s)', 
                             'GOSlim GOA Description', 
                             'GOSlim_domain']
goslim_all_mouse_filtered = goslim_all_mouse[columns_of_interest_mouse]

extract_df_m_goslim = pd.merge(
    df_m_score_subset, 
    goslim_all_mouse_filtered, 
    on='Gene stable ID', 
    how='inner'
    )
extract_df_m_goslim = extract_df_m_goslim.drop_duplicates(subset=['Gene stable ID',
                                                                  'GOSlim GOA Accession(s)', 
                                                                  'GOSlim GOA Description'], keep='first').copy()

# Extract genes with no annotations
extract_df_m_goslim_with_indicator = pd.merge(
    df_m_score_subset, 
    goslim_all_mouse_filtered,
    left_on='Gene stable ID',
    right_on='Gene stable ID',
    how='left',
    indicator=True # add indicator column to show the difference
)

# extract_df_h_goslim_with_indicator
left_only_rows = extract_df_m_goslim_with_indicator[extract_df_m_goslim_with_indicator['_merge'] == 'left_only']

extract_df_m_goslim.to_csv(f"../data/{circos_dir}/mouse_goslim_{direction}.tsv", sep='\t', index=False)
left_only_rows.to_csv(f"../data/{no_annotation}/mouse_position_down_no_annotation.tsv", sep='\t', index=False)

display(goslim_all_mouse_filtered, extract_df_m_goslim, left_only_rows)
# Out:
#             Gene stable ID GOSlim GOA Accession(s)  \
# 0       ENSMUSG00000064336              GO:0060090
# 1       ENSMUSG00000064336              GO:0003723
# 2       ENSMUSG00000064336              GO:0043226
# 3       ENSMUSG00000064336              GO:0005739
# 4       ENSMUSG00000064337              GO:0005198
# ...                    ...                     ...
# 170875  ENSMUSG00000015335              GO:0036211
# 170876  ENSMUSG00000015335              GO:0023052
# 170877  ENSMUSG00000015335              GO:0048856
# 170878  ENSMUSG00000015335              GO:0034330
# 170879  ENSMUSG00000039686              GO:0030163
#
#                   GOSlim GOA Description       GOSlim_domain
# 0             molecular adaptor activity  molecular_function
# 1                            RNA binding  molecular_function
# 2                              organelle  cellular_component
# 3                          mitochondrion  cellular_component
# 4           structural molecule activity  molecular_function
# ...                                  ...                 ...
# 170875      protein modification process  biological_process
# 170876                         signaling  biological_process
# 170877  anatomical structure development  biological_process
# 170878        cell junction organization  biological_process
# 170879         protein catabolic process  biological_process
#
# [170880 rows x 4 columns]
#           Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 0     ENSMUSG00000039936                      M_4    149733625  149787028
# 1     ENSMUSG00000039936                      M_4    149733625  149787028
# 2     ENSMUSG00000039936                      M_4    149733625  149787028
# 3     ENSMUSG00000039936                      M_4    149733625  149787028
# 4     ENSMUSG00000039936                      M_4    149733625  149787028
# ...                  ...                      ...          ...        ...
# 1555  ENSMUSG00000089798                      M_5    107682575  107699408
# 1556  ENSMUSG00000089798                      M_5    107682575  107699408
# 1557  ENSMUSG00000089798                      M_5    107682575  107699408
# 1558  ENSMUSG00000089798                      M_5    107682575  107699408
# 1559  ENSMUSG00000089798                      M_5    107682575  107699408
#
#       HN-score(HN5) organism GOSlim GOA Accession(s)   GOSlim GOA Description  \
# 0               -15    mouse              GO:0003824       catalytic activity
# 1               -15    mouse              GO:0016740     transferase activity
# 2               -15    mouse              GO:0006629  lipid metabolic process
# 3               -15    mouse              GO:0023052                signaling
# 4               -15    mouse              GO:0048870            cell motility
# ...             ...      ...                     ...                      ...
# 1555            -35    mouse              GO:0022414     reproductive process
# 1556            -35    mouse              GO:0007059   chromosome segregation
# 1557            -35    mouse              GO:0043226                organelle
# 1558            -35    mouse              GO:0005694               chromosome
# 1559            -35    mouse              GO:0006310        DNA recombination
#
#            GOSlim_domain
# 0     molecular_function
# 1     molecular_function
# 2     biological_process
# 3     biological_process
# 4     biological_process
# ...                  ...
# 1555  biological_process
# 1556  biological_process
# 1557  cellular_component
# 1558  cellular_component
# 1559  biological_process
#
# [1560 rows x 9 columns]
#           Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 64    ENSMUSG00000057047                      M_2    173561208  173563882
# 76    ENSMUSG00000025257                      M_X    150787578  150799291
# 217   ENSMUSG00000072739                     M_14     19010486   19020394
# 258   ENSMUSG00000079580                     M_17     29744981   29771359
# 271   ENSMUSG00000095681                     M_14     17376458   17398785
# 272   ENSMUSG00000096372                     M_14     43268863   43273797
# 296   ENSMUSG00000090872                     M_14     17799888   17805576
# 306   ENSMUSG00000094021                     M_14     15423279   15433254
# 340   ENSMUSG00000097271                      M_5     33787269   33789436
# 373   ENSMUSG00000081906                     M_11     83535872   83536447
# 394   ENSMUSG00000096641                     M_13     50797268   50803963
# 395   ENSMUSG00000118559                     M_16     13572430   13576401
# 422   ENSMUSG00000105734                      M_3     95293772   95310152
# 426   ENSMUSG00000109510                      M_1     36569274   36578510
# 459   ENSMUSG00000093536                      M_7      6401714    6435092
# 472   ENSMUSG00000079409                     M_14     19273092   19281518
# 476   ENSMUSG00000039032                      M_6     30873916   30892508
# 686   ENSMUSG00000051736                     M_10     38994800   39009910
# 810   ENSMUSG00000092541                      M_9     88289485   88338669
# 819   ENSMUSG00000094378                      M_X    148567469  148609690
# 820   ENSMUSG00000028391                      M_4     62366890   62389133
# 846   ENSMUSG00000090273                     M_17     57077250   57079208
# 908   ENSMUSG00000034493                     M_11      3887541    3926778
# 1046  ENSMUSG00000095195                     M_14     18875552   18897878
# 1059  ENSMUSG00000105518                      M_3     90509211   90513192
# 1140  ENSMUSG00000043687                      M_8    121335341  121374371
# 1163  ENSMUSG00000033963                      M_6    113573722  113577676
# 1177  ENSMUSG00000095918                      M_5     11233039   11237777
# 1190  ENSMUSG00000092367                      M_7     27052074   27056844
# 1191  ENSMUSG00000044556                      M_4    115637031  115638215
# 1266  ENSMUSG00000078771                     M_11     79417386   79421435
# 1267  ENSMUSG00000107071                      M_6     39562687   39573529
# 1273  ENSMUSG00000090691                     M_14     15579556   15601271
# 1303  ENSMUSG00000094293                      M_4     42091207   42092094
# 1339  ENSMUSG00000089736                      M_8      4298214    4301423
# 1435  ENSMUSG00000023935                     M_17     45751504   45786341
# 1448  ENSMUSG00000048329                     M_11     68447012   68449071
# 1459  ENSMUSG00000029477                      M_5    123173832  123185079
# 1467  ENSMUSG00000079396                     M_14     16182523   16210026
# 1485  ENSMUSG00000076846                     M_14     53872286   53872856
# 1493  ENSMUSG00000093979                     M_14     19613868   19635203
# 1494  ENSMUSG00000090141                      M_X    100304982  100307598
# 1555  ENSMUSG00000045794                      M_2    181338586  181340235
# 1564  ENSMUSG00000029784                      M_6     30509848   30520253
# 1565  ENSMUSG00000091754                     M_14     15727441   15734088
# 1566  ENSMUSG00000044083                      M_2    153621851  153686671
# 1567  ENSMUSG00000094634                     M_14     16361351   16382477
# 1574  ENSMUSG00000098559                      M_X    138614430  138615230
# 1587  ENSMUSG00000008307                      M_5      3621566    3634356
# 1602  ENSMUSG00000025652                      M_9    108743687  108744631
# 1603  ENSMUSG00000057072                      M_1    190768836  190775139
#
#       HN-score(HN5) organism GOSlim GOA Accession(s) GOSlim GOA Description  \
# 64              -15    mouse                     NaN                    NaN
# 76              -15    mouse                     NaN                    NaN
# 217             -15    mouse                     NaN                    NaN
# 258             -15    mouse                     NaN                    NaN
# 271             -15    mouse                     NaN                    NaN
# 272             -15    mouse                     NaN                    NaN
# 296             -15    mouse                     NaN                    NaN
# 306             -15    mouse                     NaN                    NaN
# 340             -16    mouse                     NaN                    NaN
# 373             -16    mouse                     NaN                    NaN
# 394             -16    mouse                     NaN                    NaN
# 395             -16    mouse                     NaN                    NaN
# 422             -16    mouse                     NaN                    NaN
# 426             -16    mouse                     NaN                    NaN
# 459             -16    mouse                     NaN                    NaN
# 472             -16    mouse                     NaN                    NaN
# 476             -16    mouse                     NaN                    NaN
# 686             -16    mouse                     NaN                    NaN
# 810             -17    mouse                     NaN                    NaN
# 819             -17    mouse                     NaN                    NaN
# 820             -17    mouse                     NaN                    NaN
# 846             -17    mouse                     NaN                    NaN
# 908             -17    mouse                     NaN                    NaN
# 1046            -18    mouse                     NaN                    NaN
# 1059            -18    mouse                     NaN                    NaN
# 1140            -18    mouse                     NaN                    NaN
# 1163            -18    mouse                     NaN                    NaN
# 1177            -18    mouse                     NaN                    NaN
# 1190            -18    mouse                     NaN                    NaN
# 1191            -18    mouse                     NaN                    NaN
# 1266            -19    mouse                     NaN                    NaN
# 1267            -19    mouse                     NaN                    NaN
# 1273            -19    mouse                     NaN                    NaN
# 1303            -19    mouse                     NaN                    NaN
# 1339            -20    mouse                     NaN                    NaN
# 1435            -21    mouse                     NaN                    NaN
# 1448            -22    mouse                     NaN                    NaN
# 1459            -22    mouse                     NaN                    NaN
# 1467            -22    mouse                     NaN                    NaN
# 1485            -23    mouse                     NaN                    NaN
# 1493            -23    mouse                     NaN                    NaN
# 1494            -24    mouse                     NaN                    NaN
# 1555            -25    mouse                     NaN                    NaN
# 1564            -26    mouse                     NaN                    NaN
# 1565            -26    mouse                     NaN                    NaN
# 1566            -26    mouse                     NaN                    NaN
# 1567            -26    mouse                     NaN                    NaN
# 1574            -28    mouse                     NaN                    NaN
# 1587            -29    mouse                     NaN                    NaN
# 1602            -31    mouse                     NaN                    NaN
# 1603            -31    mouse                     NaN                    NaN
#
#      GOSlim_domain     _merge
# 64             NaN  left_only
# 76             NaN  left_only
# 217            NaN  left_only
# 258            NaN  left_only
# 271            NaN  left_only
# 272            NaN  left_only
# 296            NaN  left_only
# 306            NaN  left_only
# 340            NaN  left_only
# 373            NaN  left_only
# 394            NaN  left_only
# 395            NaN  left_only
# 422            NaN  left_only
# 426            NaN  left_only
# 459            NaN  left_only
# 472            NaN  left_only
# 476            NaN  left_only
# 686            NaN  left_only
# 810            NaN  left_only
# 819            NaN  left_only
# 820            NaN  left_only
# 846            NaN  left_only
# 908            NaN  left_only
# 1046           NaN  left_only
# 1059           NaN  left_only
# 1140           NaN  left_only
# 1163           NaN  left_only
# 1177           NaN  left_only
# 1190           NaN  left_only
# 1191           NaN  left_only
# 1266           NaN  left_only
# 1267           NaN  left_only
# 1273           NaN  left_only
# 1303           NaN  left_only
# 1339           NaN  left_only
# 1435           NaN  left_only
# 1448           NaN  left_only
# 1459           NaN  left_only
# 1467           NaN  left_only
# 1485           NaN  left_only
# 1493           NaN  left_only
# 1494           NaN  left_only
# 1555           NaN  left_only
# 1564           NaN  left_only
# 1565           NaN  left_only
# 1566           NaN  left_only
# 1567           NaN  left_only
# 1574           NaN  left_only
# 1587           NaN  left_only
# 1602           NaN  left_only
# 1603           NaN  left_only

# %% [markdown]
# ## RICE_down
#
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#
# 2. Extract GOSlim corresponding to the list of up-regulated genes

# %%
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
df_r_score = pd.read_csv(f'../data/rice_annotation/rice_position_{direction}.tsv', sep='\t')
df_r_score_subset = df_r_score[['Gene stable ID', # create a subset
                        'Chromosome/scaffold name', 
                        'start1 (bp)',
                        'end1 (bp)',
                        'HN-score(HN5)']].copy()
df_r_score_subset['Chromosome/scaffold name'] = 'R_' + df_r_score_subset['Chromosome/scaffold name'].astype(str)
df_r_score_subset['organism'] = 'rice'# assign the tag

df_r_score_subset.to_csv(f"../data/{circos_dir}/rice_position_{direction}_assign.tsv", sep='\t', index=False)

display(df_r_score_subset)
# Out:
#     Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0     Os01g0136300                      R_1      1955181    1955914
# 1     Os05g0588225                      R_5     29307170   29307793
# 2     Os03g0358800                      R_3     13915940   13917546
# 3     Os06g0157900                      R_6      2947702    2948085
# 4     Os11g0439600                     R_11     14390405   14398122
# ..             ...                      ...          ...        ...
# 379   Os01g0952800                      R_1     41971444   41978093
# 380   Os07g0142100                      R_7      2175193    2175719
# 381   Os03g0307200                      R_3     10926469   10927729
# 382   Os07g0142200                      R_7      2176824    2177640
# 383   Os03g0307300                      R_3     10929507   10930895
#
#      HN-score(HN5) organism
# 0              -40     rice
# 1              -40     rice
# 2              -40     rice
# 3              -40     rice
# 4              -40     rice
# ..             ...      ...
# 379           -173     rice
# 380           -178     rice
# 381           -182     rice
# 382           -189     rice
# 383           -196     rice
#
# [384 rows x 6 columns]

# %%
# 2. Extract GOSlim corresponding to the list of up-regulated genes
goslim_all_rice = pd.read_csv('../data/biomart_goslim/biomart_rice_goslim_R56_domain.tsv', sep='\t',
                               dtype={'Gene stable ID': 'object'}, 
                               low_memory=False)
columns_of_interest_rice = ['Gene stable ID',
                            'GOSlim GOA Accession(s)', 
                            'GOSlim GOA Description', 
                            'GOSlim_domain']
goslim_all_rice_filtered = goslim_all_rice[columns_of_interest_rice]

extract_df_r_goslim = pd.merge(
    df_r_score_subset, 
    goslim_all_rice_filtered, 
    on='Gene stable ID', 
    how='inner'
    )

extract_df_r_goslim = extract_df_r_goslim.drop_duplicates(subset=['Gene stable ID',
                                                                    'GOSlim GOA Accession(s)', 
                                                                    'GOSlim GOA Description'], keep='first').copy()

# Extract genes with no annotations
extract_df_r_goslim_with_indicator = pd.merge(
    df_r_score_subset, 
    goslim_all_rice_filtered,
    left_on='Gene stable ID',
    right_on='Gene stable ID',
    how='left',
    indicator=True # add indicator column to show the difference
)

# extract_df_r_goslim_with_indicator
left_only_rows = extract_df_r_goslim_with_indicator[extract_df_r_goslim_with_indicator['_merge'] == 'left_only']

extract_df_r_goslim.to_csv(f"../data/{circos_dir}/rice_goslim_{direction}.tsv", sep='\t', index=False)
left_only_rows.to_csv(f"../data/{no_annotation}/rice_position_{direction}_no_annotation.tsv", sep='\t', index=False)

display(goslim_all_rice_filtered, extract_df_r_goslim, left_only_rows)
# Out:
#        Gene stable ID GOSlim GOA Accession(s)        GOSlim GOA Description  \
# 0        Os01g0100100              GO:0006810                     transport
# 1        Os01g0100100              GO:0008150            biological_process
# 2        Os01g0100100              GO:0009987              cellular process
# 3        Os01g0100100              GO:0003674            molecular_function
# 4        Os01g0100100              GO:0030234     enzyme regulator activity
# ...               ...                     ...                           ...
# 219494     gene-rps19              GO:0003674            molecular_function
# 219495     gene-rps19              GO:0005198  structural molecule activity
# 219496     gene-rps19              GO:0005488                       binding
# 219497     gene-rps19              GO:0003723                   RNA binding
# 219498     gene-rps19              GO:0003676          nucleic acid binding
#
#              GOSlim_domain
# 0       biological_process
# 1       biological_process
# 2       biological_process
# 3       molecular_function
# 4       molecular_function
# ...                    ...
# 219494  molecular_function
# 219495  molecular_function
# 219496  molecular_function
# 219497  molecular_function
# 219498  molecular_function
#
# [219499 rows x 4 columns]
#      Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0      Os03g0358800                      R_3     13915940   13917546
# 1      Os03g0358800                      R_3     13915940   13917546
# 2      Os03g0358800                      R_3     13915940   13917546
# 3      Os03g0358800                      R_3     13915940   13917546
# 4      Os03g0358800                      R_3     13915940   13917546
# ...             ...                      ...          ...        ...
# 2028   Os03g0307300                      R_3     10929507   10930895
# 2029   Os03g0307300                      R_3     10929507   10930895
# 2030   Os03g0307300                      R_3     10929507   10930895
# 2031   Os03g0307300                      R_3     10929507   10930895
# 2032   Os03g0307300                      R_3     10929507   10930895
#
#       HN-score(HN5) organism GOSlim GOA Accession(s)  \
# 0               -40     rice              GO:0005575
# 1               -40     rice              GO:0005622
# 2               -40     rice              GO:0003674
# 3               -40     rice              GO:0003824
# 4               -40     rice              GO:0016740
# ...             ...      ...                     ...
# 2028           -196     rice              GO:0016740
# 2029           -196     rice              GO:0008150
# 2030           -196     rice              GO:0009987
# 2031           -196     rice              GO:0008152
# 2032           -196     rice              GO:0009058
#
#                   GOSlim GOA Description       GOSlim_domain
# 0                     cellular_component  cellular_component
# 1     intracellular anatomical structure  cellular_component
# 2                     molecular_function  molecular_function
# 3                     catalytic activity  molecular_function
# 4                   transferase activity  molecular_function
# ...                                  ...                 ...
# 2028                transferase activity  molecular_function
# 2029                  biological_process  biological_process
# 2030                    cellular process  biological_process
# 2031                   metabolic process  biological_process
# 2032                biosynthetic process  biological_process
#
# [2033 rows x 9 columns]
#      Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0      Os01g0136300                      R_1      1955181    1955914
# 1      Os05g0588225                      R_5     29307170   29307793
# 24     Os07g0600200                      R_7     24487821   24488449
# 25     Os08g0178650                      R_8      4597056    4597381
# 32     Os02g0565150                      R_2     21457944   21458344
# ...             ...                      ...          ...        ...
# 2124   Os01g0647200                      R_1     26086062   26088337
# 2132   Os02g0594166                      R_2     23008659   23011091
# 2133   Os01g0608101                      R_1     24004176   24006793
# 2157   Os07g0142100                      R_7      2175193    2175719
# 2165   Os07g0142200                      R_7      2176824    2177640
#
#       HN-score(HN5) organism GOSlim GOA Accession(s) GOSlim GOA Description  \
# 0               -40     rice                     NaN                    NaN
# 1               -40     rice                     NaN                    NaN
# 24              -40     rice                     NaN                    NaN
# 25              -40     rice                     NaN                    NaN
# 32              -40     rice                     NaN                    NaN
# ...             ...      ...                     ...                    ...
# 2124           -165     rice                     NaN                    NaN
# 2132           -170     rice                     NaN                    NaN
# 2133           -171     rice                     NaN                    NaN
# 2157           -178     rice                     NaN                    NaN
# 2165           -189     rice                     NaN                    NaN
#
#      GOSlim_domain     _merge
# 0              NaN  left_only
# 1              NaN  left_only
# 24             NaN  left_only
# 25             NaN  left_only
# 32             NaN  left_only
# ...            ...        ...
# 2124           NaN  left_only
# 2132           NaN  left_only
# 2133           NaN  left_only
# 2157           NaN  left_only
# 2165           NaN  left_only
#
# [140 rows x 10 columns]

# %% [markdown]
# ## COMBINED_UP( MOUSE_DOWN + RICE_DOWN )
#
# 1. chromosome position + gene position + HN-score
#
# 2. GOslim terms corresponding to the list of up-regulated genes

# %%
# 1. chromosome position + gene position + HN-score
combined_df_score = pd.concat([df_m_score_subset, 
                               df_r_score_subset])
combined_df_score.reset_index(drop=True, inplace=True)
combined_df_score['Gene start (bp)'] = combined_df_score['start1 (bp)'].combine_first(combined_df_score['start2 (bp)'])
combined_df_score['Gene end (bp)'] = combined_df_score['end1 (bp)'].combine_first(combined_df_score['end2 (bp)'])
combined_df_score.drop(['start1 (bp)', 'start2 (bp)', 'end1 (bp)', 'end2 (bp)'], axis=1, inplace=True)

combined_df_score.to_csv(f"../data/{circos_dir}/combined_position_{direction}.tsv", sep='\t', index=False)

display(combined_df_score)
# Out:
#          Gene stable ID Chromosome/scaffold name  HN-score(HN5) organism  \
# 0    ENSMUSG00000039936                      M_4            -15    mouse
# 1    ENSMUSG00000047671                      M_4            -15    mouse
# 2    ENSMUSG00000051378                     M_11            -15    mouse
# 3    ENSMUSG00000000440                      M_6            -15    mouse
# 4    ENSMUSG00000046949                     M_13            -15    mouse
# ..                  ...                      ...            ...      ...
# 638        Os01g0952800                      R_1           -173     rice
# 639        Os07g0142100                      R_7           -178     rice
# 640        Os03g0307200                      R_3           -182     rice
# 641        Os07g0142200                      R_7           -189     rice
# 642        Os03g0307300                      R_3           -196     rice
#
#      Gene start (bp)  Gene end (bp)
# 0        149733625.0    149787028.0
# 1        116983991.0    116985935.0
# 2        102796355.0    102815950.0
# 3        115337912.0    115467360.0
# 4         34148670.0     34172426.0
# ..               ...            ...
# 638       41971444.0     41978093.0
# 639        2175193.0      2175719.0
# 640       10926469.0     10927729.0
# 641        2176824.0      2177640.0
# 642       10929507.0     10930895.0
#
# [643 rows x 6 columns]

# %%
merged_df_goslim = pd.merge(
    extract_df_m_goslim, 
    extract_df_r_goslim, 
    left_on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'],
    right_on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'],
    how='inner',
    suffixes=('_mouse', '_rice')
)

merged_df_goslim = merged_df_goslim[['GOSlim GOA Accession(s)',
                                     'GOSlim GOA Description',
                                     'GOSlim_domain',
                                     'Gene stable ID_rice',
                                     'Gene stable ID_mouse',
                                     'Chromosome/scaffold name_rice',
                                     'start1 (bp)',
                                     'end1 (bp)',
                                     'Chromosome/scaffold name_mouse',
                                     'start2 (bp)',
                                     'end2 (bp)',
                                     'HN-score(HN5)_rice',
                                     'HN-score(HN5)_mouse']]

# Remove duplicate rows based on specific columns
merged_df_goslim.drop_duplicates(inplace=True)

display(merged_df_goslim)
# Out:
#       GOSlim GOA Accession(s)            GOSlim GOA Description  \
# 0                  GO:0003824                catalytic activity
# 1                  GO:0003824                catalytic activity
# 2                  GO:0003824                catalytic activity
# 3                  GO:0003824                catalytic activity
# 4                  GO:0003824                catalytic activity
# ...                       ...                               ...
# 16810              GO:0030312  external encapsulating structure
# 16811              GO:0030312  external encapsulating structure
# 16812              GO:0030312  external encapsulating structure
# 16813              GO:0030312  external encapsulating structure
# 16814              GO:0030312  external encapsulating structure
#
#             GOSlim_domain Gene stable ID_rice Gene stable ID_mouse  \
# 0      molecular_function        Os03g0358800   ENSMUSG00000039936
# 1      molecular_function        Os11g0439600   ENSMUSG00000039936
# 2      molecular_function        Os01g0891100   ENSMUSG00000039936
# 3      molecular_function        Os05g0458600   ENSMUSG00000039936
# 4      molecular_function        Os02g0706900   ENSMUSG00000039936
# ...                   ...                 ...                  ...
# 16810  cellular_component        Os02g0783000   ENSMUSG00000021624
# 16811  cellular_component        Os06g0193200   ENSMUSG00000021624
# 16812  cellular_component        Os09g0472900   ENSMUSG00000021624
# 16813  cellular_component        Os01g0284500   ENSMUSG00000021624
# 16814  cellular_component        Os03g0651800   ENSMUSG00000021624
#
#       Chromosome/scaffold name_rice  start1 (bp)  end1 (bp)  \
# 0                               R_3     13915940   13917546
# 1                              R_11     14390405   14398122
# 2                               R_1     38750313   38750768
# 3                               R_5     22533536   22536087
# 4                               R_2     29224218   29226240
# ...                             ...          ...        ...
# 16810                           R_2     33221378   33223595
# 16811                           R_6      4700512    4703042
# 16812                           R_9     18067436   18068411
# 16813                           R_1     10167946   10168997
# 16814                           R_3     25315697   25317065
#
#       Chromosome/scaffold name_mouse  start2 (bp)  end2 (bp)  \
# 0                                M_4    149733625  149787028
# 1                                M_4    149733625  149787028
# 2                                M_4    149733625  149787028
# 3                                M_4    149733625  149787028
# 4                                M_4    149733625  149787028
# ...                              ...          ...        ...
# 16810                           M_13    102830066  102876137
# 16811                           M_13    102830066  102876137
# 16812                           M_13    102830066  102876137
# 16813                           M_13    102830066  102876137
# 16814                           M_13    102830066  102876137
#
#        HN-score(HN5)_rice  HN-score(HN5)_mouse
# 0                     -40                  -15
# 1                     -40                  -15
# 2                     -40                  -15
# 3                     -40                  -15
# 4                     -40                  -15
# ...                   ...                  ...
# 16810                 -45                  -16
# 16811                 -45                  -16
# 16812                 -47                  -16
# 16813                 -52                  -16
# 16814                 -68                  -16
#
# [16815 rows x 13 columns]

# %%
# for debugging purpose
unique_accessions_r = set(extract_df_r_goslim['GOSlim GOA Accession(s)'].unique())
unique_accessions_m = set(extract_df_m_goslim['GOSlim GOA Accession(s)'].unique())
common_accessions = unique_accessions_r.intersection(unique_accessions_m)
unique_accessions_merged = set(merged_df_goslim['GOSlim GOA Accession(s)'].unique())
missing_accessions = common_accessions.difference(unique_accessions_merged)
duplicates = merged_df_goslim.duplicated(subset=['GOSlim GOA Accession(s)', 'Gene stable ID_rice', 'Gene stable ID_mouse'], keep=False)
unique_combinations = not duplicates.any()
print(f"Number of common accessions: {len(common_accessions)}")
print(f"Number of missing accessions: {len(missing_accessions)}")
print(f"Missing accessions: {missing_accessions}")
print(f"各'Gene stable ID_rice'と'Gene stable ID_mouse'の組み合わせはユニークですか？: {unique_combinations}")

#Count the occurrences of each 'GOSlim GOA Accession(s)'
accession_counter = Counter(merged_df_goslim['GOSlim GOA Accession(s)'])

#Sort the DataFrame based on the counts
merged_df_goslim['count'] = merged_df_goslim['GOSlim GOA Accession(s)'].map(accession_counter)
merged_df_goslim_sorted = merged_df_goslim.sort_values('count', ascending=False).drop('count', axis=1)
merged_df_goslim_sorted.reset_index(drop=True, inplace=True)
merged_df_goslim_sorted.to_csv(f"../data/{circos_dir}/combined_goslim_{direction}.tsv", sep='\t', index=False)

display(merged_df_goslim_sorted)
# Out:
# Number of common accessions: 26
# Number of missing accessions: 0
# Missing accessions: set()
# 各'Gene stable ID_rice'と'Gene stable ID_mouse'の組み合わせはユニークですか？: True
#       GOSlim GOA Accession(s) GOSlim GOA Description       GOSlim_domain  \
# 0                  GO:0003824     catalytic activity  molecular_function
# 1                  GO:0003824     catalytic activity  molecular_function
# 2                  GO:0003824     catalytic activity  molecular_function
# 3                  GO:0003824     catalytic activity  molecular_function
# 4                  GO:0003824     catalytic activity  molecular_function
# ...                       ...                    ...                 ...
# 16810              GO:0005764               lysosome  cellular_component
# 16811              GO:0005764               lysosome  cellular_component
# 16812              GO:0005764               lysosome  cellular_component
# 16813              GO:0005635       nuclear envelope  cellular_component
# 16814              GO:0005635       nuclear envelope  cellular_component
#
#       Gene stable ID_rice Gene stable ID_mouse Chromosome/scaffold name_rice  \
# 0            Os03g0358800   ENSMUSG00000039936                           R_3
# 1            Os10g0527601   ENSMUSG00000071724                          R_10
# 2            Os04g0493400   ENSMUSG00000071724                           R_4
# 3            Os01g0591300   ENSMUSG00000071724                           R_1
# 4            Os02g0240300   ENSMUSG00000071724                           R_2
# ...                   ...                  ...                           ...
# 16810        Os02g0715000   ENSMUSG00000020323                           R_2
# 16811        Os01g0613500   ENSMUSG00000020323                           R_1
# 16812        Os01g0971400   ENSMUSG00000020323                           R_1
# 16813        Os12g0236100   ENSMUSG00000037997                          R_12
# 16814        Os12g0236100   ENSMUSG00000018362                          R_12
#
#        start1 (bp)  end1 (bp) Chromosome/scaffold name_mouse  start2 (bp)  \
# 0         13915940   13917546                            M_4    149733625
# 1         20493427   20494200                           M_15     76178548
# 2         24687753   24689297                           M_15     76178548
# 3         23113647   23120516                           M_15     76178548
# 4          7948543    7949997                           M_15     76178548
# ...            ...        ...                            ...          ...
# 16810     29667743   29669572                           M_10     79617308
# 16811     24343518   24345172                           M_10     79617308
# 16812     42855657   42857462                           M_10     79617308
# 16813      7441389    7446142                            M_6    127423803
# 16814      7441389    7446142                           M_11    106879455
#
#        end2 (bp)  HN-score(HN5)_rice  HN-score(HN5)_mouse
# 0      149787028                 -40                  -15
# 1       76181096                 -55                  -17
# 2       76181096                 -61                  -17
# 3       76181096                 -60                  -17
# 4       76181096                 -60                  -17
# ...          ...                 ...                  ...
# 16810   79626795                 -41                  -17
# 16811   79626795                 -75                  -17
# 16812   79626795                 -41                  -17
# 16813  127471224                 -81                  -16
# 16814  106890367                 -81                  -17
#
# [16815 rows x 13 columns]

# %% [markdown]
# ## Merge GOslim terms and line enrichment results

# %%
enrichment = pd.read_csv(f'../data/line_enrichment_{direction}_MR_2312/goslim_correspondence_q_values_{direction}_MR/goslim_correspondence_fold_enrichment_p_q_{direction}.tsv', sep='\t')

merged_df_goslim_sorted["GOSlim"] = merged_df_goslim_sorted['GOSlim GOA Accession(s)'] + ": " + merged_df_goslim_sorted['GOSlim GOA Description']

merged_df_goslim_sorted = merged_df_goslim_sorted[['GOSlim',
                                                    'GOSlim GOA Accession(s)',
                                                    'GOSlim GOA Description',
                                                    'GOSlim_domain',
                                                    'Gene stable ID_rice',
                                                    'Gene stable ID_mouse',
                                                    'Chromosome/scaffold name_rice',
                                                    'start1 (bp)',
                                                    'end1 (bp)',
                                                    'Chromosome/scaffold name_mouse',
                                                    'start2 (bp)',
                                                    'end2 (bp)',
                                                    'HN-score(HN5)_rice',
                                                    'HN-score(HN5)_mouse']]


merged_df_goslim_enrichment = pd.merge(
    merged_df_goslim_sorted,
    enrichment[['GOSlim', f'counts_{direction}', 'fold_enrichment', 'p_value', 'q_value']],
    on='GOSlim',
    how='left'
)
merged_df_goslim_enrichment.sort_values('fold_enrichment', ascending=False, inplace=True)
merged_df_goslim_enrichment.reset_index(drop=True, inplace=True)
merged_df_goslim_enrichment.to_csv(f"../data/{circos_dir}/combined_goslim_enrichment_{direction}.tsv", sep='\t', index=False)

display(enrichment, merged_df_goslim_sorted, merged_df_goslim_enrichment)
# Out:
#                                                GOSlim GOSlim GOA Accession(s)  \
# 0                    GO:0005576: extracellular region              GO:0005576
# 1                                GO:0005764: lysosome              GO:0005764
# 2                           GO:0008289: lipid binding              GO:0008289
# 3                    GO:0005215: transporter activity              GO:0005215
# 4          GO:0005975: carbohydrate metabolic process              GO:0005975
# 5                             GO:0003677: DNA binding              GO:0003677
# 6                      GO:0003824: catalytic activity              GO:0003824
# 7                      GO:0016787: hydrolase activity              GO:0016787
# 8   GO:0006091: generation of precursor metabolite...              GO:0006091
# 9                 GO:0006629: lipid metabolic process              GO:0006629
# 10       GO:0140110: transcription regulator activity              GO:0140110
# 11                   GO:0016740: transferase activity              GO:0016740
# 12                        GO:0005886: plasma membrane              GO:0005886
# 13       GO:0048856: anatomical structure development              GO:0048856
# 14       GO:0030312: external encapsulating structure              GO:0030312
# 15                                GO:0005773: vacuole              GO:0005773
# 16                   GO:0030154: cell differentiation              GO:0030154
# 17                                GO:0005634: nucleus              GO:0005634
# 18                           GO:0005856: cytoskeleton              GO:0005856
# 19                                GO:0005829: cytosol              GO:0005829
# 20                       GO:0005635: nuclear envelope              GO:0005635
# 21           GO:0036211: protein modification process              GO:0036211
# 22           GO:0005198: structural molecule activity              GO:0005198
# 23                          GO:0005739: mitochondrion              GO:0005739
# 24                        GO:0005794: Golgi apparatus              GO:0005794
# 25                  GO:0005783: endoplasmic reticulum              GO:0005783
#
#                             GOSlim GOA Description       GOSlim_domain  \
# 0                             extracellular region  cellular_component
# 1                                         lysosome  cellular_component
# 2                                    lipid binding  molecular_function
# 3                             transporter activity  molecular_function
# 4                   carbohydrate metabolic process  biological_process
# 5                                      DNA binding  molecular_function
# 6                               catalytic activity  molecular_function
# 7                               hydrolase activity  molecular_function
# 8   generation of precursor metabolites and energy  biological_process
# 9                          lipid metabolic process  biological_process
# 10                transcription regulator activity  molecular_function
# 11                            transferase activity  molecular_function
# 12                                 plasma membrane  cellular_component
# 13                anatomical structure development  biological_process
# 14                external encapsulating structure  cellular_component
# 15                                         vacuole  cellular_component
# 16                            cell differentiation  biological_process
# 17                                         nucleus  cellular_component
# 18                                    cytoskeleton  cellular_component
# 19                                         cytosol  cellular_component
# 20                                nuclear envelope  cellular_component
# 21                    protein modification process  biological_process
# 22                    structural molecule activity  molecular_function
# 23                                   mitochondrion  cellular_component
# 24                                 Golgi apparatus  cellular_component
# 25                           endoplasmic reticulum  cellular_component
#
#     counts_down  counts_all  down_ratio  all_ratio  fold_enrichment  \
# 0           841     2069023    0.050015   0.011300         4.426216
# 1             6       27234    0.000357   0.000149         2.399063
# 2            56      257535    0.003330   0.001406         2.367847
# 3           308     1687420    0.018317   0.009216         1.987602
# 4           102      655182    0.006066   0.003578         1.695275
# 5           736     4990802    0.043770   0.027257         1.605866
# 6          7482    56414781    0.444960   0.308102         1.444198
# 7           984     7777545    0.058519   0.042476         1.377699
# 8            27      243045    0.001606   0.001327         1.209704
# 9           153     1429560    0.009099   0.007807         1.165443
# 10          190     1948470    0.011299   0.010641         1.061847
# 11          840     9615454    0.049955   0.052514         0.951287
# 12         1110    13465191    0.066012   0.073538         0.897661
# 13          530     7211128    0.031519   0.039383         0.800340
# 14           12      174151    0.000714   0.000951         0.750338
# 15           18      270510    0.001070   0.001477         0.724588
# 16           84     1302168    0.004996   0.007112         0.702448
# 17         2520    46028115    0.149866   0.251376         0.596183
# 18           32      661920    0.001903   0.003615         0.526437
# 19          261     5489678    0.015522   0.029981         0.517721
# 20            2       45942    0.000119   0.000251         0.474048
# 21          450    10391837    0.026762   0.056754         0.471544
# 22           20      488130    0.001189   0.002666         0.446166
# 23           31     2075124    0.001844   0.011333         0.162675
# 24           12     1297950    0.000714   0.007089         0.100676
# 25            8     1609508    0.000476   0.008790         0.054125
#
#           p_value        q_value
# 0   1.028298e-268  1.748106e-267
# 1    4.206618e-02   1.589167e-01
# 2    1.063385e-08   6.025850e-08
# 3    8.451898e-28   7.184113e-27
# 4    5.390000e-07   2.618000e-06
# 5    5.572734e-34   6.315766e-33
# 6   1.324139e-303  4.502072e-302
# 7    7.895711e-23   5.369083e-22
# 8    1.856097e-01   6.310729e-01
# 9    3.387015e-02   1.439482e-01
# 10   2.122061e-01   6.559098e-01
# 11   9.346300e-01   1.000000e+00
# 12   9.999309e-01   1.000000e+00
# 13   1.000000e+00   1.000000e+00
# 14   8.727785e-01   1.000000e+00
# 15   9.359822e-01   1.000000e+00
# 16   9.997548e-01   1.000000e+00
# 17   1.000000e+00   1.000000e+00
# 18   9.999815e-01   1.000000e+00
# 19   1.000000e+00   1.000000e+00
# 20   9.232444e-01   1.000000e+00
# 21   1.000000e+00   1.000000e+00
# 22   9.999889e-01   1.000000e+00
# 23   1.000000e+00   1.000000e+00
# 24   1.000000e+00   1.000000e+00
# 25   1.000000e+00   1.000000e+00
#                                GOSlim GOSlim GOA Accession(s)  \
# 0      GO:0003824: catalytic activity              GO:0003824
# 1      GO:0003824: catalytic activity              GO:0003824
# 2      GO:0003824: catalytic activity              GO:0003824
# 3      GO:0003824: catalytic activity              GO:0003824
# 4      GO:0003824: catalytic activity              GO:0003824
# ...                               ...                     ...
# 16810            GO:0005764: lysosome              GO:0005764
# 16811            GO:0005764: lysosome              GO:0005764
# 16812            GO:0005764: lysosome              GO:0005764
# 16813    GO:0005635: nuclear envelope              GO:0005635
# 16814    GO:0005635: nuclear envelope              GO:0005635
#
#       GOSlim GOA Description       GOSlim_domain Gene stable ID_rice  \
# 0         catalytic activity  molecular_function        Os03g0358800
# 1         catalytic activity  molecular_function        Os10g0527601
# 2         catalytic activity  molecular_function        Os04g0493400
# 3         catalytic activity  molecular_function        Os01g0591300
# 4         catalytic activity  molecular_function        Os02g0240300
# ...                      ...                 ...                 ...
# 16810               lysosome  cellular_component        Os02g0715000
# 16811               lysosome  cellular_component        Os01g0613500
# 16812               lysosome  cellular_component        Os01g0971400
# 16813       nuclear envelope  cellular_component        Os12g0236100
# 16814       nuclear envelope  cellular_component        Os12g0236100
#
#       Gene stable ID_mouse Chromosome/scaffold name_rice  start1 (bp)  \
# 0       ENSMUSG00000039936                           R_3     13915940
# 1       ENSMUSG00000071724                          R_10     20493427
# 2       ENSMUSG00000071724                           R_4     24687753
# 3       ENSMUSG00000071724                           R_1     23113647
# 4       ENSMUSG00000071724                           R_2      7948543
# ...                    ...                           ...          ...
# 16810   ENSMUSG00000020323                           R_2     29667743
# 16811   ENSMUSG00000020323                           R_1     24343518
# 16812   ENSMUSG00000020323                           R_1     42855657
# 16813   ENSMUSG00000037997                          R_12      7441389
# 16814   ENSMUSG00000018362                          R_12      7441389
#
#        end1 (bp) Chromosome/scaffold name_mouse  start2 (bp)  end2 (bp)  \
# 0       13917546                            M_4    149733625  149787028
# 1       20494200                           M_15     76178548   76181096
# 2       24689297                           M_15     76178548   76181096
# 3       23120516                           M_15     76178548   76181096
# 4        7949997                           M_15     76178548   76181096
# ...          ...                            ...          ...        ...
# 16810   29669572                           M_10     79617308   79626795
# 16811   24345172                           M_10     79617308   79626795
# 16812   42857462                           M_10     79617308   79626795
# 16813    7446142                            M_6    127423803  127471224
# 16814    7446142                           M_11    106879455  106890367
#
#        HN-score(HN5)_rice  HN-score(HN5)_mouse
# 0                     -40                  -15
# 1                     -55                  -17
# 2                     -61                  -17
# 3                     -60                  -17
# 4                     -60                  -17
# ...                   ...                  ...
# 16810                 -41                  -17
# 16811                 -75                  -17
# 16812                 -41                  -17
# 16813                 -81                  -16
# 16814                 -81                  -17
#
# [16815 rows x 14 columns]
#                                   GOSlim GOSlim GOA Accession(s)  \
# 0       GO:0005576: extracellular region              GO:0005576
# 1       GO:0005576: extracellular region              GO:0005576
# 2       GO:0005576: extracellular region              GO:0005576
# 3       GO:0005576: extracellular region              GO:0005576
# 4       GO:0005576: extracellular region              GO:0005576
# ...                                  ...                     ...
# 16810  GO:0005783: endoplasmic reticulum              GO:0005783
# 16811  GO:0005783: endoplasmic reticulum              GO:0005783
# 16812  GO:0005783: endoplasmic reticulum              GO:0005783
# 16813  GO:0005783: endoplasmic reticulum              GO:0005783
# 16814  GO:0005783: endoplasmic reticulum              GO:0005783
#
#       GOSlim GOA Description       GOSlim_domain Gene stable ID_rice  \
# 0       extracellular region  cellular_component        Os06g0688200
# 1       extracellular region  cellular_component        Os01g0696800
# 2       extracellular region  cellular_component        Os06g0306300
# 3       extracellular region  cellular_component        Os06g0688200
# 4       extracellular region  cellular_component        Os01g0613500
# ...                      ...                 ...                 ...
# 16810  endoplasmic reticulum  cellular_component        Os05g0482400
# 16811  endoplasmic reticulum  cellular_component        Os05g0482400
# 16812  endoplasmic reticulum  cellular_component        Os05g0482400
# 16813  endoplasmic reticulum  cellular_component        Os05g0482400
# 16814  endoplasmic reticulum  cellular_component        Os05g0482400
#
#       Gene stable ID_mouse Chromosome/scaffold name_rice  start1 (bp)  \
# 0       ENSMUSG00000109523                           R_6     28707334
# 1       ENSMUSG00000074141                           R_1     28835243
# 2       ENSMUSG00000030858                           R_6     11559570
# 3       ENSMUSG00000030858                           R_6     28707334
# 4       ENSMUSG00000030858                           R_1     24343518
# ...                    ...                           ...          ...
# 16810   ENSMUSG00000031444                           R_5     23728568
# 16811   ENSMUSG00000022297                           R_5     23728568
# 16812   ENSMUSG00000044916                           R_5     23728568
# 16813   ENSMUSG00000047694                           R_5     23728568
# 16814   ENSMUSG00000062526                           R_5     23728568
#
#        end1 (bp) Chromosome/scaffold name_mouse  start2 (bp)  end2 (bp)  \
# 0       28708349                            M_8     70782467   70784237
# 1       28836884                            M_7     44465811   44490233
# 2       11560896                            M_7    130927673  130931245
# 3       28708349                            M_7    130927673  130931245
# 4       24345172                            M_7    130927673  130931245
# ...          ...                            ...          ...        ...
# 16810   23738372                            M_8     13087308   13106676
# 16811   23738372                           M_15     38869429   38901583
# 16812   23738372                            M_2     92212883   92216053
# 16813   23738372                            M_X     97979922   97992623
# 16814   23738372                           M_18     67358114   67378901
#
#        HN-score(HN5)_rice  HN-score(HN5)_mouse  counts_down  fold_enrichment  \
# 0                     -77                  -17          841         4.426216
# 1                     -42                  -30          841         4.426216
# 2                     -41                  -33          841         4.426216
# 3                     -77                  -33          841         4.426216
# 4                     -75                  -33          841         4.426216
# ...                   ...                  ...          ...              ...
# 16810                 -49                  -15            8         0.054125
# 16811                 -49                  -15            8         0.054125
# 16812                 -49                  -25            8         0.054125
# 16813                 -49                  -19            8         0.054125
# 16814                 -49                  -16            8         0.054125
#
#              p_value        q_value
# 0      1.028298e-268  1.748106e-267
# 1      1.028298e-268  1.748106e-267
# 2      1.028298e-268  1.748106e-267
# 3      1.028298e-268  1.748106e-267
# 4      1.028298e-268  1.748106e-267
# ...              ...            ...
# 16810   1.000000e+00   1.000000e+00
# 16811   1.000000e+00   1.000000e+00
# 16812   1.000000e+00   1.000000e+00
# 16813   1.000000e+00   1.000000e+00
# 16814   1.000000e+00   1.000000e+00
#
# [16815 rows x 18 columns]
