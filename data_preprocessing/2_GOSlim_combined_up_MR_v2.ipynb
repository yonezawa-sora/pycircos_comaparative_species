# %% [markdown]
# ## Discription
#
# ### Background
# Circos plotの描画の処理内で行われている結合をこちらのファイルで行うことを目的に作成しました

# %%
import collections
import csv
import datetime
import os
import pandas as pd
import numpy as np
from collections import Counter

# %%
# output directory
organism1_vs_organism2 = "MR" # human vs rice
direction = "up"
now = datetime.datetime.now()
circos_dir = f'../data/circos_{direction}_{organism1_vs_organism2}_{now.strftime("%y%m")}'
no_annotation = f'../data/{circos_dir}/no_annotation_{direction}'
os.makedirs(circos_dir, exist_ok=True)
os.makedirs(no_annotation, exist_ok=True)

# %% [markdown]
# ## MOUSE_UP
#
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#
# 2. Extract GOSlim corresponding to the list of up-regulated genes

# %%
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#organism = "human" (H)
df_m_score = pd.read_csv(f"../data/mouse_annotation/mouse_position_{direction}.tsv", sep='\t')
df_m_score_subset = df_m_score[['Gene stable ID', # create a subset
                        'Chromosome/scaffold name', 
                        'start2 (bp)',
                        'end2 (bp)',
                        'HN-score(HN5)']].copy()
df_m_score_subset['Chromosome/scaffold name'] = 'M_' + df_m_score_subset['Chromosome/scaffold name'].astype(str)
df_m_score_subset['organism'] = 'mouse'# assign the tag

df_m_score_subset.to_csv(f"../data/{circos_dir}/human_position_{direction}_assign.tsv", sep='\t', index=False)

display(df_m_score_subset)
# Out:
#          Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 0    ENSMUSG00000090877                     M_17     35175412   35178214
# 1    ENSMUSG00000091971                     M_17     35188166   35191132
# 2    ENSMUSG00000004951                      M_5    135916773  135918417
# 3    ENSMUSG00000092609                     M_17     35188888   35191112
# 4    ENSMUSG00000026628                      M_1    190902493  190950236
# ..                  ...                      ...          ...        ...
# 243  ENSMUSG00000037887                      M_7    141633227  141649580
# 244  ENSMUSG00000035775                     M_11     99319229   99328976
# 245  ENSMUSG00000054034                      M_X    135101697  135104625
# 246  ENSMUSG00000098715                      M_6     48695541   48729578
# 247  ENSMUSG00000036731                      M_2     25128830   25132464
#
#      HN-score(HN5) organism
# 0              149    mouse
# 1              137    mouse
# 2              111    mouse
# 3               88    mouse
# 4               78    mouse
# ..             ...      ...
# 243             13    mouse
# 244             13    mouse
# 245             13    mouse
# 246             13    mouse
# 247             13    mouse
#
# [248 rows x 6 columns]

# %%
# 2. Extract GOSlim corresponding to the list of up-regulated genes
goslim_all_mouse = pd.read_csv('../data/biomart_goslim/biomart_mouse_goslim_R110_domain.tsv', sep='\t',
                               dtype={'Gene stable ID': 'object'}, 
                               low_memory=False)
columns_of_interest_mouse = ['Gene stable ID', 
                             'GOSlim GOA Accession(s)', 
                             'GOSlim GOA Description', 
                             'GOSlim_domain']
goslim_all_mouse_filtered = goslim_all_mouse[columns_of_interest_mouse]

extract_df_m_goslim = pd.merge(
    df_m_score_subset, 
    goslim_all_mouse_filtered, 
    on='Gene stable ID', 
    how='inner'
    )
extract_df_m_goslim = extract_df_m_goslim.drop_duplicates(subset=['Gene stable ID',
                                                                  'GOSlim GOA Accession(s)', 
                                                                  'GOSlim GOA Description'], keep='first').copy()

# Extract genes with no annotations
extract_df_h_goslim_with_indicator = pd.merge(
    df_m_score_subset, 
    goslim_all_mouse_filtered,
    left_on='Gene stable ID',
    right_on='Gene stable ID',
    how='left',
    indicator=True # add indicator column to show the difference
)

# extract_df_h_goslim_with_indicator
left_only_rows = extract_df_h_goslim_with_indicator[extract_df_h_goslim_with_indicator['_merge'] == 'left_only']

extract_df_m_goslim.to_csv(f"../data/{circos_dir}/human_goslim_{direction}.tsv", sep='\t', index=False)
left_only_rows.to_csv(f"../data/{no_annotation}/human_position_down_no_annotation.tsv", sep='\t', index=False)

display(goslim_all_mouse_filtered, extract_df_m_goslim, left_only_rows)
# Out:
#             Gene stable ID GOSlim GOA Accession(s)  \
# 0       ENSMUSG00000064336              GO:0060090
# 1       ENSMUSG00000064336              GO:0003723
# 2       ENSMUSG00000064336              GO:0043226
# 3       ENSMUSG00000064336              GO:0005739
# 4       ENSMUSG00000064337              GO:0005198
# ...                    ...                     ...
# 170875  ENSMUSG00000015335              GO:0036211
# 170876  ENSMUSG00000015335              GO:0023052
# 170877  ENSMUSG00000015335              GO:0048856
# 170878  ENSMUSG00000015335              GO:0034330
# 170879  ENSMUSG00000039686              GO:0030163
#
#                   GOSlim GOA Description       GOSlim_domain
# 0             molecular adaptor activity  molecular_function
# 1                            RNA binding  molecular_function
# 2                              organelle  cellular_component
# 3                          mitochondrion  cellular_component
# 4           structural molecule activity  molecular_function
# ...                                  ...                 ...
# 170875      protein modification process  biological_process
# 170876                         signaling  biological_process
# 170877  anatomical structure development  biological_process
# 170878        cell junction organization  biological_process
# 170879         protein catabolic process  biological_process
#
# [170880 rows x 4 columns]
#           Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 0     ENSMUSG00000090877                     M_17     35175412   35178214
# 1     ENSMUSG00000090877                     M_17     35175412   35178214
# 2     ENSMUSG00000090877                     M_17     35175412   35178214
# 3     ENSMUSG00000090877                     M_17     35175412   35178214
# 4     ENSMUSG00000090877                     M_17     35175412   35178214
# ...                  ...                      ...          ...        ...
# 2137  ENSMUSG00000035775                     M_11     99319229   99328976
# 2138  ENSMUSG00000035775                     M_11     99319229   99328976
# 2139  ENSMUSG00000054034                      M_X    135101697  135104625
# 2140  ENSMUSG00000054034                      M_X    135101697  135104625
# 2141  ENSMUSG00000054034                      M_X    135101697  135104625
#
#       HN-score(HN5) organism GOSlim GOA Accession(s)  \
# 0               149    mouse              GO:0140657
# 1               149    mouse              GO:0044183
# 2               149    mouse              GO:0043226
# 3               149    mouse              GO:0005739
# 4               149    mouse              GO:0012501
# ...             ...      ...                     ...
# 2137             13    mouse              GO:0048856
# 2138             13    mouse              GO:0030154
# 2139             13    mouse              GO:0043226
# 2140             13    mouse              GO:0005634
# 2141             13    mouse              GO:0045182
#
#                 GOSlim GOA Description       GOSlim_domain
# 0               ATP-dependent activity  molecular_function
# 1            protein folding chaperone  molecular_function
# 2                            organelle  cellular_component
# 3                        mitochondrion  cellular_component
# 4                programmed cell death  biological_process
# ...                                ...                 ...
# 2137  anatomical structure development  biological_process
# 2138              cell differentiation  biological_process
# 2139                         organelle  cellular_component
# 2140                           nucleus  cellular_component
# 2141    translation regulator activity  molecular_function
#
# [2142 rows x 9 columns]
#           Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 66    ENSMUSG00000092609                     M_17     35188888   35191112
# 290   ENSMUSG00000118491                     M_19     12741024   12773490
# 303   ENSMUSG00000068349                     M_15     74685301   74690664
# 319   ENSMUSG00000079304                      M_6    128352419  128362107
# 520   ENSMUSG00000068600                     M_15     74690920   74706720
# 527   ENSMUSG00000115463                     M_15     58761147   58809208
# 619   ENSMUSG00000087610                      M_3     96484300   96487979
# 736   ENSMUSG00000062563                     M_12     24715832   24731812
# 902   ENSMUSG00000050671                     M_12     87325412   87346479
# 985   ENSMUSG00000053522                      M_7     28563278   28565709
# 986   ENSMUSG00000096257                      M_7     28455599   28458393
# 996   ENSMUSG00000096330                     M_13     98416395   98443662
# 1095  ENSMUSG00000076613                     M_12    113266585  113271553
# 1191  ENSMUSG00000048572                     M_19     24651372   24659597
# 1192  ENSMUSG00000118553                      M_7     43077110   43078256
# 1290  ENSMUSG00000036858                     M_17     47066589   47074638
# 1316  ENSMUSG00000032092                      M_9     44951097   44965313
# 1358  ENSMUSG00000091060                      M_1    162474762  162485788
# 1521  ENSMUSG00000108900                      M_8     71972764   71978355
# 1594  ENSMUSG00000089953                      M_2     25124488   25126799
# 1746  ENSMUSG00000040405                     M_11     46625907   46670405
# 1980  ENSMUSG00000026774                      M_2     23097488   23157141
# 2015  ENSMUSG00000110404                      M_4    156214970  156217877
# 2042  ENSMUSG00000098678                     M_15     75755986   75760619
# 2121  ENSMUSG00000048636                      M_6     92793459   92824155
# 2167  ENSMUSG00000098715                      M_6     48695541   48729578
# 2168  ENSMUSG00000036731                      M_2     25128830   25132464
#
#       HN-score(HN5) organism GOSlim GOA Accession(s) GOSlim GOA Description  \
# 66               88    mouse                     NaN                    NaN
# 290              32    mouse                     NaN                    NaN
# 303              30    mouse                     NaN                    NaN
# 319              29    mouse                     NaN                    NaN
# 520              24    mouse                     NaN                    NaN
# 527              23    mouse                     NaN                    NaN
# 619              22    mouse                     NaN                    NaN
# 736              20    mouse                     NaN                    NaN
# 902              19    mouse                     NaN                    NaN
# 985              18    mouse                     NaN                    NaN
# 986              18    mouse                     NaN                    NaN
# 996              17    mouse                     NaN                    NaN
# 1095             17    mouse                     NaN                    NaN
# 1191             16    mouse                     NaN                    NaN
# 1192             16    mouse                     NaN                    NaN
# 1290             16    mouse                     NaN                    NaN
# 1316             16    mouse                     NaN                    NaN
# 1358             16    mouse                     NaN                    NaN
# 1521             15    mouse                     NaN                    NaN
# 1594             14    mouse                     NaN                    NaN
# 1746             14    mouse                     NaN                    NaN
# 1980             13    mouse                     NaN                    NaN
# 2015             13    mouse                     NaN                    NaN
# 2042             13    mouse                     NaN                    NaN
# 2121             13    mouse                     NaN                    NaN
# 2167             13    mouse                     NaN                    NaN
# 2168             13    mouse                     NaN                    NaN
#
#      GOSlim_domain     _merge
# 66             NaN  left_only
# 290            NaN  left_only
# 303            NaN  left_only
# 319            NaN  left_only
# 520            NaN  left_only
# 527            NaN  left_only
# 619            NaN  left_only
# 736            NaN  left_only
# 902            NaN  left_only
# 985            NaN  left_only
# 986            NaN  left_only
# 996            NaN  left_only
# 1095           NaN  left_only
# 1191           NaN  left_only
# 1192           NaN  left_only
# 1290           NaN  left_only
# 1316           NaN  left_only
# 1358           NaN  left_only
# 1521           NaN  left_only
# 1594           NaN  left_only
# 1746           NaN  left_only
# 1980           NaN  left_only
# 2015           NaN  left_only
# 2042           NaN  left_only
# 2121           NaN  left_only
# 2167           NaN  left_only
# 2168           NaN  left_only

# %% [markdown]
# ## RICE_UP
#
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#
# 2. Extract GOSlim corresponding to the list of up-regulated genes

# %%
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
df_r_score = pd.read_csv(f'../data/rice_annotation/rice_position_{direction}.tsv', sep='\t')
df_r_score_subset = df_r_score[['Gene stable ID', # create a subset
                        'Chromosome/scaffold name', 
                        'start1 (bp)',
                        'end1 (bp)',
                        'HN-score(HN5)']].copy()
df_r_score_subset['Chromosome/scaffold name'] = 'R_' + df_r_score_subset['Chromosome/scaffold name'].astype(str)
df_r_score_subset['organism'] = 'rice'# assign the tag

df_r_score_subset.to_csv(f"../data/{circos_dir}/rice_position_{direction}_assign.tsv", sep='\t', index=False)

display(df_r_score_subset)
# Out:
#     Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0     Os04g0107900                      R_4       483234     485978
# 1     Os01g0136100                      R_1      1948773    1949587
# 2     Os02g0259900                      R_2      9021454    9023102
# 3     Os03g0245800                      R_3      7697015    7698027
# 4     Os03g0277300                      R_3      9411494    9416082
# ..             ...                      ...          ...        ...
# 384   Os03g0820400                      R_3     34427704   34428391
# 385   Os10g0328600                     R_10      9212944    9216458
# 386   Os01g0971800                      R_1     42874273   42875515
# 387   Os07g0621600                      R_7     25691906   25692138
# 388   Os04g0639000                      R_4     32476494   32477199
#
#      HN-score(HN5) organism
# 0              253     rice
# 1              246     rice
# 2              238     rice
# 3              237     rice
# 4              236     rice
# ..             ...      ...
# 384             42     rice
# 385             42     rice
# 386             42     rice
# 387             42     rice
# 388             42     rice
#
# [389 rows x 6 columns]

# %%
# 2. Extract GOSlim corresponding to the list of up-regulated genes
goslim_all_rice = pd.read_csv('../data/biomart_goslim/biomart_rice_goslim_R56_domain.tsv', sep='\t',
                               dtype={'Gene stable ID': 'object'}, 
                               low_memory=False)
columns_of_interest_rice = ['Gene stable ID',
                            'GOSlim GOA Accession(s)', 
                            'GOSlim GOA Description', 
                            'GOSlim_domain']
goslim_all_rice_filtered = goslim_all_rice[columns_of_interest_rice]

extract_df_r_goslim = pd.merge(
    df_r_score_subset, 
    goslim_all_rice_filtered, 
    on='Gene stable ID', 
    how='inner'
    )

extract_df_r_goslim = extract_df_r_goslim.drop_duplicates(subset=['Gene stable ID',
                                                                    'GOSlim GOA Accession(s)', 
                                                                    'GOSlim GOA Description'], keep='first').copy()

# Extract genes with no annotations
extract_df_r_goslim_with_indicator = pd.merge(
    df_r_score_subset, 
    goslim_all_rice_filtered,
    left_on='Gene stable ID',
    right_on='Gene stable ID',
    how='left',
    indicator=True # add indicator column to show the difference
)

# extract_df_r_goslim_with_indicator
left_only_rows = extract_df_r_goslim_with_indicator[extract_df_r_goslim_with_indicator['_merge'] == 'left_only']

extract_df_r_goslim.to_csv(f"../data/{circos_dir}/rice_goslim_{direction}.tsv", sep='\t', index=False)
left_only_rows.to_csv(f"../data/{no_annotation}/rice_position_{direction}_no_annotation.tsv", sep='\t', index=False)

display(goslim_all_rice_filtered, extract_df_r_goslim, left_only_rows)
# Out:
#        Gene stable ID GOSlim GOA Accession(s)        GOSlim GOA Description  \
# 0        Os01g0100100              GO:0006810                     transport
# 1        Os01g0100100              GO:0008150            biological_process
# 2        Os01g0100100              GO:0009987              cellular process
# 3        Os01g0100100              GO:0003674            molecular_function
# 4        Os01g0100100              GO:0030234     enzyme regulator activity
# ...               ...                     ...                           ...
# 219494     gene-rps19              GO:0003674            molecular_function
# 219495     gene-rps19              GO:0005198  structural molecule activity
# 219496     gene-rps19              GO:0005488                       binding
# 219497     gene-rps19              GO:0003723                   RNA binding
# 219498     gene-rps19              GO:0003676          nucleic acid binding
#
#              GOSlim_domain
# 0       biological_process
# 1       biological_process
# 2       biological_process
# 3       molecular_function
# 4       molecular_function
# ...                    ...
# 219494  molecular_function
# 219495  molecular_function
# 219496  molecular_function
# 219497  molecular_function
# 219498  molecular_function
#
# [219499 rows x 4 columns]
#      Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0      Os04g0107900                      R_4       483234     485978
# 1      Os04g0107900                      R_4       483234     485978
# 2      Os04g0107900                      R_4       483234     485978
# 3      Os04g0107900                      R_4       483234     485978
# 4      Os04g0107900                      R_4       483234     485978
# ...             ...                      ...          ...        ...
# 2522   Os01g0971800                      R_1     42874273   42875515
# 2523   Os01g0971800                      R_1     42874273   42875515
# 2524   Os01g0971800                      R_1     42874273   42875515
# 2525   Os01g0971800                      R_1     42874273   42875515
# 2526   Os01g0971800                      R_1     42874273   42875515
#
#       HN-score(HN5) organism GOSlim GOA Accession(s)  \
# 0               253     rice              GO:0003674
# 1               253     rice              GO:0005515
# 2               253     rice              GO:0005488
# 3               253     rice              GO:0008150
# 4               253     rice              GO:0006950
# ...             ...      ...                     ...
# 2522             42     rice              GO:0008152
# 2523             42     rice              GO:0009058
# 2524             42     rice              GO:0006139
# 2525             42     rice              GO:0003700
# 2526             42     rice              GO:0140110
#
#                                 GOSlim GOA Description       GOSlim_domain
# 0                                   molecular_function  molecular_function
# 1                                      protein binding  molecular_function
# 2                                              binding  molecular_function
# 3                                   biological_process  biological_process
# 4                                   response to stress  biological_process
# ...                                                ...                 ...
# 2522                                 metabolic process  biological_process
# 2523                              biosynthetic process  biological_process
# 2524  nucleobase-containing compound metabolic process  biological_process
# 2525         DNA-binding transcription factor activity  molecular_function
# 2526                  transcription regulator activity  molecular_function
#
# [2527 rows x 9 columns]
#      Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 172    Os04g0108101                      R_4       485272     485663
# 173    Os01g0184050                      R_1      4449056    4449806
# 229    Os05g0296800                      R_5     13197199   13199560
# 243    Os11g0533400                     R_11     19430389   19431158
# 274    Os04g0578550                      R_4     29163356   29165144
# ...             ...                      ...          ...        ...
# 2588   Os11g0506700                     R_11     18069286   18071596
# 2589   Os03g0254250                      R_3      8134007    8134226
# 2642   Os10g0328600                     R_10      9212944    9216458
# 2657   Os07g0621600                      R_7     25691906   25692138
# 2658   Os04g0639000                      R_4     32476494   32477199
#
#       HN-score(HN5) organism GOSlim GOA Accession(s) GOSlim GOA Description  \
# 172             205     rice                     NaN                    NaN
# 173             205     rice                     NaN                    NaN
# 229             166     rice                     NaN                    NaN
# 243             165     rice                     NaN                    NaN
# 274             158     rice                     NaN                    NaN
# ...             ...      ...                     ...                    ...
# 2588             42     rice                     NaN                    NaN
# 2589             42     rice                     NaN                    NaN
# 2642             42     rice                     NaN                    NaN
# 2657             42     rice                     NaN                    NaN
# 2658             42     rice                     NaN                    NaN
#
#      GOSlim_domain     _merge
# 172            NaN  left_only
# 173            NaN  left_only
# 229            NaN  left_only
# 243            NaN  left_only
# 274            NaN  left_only
# ...            ...        ...
# 2588           NaN  left_only
# 2589           NaN  left_only
# 2642           NaN  left_only
# 2657           NaN  left_only
# 2658           NaN  left_only
#
# [132 rows x 10 columns]

# %% [markdown]
# ## COMBINED_UP( HUMAN_UP + RICE_UP )
#
# 1. chromosome position + gene position + HN-score
#
# 2. GOslim terms corresponding to the list of up-regulated genes

# %%
# 1. chromosome position + gene position + HN-score
combined_df_score = pd.concat([df_m_score_subset, 
                               df_r_score_subset])
combined_df_score.reset_index(drop=True, inplace=True)
combined_df_score['Gene start (bp)'] = combined_df_score['start1 (bp)'].combine_first(combined_df_score['start2 (bp)'])
combined_df_score['Gene end (bp)'] = combined_df_score['end1 (bp)'].combine_first(combined_df_score['end2 (bp)'])
combined_df_score.drop(['start1 (bp)', 'start2 (bp)', 'end1 (bp)', 'end2 (bp)'], axis=1, inplace=True)

combined_df_score.to_csv(f"../data/{circos_dir}/combined_position_{direction}.tsv", sep='\t', index=False)

display(combined_df_score)
# Out:
#          Gene stable ID Chromosome/scaffold name  HN-score(HN5) organism  \
# 0    ENSMUSG00000090877                     M_17            149    mouse
# 1    ENSMUSG00000091971                     M_17            137    mouse
# 2    ENSMUSG00000004951                      M_5            111    mouse
# 3    ENSMUSG00000092609                     M_17             88    mouse
# 4    ENSMUSG00000026628                      M_1             78    mouse
# ..                  ...                      ...            ...      ...
# 632        Os03g0820400                      R_3             42     rice
# 633        Os10g0328600                     R_10             42     rice
# 634        Os01g0971800                      R_1             42     rice
# 635        Os07g0621600                      R_7             42     rice
# 636        Os04g0639000                      R_4             42     rice
#
#      Gene start (bp)  Gene end (bp)
# 0         35175412.0     35178214.0
# 1         35188166.0     35191132.0
# 2        135916773.0    135918417.0
# 3         35188888.0     35191112.0
# 4        190902493.0    190950236.0
# ..               ...            ...
# 632       34427704.0     34428391.0
# 633        9212944.0      9216458.0
# 634       42874273.0     42875515.0
# 635       25691906.0     25692138.0
# 636       32476494.0     32477199.0
#
# [637 rows x 6 columns]

# %%
merged_df_goslim = pd.merge(
    extract_df_m_goslim, 
    extract_df_r_goslim, 
    left_on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'],
    right_on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'],
    how='inner',
    suffixes=('_mouse', '_rice')
)

merged_df_goslim = merged_df_goslim[['GOSlim GOA Accession(s)',
                                     'GOSlim GOA Description',
                                     'GOSlim_domain',
                                     'Gene stable ID_rice',
                                     'Gene stable ID_mouse',
                                     'Chromosome/scaffold name_rice',
                                     'start1 (bp)',
                                     'end1 (bp)',
                                     'Chromosome/scaffold name_mouse',
                                     'start2 (bp)',
                                     'end2 (bp)',
                                     'HN-score(HN5)_rice',
                                     'HN-score(HN5)_mouse']]

# Remove duplicate rows based on specific columns
merged_df_goslim.drop_duplicates(inplace=True)

display(merged_df_goslim)
# Out:
#       GOSlim GOA Accession(s)          GOSlim GOA Description  \
# 0                  GO:0005739                   mitochondrion
# 1                  GO:0005739                   mitochondrion
# 2                  GO:0005739                   mitochondrion
# 3                  GO:0005739                   mitochondrion
# 4                  GO:0005739                   mitochondrion
# ...                       ...                             ...
# 16724              GO:0005773                         vacuole
# 16725              GO:0005773                         vacuole
# 16726              GO:0005777                      peroxisome
# 16727              GO:0005777                      peroxisome
# 16728              GO:0045182  translation regulator activity
#
#             GOSlim_domain Gene stable ID_rice Gene stable ID_mouse  \
# 0      cellular_component        Os07g0467200   ENSMUSG00000090877
# 1      cellular_component        Os03g0276700   ENSMUSG00000090877
# 2      cellular_component        Os02g0758000   ENSMUSG00000090877
# 3      cellular_component        Os03g0776900   ENSMUSG00000090877
# 4      cellular_component        Os02g0181900   ENSMUSG00000090877
# ...                   ...                 ...                  ...
# 16724  cellular_component        Os09g0491772   ENSMUSG00000031957
# 16725  cellular_component        Os08g0442200   ENSMUSG00000031957
# 16726  cellular_component        Os06g0253100   ENSMUSG00000070985
# 16727  cellular_component        Os07g0529000   ENSMUSG00000070985
# 16728  molecular_function        Os05g0373900   ENSMUSG00000054034
#
#       Chromosome/scaffold name_rice  start1 (bp)  end1 (bp)  \
# 0                               R_7     16600103   16601979
# 1                               R_3      9375984    9377688
# 2                               R_2     31920854   31922068
# 3                               R_3     32208931   32210830
# 4                               R_2      4567630    4573049
# ...                             ...          ...        ...
# 16724                           R_9     18987999   18991156
# 16725                           R_8     21549721   21551326
# 16726                           R_6      7940956    7941680
# 16727                           R_7     20691213   20693521
# 16728                           R_5     18016742   18020353
#
#       Chromosome/scaffold name_mouse  start2 (bp)  end2 (bp)  \
# 0                               M_17     35175412   35178214
# 1                               M_17     35175412   35178214
# 2                               M_17     35175412   35178214
# 3                               M_17     35175412   35178214
# 4                               M_17     35175412   35178214
# ...                              ...          ...        ...
# 16724                            M_8    112413151  112417642
# 16725                            M_8    112413151  112417642
# 16726                            M_4     49447105   49473912
# 16727                            M_4     49447105   49473912
# 16728                            M_X    135101697  135104625
#
#        HN-score(HN5)_rice  HN-score(HN5)_mouse
# 0                     103                  149
# 1                      99                  149
# 2                      98                  149
# 3                      72                  149
# 4                      71                  149
# ...                   ...                  ...
# 16724                  51                   13
# 16725                  48                   13
# 16726                 129                   14
# 16727                  59                   14
# 16728                  42                   13
#
# [16729 rows x 13 columns]

# %%
# for debugging purpose
unique_accessions_r = set(extract_df_r_goslim['GOSlim GOA Accession(s)'].unique())
unique_accessions_h = set(extract_df_m_goslim['GOSlim GOA Accession(s)'].unique())
common_accessions = unique_accessions_r.intersection(unique_accessions_h)
unique_accessions_merged = set(merged_df_goslim['GOSlim GOA Accession(s)'].unique())
missing_accessions = common_accessions.difference(unique_accessions_merged)
duplicates = merged_df_goslim.duplicated(subset=['GOSlim GOA Accession(s)', 'Gene stable ID_rice', 'Gene stable ID_mouse'], keep=False)
unique_combinations = not duplicates.any()
print(f"Number of common accessions: {len(common_accessions)}")
print(f"Number of missing accessions: {len(missing_accessions)}")
print(f"Missing accessions: {missing_accessions}")
print(f"各'Gene stable ID_rice'と'Gene stable ID_mouse'の組み合わせはユニークですか？: {unique_combinations}")

#Count the occurrences of each 'GOSlim GOA Accession(s)'
accession_counter = Counter(merged_df_goslim['GOSlim GOA Accession(s)'])

#Sort the DataFrame based on the counts
merged_df_goslim['count'] = merged_df_goslim['GOSlim GOA Accession(s)'].map(accession_counter)
merged_df_goslim_sorted = merged_df_goslim.sort_values('count', ascending=False).drop('count', axis=1)
merged_df_goslim_sorted.reset_index(drop=True, inplace=True)
merged_df_goslim_sorted.to_csv(f"../data/{circos_dir}/combined_goslim_{direction}.tsv", sep='\t', index=False)

display(merged_df_goslim_sorted)
# Out:
# Number of common accessions: 28
# Number of missing accessions: 0
# Missing accessions: set()
# 各'Gene stable ID_rice'と'Gene stable ID_mouse'の組み合わせはユニークですか？: True
#       GOSlim GOA Accession(s)          GOSlim GOA Description  \
# 0                  GO:0005634                         nucleus
# 1                  GO:0005634                         nucleus
# 2                  GO:0005634                         nucleus
# 3                  GO:0005634                         nucleus
# 4                  GO:0005634                         nucleus
# ...                       ...                             ...
# 16724              GO:0005730                       nucleolus
# 16725              GO:0005730                       nucleolus
# 16726              GO:0005777                      peroxisome
# 16727              GO:0005777                      peroxisome
# 16728              GO:0045182  translation regulator activity
#
#             GOSlim_domain Gene stable ID_rice Gene stable ID_mouse  \
# 0      cellular_component        Os03g0268600   ENSMUSG00000042745
# 1      cellular_component        Os03g0701100   ENSMUSG00000020427
# 2      cellular_component        Os03g0131800   ENSMUSG00000020427
# 3      cellular_component        Os08g0546800   ENSMUSG00000020427
# 4      cellular_component        Os03g0710500   ENSMUSG00000020427
# ...                   ...                 ...                  ...
# 16724  cellular_component        Os06g0592500   ENSMUSG00000005483
# 16725  cellular_component        Os06g0592500   ENSMUSG00000026628
# 16726  cellular_component        Os06g0253100   ENSMUSG00000070985
# 16727  cellular_component        Os07g0529000   ENSMUSG00000070985
# 16728  molecular_function        Os05g0373900   ENSMUSG00000054034
#
#       Chromosome/scaffold name_rice  start1 (bp)  end1 (bp)  \
# 0                               R_3      8921424    8923437
# 1                               R_3     28138905   28141758
# 2                               R_3      1815345    1816503
# 3                               R_8     27382872   27384470
# 4                               R_3     28647086   28649570
# ...                             ...          ...        ...
# 16724                           R_6     23293383   23294073
# 16725                           R_6     23293383   23294073
# 16726                           R_6      7940956    7941680
# 16727                           R_7     20691213   20693521
# 16728                           R_5     18016742   18020353
#
#       Chromosome/scaffold name_mouse  start2 (bp)  end2 (bp)  \
# 0                                M_2    152578171  152579330
# 1                               M_11      7156086    7163923
# 2                               M_11      7156086    7163923
# 3                               M_11      7156086    7163923
# 4                               M_11      7156086    7163923
# ...                              ...          ...        ...
# 16724                            M_8     84334822   84339282
# 16725                            M_1    190902493  190950236
# 16726                            M_4     49447105   49473912
# 16727                            M_4     49447105   49473912
# 16728                            M_X    135101697  135104625
#
#        HN-score(HN5)_rice  HN-score(HN5)_mouse
# 0                      59                   14
# 1                     103                   16
# 2                      65                   16
# 3                      73                   16
# 4                      74                   16
# ...                   ...                  ...
# 16724                 118                   71
# 16725                 118                   78
# 16726                 129                   14
# 16727                  59                   14
# 16728                  42                   13
#
# [16729 rows x 13 columns]

# %% [markdown]
# ## Merge GOslim terms and line enrichment results

# %%
enrichment = pd.read_csv(
    f'../data/line_enrichment_{direction}_MR_2312/goslim_correspondence_q_values_{direction}_MR/goslim_correspondence_fold_enrichment_p_q_{direction}.tsv', sep='\t')

merged_df_goslim_sorted["GOSlim"] = merged_df_goslim_sorted['GOSlim GOA Accession(s)'] + ": " + merged_df_goslim_sorted['GOSlim GOA Description']

merged_df_goslim_sorted = merged_df_goslim_sorted[['GOSlim',
                                                    'GOSlim GOA Accession(s)',
                                                    'GOSlim GOA Description',
                                                    'GOSlim_domain',
                                                    'Gene stable ID_rice',
                                                    'Gene stable ID_mouse',
                                                    'Chromosome/scaffold name_rice',
                                                    'start1 (bp)',
                                                    'end1 (bp)',
                                                    'Chromosome/scaffold name_mouse',
                                                    'start2 (bp)',
                                                    'end2 (bp)',
                                                    'HN-score(HN5)_rice',
                                                    'HN-score(HN5)_mouse']]


merged_df_goslim_enrichment = pd.merge(
    merged_df_goslim_sorted,
    enrichment[['GOSlim', f'counts_{direction}', 'fold_enrichment', 'p_value', 'q_value']],
    on='GOSlim',
    how='left'
)
merged_df_goslim_enrichment.sort_values('fold_enrichment', ascending=False, inplace=True)
merged_df_goslim_enrichment.reset_index(drop=True, inplace=True)
merged_df_goslim_enrichment.to_csv(f"../data/{circos_dir}/combined_goslim_enrichment_{direction}.tsv", sep='\t', index=False)

display(enrichment, merged_df_goslim_sorted, merged_df_goslim_enrichment)
# Out:
#                                                GOSlim GOSlim GOA Accession(s)  \
# 0                           GO:0008289: lipid binding              GO:0008289
# 1   GO:0006091: generation of precursor metabolite...              GO:0006091
# 2                   GO:0005783: endoplasmic reticulum              GO:0005783
# 3                    GO:0005576: extracellular region              GO:0005576
# 4                                 GO:0005829: cytosol              GO:0005829
# 5                                 GO:0005773: vacuole              GO:0005773
# 6        GO:0140110: transcription regulator activity              GO:0140110
# 7          GO:0005975: carbohydrate metabolic process              GO:0005975
# 8        GO:0048856: anatomical structure development              GO:0048856
# 9                           GO:0005739: mitochondrion              GO:0005739
# 10                            GO:0003677: DNA binding              GO:0003677
# 11                GO:0006629: lipid metabolic process              GO:0006629
# 12                             GO:0005777: peroxisome              GO:0005777
# 13                     GO:0016787: hydrolase activity              GO:0016787
# 14                                GO:0005634: nucleus              GO:0005634
# 15                   GO:0005215: transporter activity              GO:0005215
# 16           GO:0005198: structural molecule activity              GO:0005198
# 17                     GO:0003824: catalytic activity              GO:0003824
# 18                            GO:0005654: nucleoplasm              GO:0005654
# 19                        GO:0005886: plasma membrane              GO:0005886
# 20                   GO:0030154: cell differentiation              GO:0030154
# 21                           GO:0005856: cytoskeleton              GO:0005856
# 22           GO:0036211: protein modification process              GO:0036211
# 23                        GO:0005794: Golgi apparatus              GO:0005794
# 24         GO:0045182: translation regulator activity              GO:0045182
# 25                   GO:0016740: transferase activity              GO:0016740
# 26                              GO:0005730: nucleolus              GO:0005730
# 27                            GO:0003723: RNA binding              GO:0003723
#
#                             GOSlim GOA Description       GOSlim_domain  \
# 0                                    lipid binding  molecular_function
# 1   generation of precursor metabolites and energy  biological_process
# 2                            endoplasmic reticulum  cellular_component
# 3                             extracellular region  cellular_component
# 4                                          cytosol  cellular_component
# 5                                          vacuole  cellular_component
# 6                 transcription regulator activity  molecular_function
# 7                   carbohydrate metabolic process  biological_process
# 8                 anatomical structure development  biological_process
# 9                                    mitochondrion  cellular_component
# 10                                     DNA binding  molecular_function
# 11                         lipid metabolic process  biological_process
# 12                                      peroxisome  cellular_component
# 13                              hydrolase activity  molecular_function
# 14                                         nucleus  cellular_component
# 15                            transporter activity  molecular_function
# 16                    structural molecule activity  molecular_function
# 17                              catalytic activity  molecular_function
# 18                                     nucleoplasm  cellular_component
# 19                                 plasma membrane  cellular_component
# 20                            cell differentiation  biological_process
# 21                                    cytoskeleton  cellular_component
# 22                    protein modification process  biological_process
# 23                                 Golgi apparatus  cellular_component
# 24                  translation regulator activity  molecular_function
# 25                            transferase activity  molecular_function
# 26                                       nucleolus  cellular_component
# 27                                     RNA binding  molecular_function
#
#     counts_up  counts_all  up_ratio  all_ratio  fold_enrichment  \
# 0         147      257535  0.008787   0.001406         6.247552
# 1          77      243045  0.004603   0.001327         3.467630
# 2         504     1609508  0.030127   0.008790         3.427411
# 3         610     2069023  0.036464   0.011300         3.226958
# 4        1326     5489678  0.079264   0.029981         2.643781
# 5          64      270510  0.003826   0.001477         2.589557
# 6         396     1948470  0.023671   0.010641         2.224489
# 7         120      655182  0.007173   0.003578         2.004694
# 8        1222     7211128  0.073047   0.039383         1.854799
# 9         322     2075124  0.019248   0.011333         1.698402
# 10        567     4990802  0.033893   0.027257         1.243488
# 11        162     1429560  0.009684   0.007807         1.240342
# 12          2       17818  0.000120   0.000097         1.228570
# 13        798     7777545  0.047702   0.042476         1.123024
# 14       4150    46028115  0.248072   0.251376         0.986856
# 15        150     1687420  0.008966   0.009216         0.972964
# 16         40      488130  0.002391   0.002666         0.896919
# 17       4136    56414781  0.247235   0.308102         0.802447
# 18         82     1255426  0.004902   0.006856         0.714910
# 19        858    13465191  0.051288   0.073538         0.697435
# 20         76     1302168  0.004543   0.007112         0.638815
# 21         35      661920  0.002092   0.003615         0.578750
# 22        462    10391837  0.027617   0.056754         0.486607
# 23         54     1297950  0.003228   0.007089         0.455370
# 24          1       26832  0.000060   0.000147         0.407921
# 25        306     9615454  0.018292   0.052514         0.348322
# 26         12      654804  0.000717   0.003576         0.200585
# 27         50     3071712  0.002989   0.016776         0.178163
#
#           p_value        q_value
# 0    1.084662e-65   7.375700e-65
# 1    9.441559e-20   4.585900e-19
# 2   1.265856e-118  1.434636e-117
# 3   2.927792e-132  4.977246e-131
# 4   1.413623e-213  4.806317e-212
# 5    3.137256e-11   1.066667e-10
# 6    1.240937e-45   7.031977e-45
# 7    4.773265e-12   1.803234e-11
# 8    5.857880e-90   4.979198e-89
# 9    8.449761e-19   3.591148e-18
# 10   2.012027e-07   6.218991e-07
# 11   4.259509e-03   1.114025e-02
# 12   4.840561e-01   1.000000e+00
# 13   5.258864e-04   1.490011e-03
# 14   8.399103e-01   1.000000e+00
# 15   6.429360e-01   1.000000e+00
# 16   7.746165e-01   1.000000e+00
# 17   1.000000e+00   1.000000e+00
# 18   9.994528e-01   1.000000e+00
# 19   1.000000e+00   1.000000e+00
# 20   9.999903e-01   1.000000e+00
# 21   9.998519e-01   1.000000e+00
# 22   1.000000e+00   1.000000e+00
# 23   1.000000e+00   1.000000e+00
# 24   9.138572e-01   1.000000e+00
# 25   1.000000e+00   1.000000e+00
# 26   1.000000e+00   1.000000e+00
# 27   1.000000e+00   1.000000e+00
#                                            GOSlim GOSlim GOA Accession(s)  \
# 0                             GO:0005634: nucleus              GO:0005634
# 1                             GO:0005634: nucleus              GO:0005634
# 2                             GO:0005634: nucleus              GO:0005634
# 3                             GO:0005634: nucleus              GO:0005634
# 4                             GO:0005634: nucleus              GO:0005634
# ...                                           ...                     ...
# 16724                       GO:0005730: nucleolus              GO:0005730
# 16725                       GO:0005730: nucleolus              GO:0005730
# 16726                      GO:0005777: peroxisome              GO:0005777
# 16727                      GO:0005777: peroxisome              GO:0005777
# 16728  GO:0045182: translation regulator activity              GO:0045182
#
#                GOSlim GOA Description       GOSlim_domain Gene stable ID_rice  \
# 0                             nucleus  cellular_component        Os03g0268600
# 1                             nucleus  cellular_component        Os03g0701100
# 2                             nucleus  cellular_component        Os03g0131800
# 3                             nucleus  cellular_component        Os08g0546800
# 4                             nucleus  cellular_component        Os03g0710500
# ...                               ...                 ...                 ...
# 16724                       nucleolus  cellular_component        Os06g0592500
# 16725                       nucleolus  cellular_component        Os06g0592500
# 16726                      peroxisome  cellular_component        Os06g0253100
# 16727                      peroxisome  cellular_component        Os07g0529000
# 16728  translation regulator activity  molecular_function        Os05g0373900
#
#       Gene stable ID_mouse Chromosome/scaffold name_rice  start1 (bp)  \
# 0       ENSMUSG00000042745                           R_3      8921424
# 1       ENSMUSG00000020427                           R_3     28138905
# 2       ENSMUSG00000020427                           R_3      1815345
# 3       ENSMUSG00000020427                           R_8     27382872
# 4       ENSMUSG00000020427                           R_3     28647086
# ...                    ...                           ...          ...
# 16724   ENSMUSG00000005483                           R_6     23293383
# 16725   ENSMUSG00000026628                           R_6     23293383
# 16726   ENSMUSG00000070985                           R_6      7940956
# 16727   ENSMUSG00000070985                           R_7     20691213
# 16728   ENSMUSG00000054034                           R_5     18016742
#
#        end1 (bp) Chromosome/scaffold name_mouse  start2 (bp)  end2 (bp)  \
# 0        8923437                            M_2    152578171  152579330
# 1       28141758                           M_11      7156086    7163923
# 2        1816503                           M_11      7156086    7163923
# 3       27384470                           M_11      7156086    7163923
# 4       28649570                           M_11      7156086    7163923
# ...          ...                            ...          ...        ...
# 16724   23294073                            M_8     84334822   84339282
# 16725   23294073                            M_1    190902493  190950236
# 16726    7941680                            M_4     49447105   49473912
# 16727   20693521                            M_4     49447105   49473912
# 16728   18020353                            M_X    135101697  135104625
#
#        HN-score(HN5)_rice  HN-score(HN5)_mouse
# 0                      59                   14
# 1                     103                   16
# 2                      65                   16
# 3                      73                   16
# 4                      74                   16
# ...                   ...                  ...
# 16724                 118                   71
# 16725                 118                   78
# 16726                 129                   14
# 16727                  59                   14
# 16728                  42                   13
#
# [16729 rows x 14 columns]
#                           GOSlim GOSlim GOA Accession(s)  \
# 0      GO:0008289: lipid binding              GO:0008289
# 1      GO:0008289: lipid binding              GO:0008289
# 2      GO:0008289: lipid binding              GO:0008289
# 3      GO:0008289: lipid binding              GO:0008289
# 4      GO:0008289: lipid binding              GO:0008289
# ...                          ...                     ...
# 16724    GO:0003723: RNA binding              GO:0003723
# 16725    GO:0003723: RNA binding              GO:0003723
# 16726    GO:0003723: RNA binding              GO:0003723
# 16727    GO:0003723: RNA binding              GO:0003723
# 16728    GO:0003723: RNA binding              GO:0003723
#
#       GOSlim GOA Description       GOSlim_domain Gene stable ID_rice  \
# 0              lipid binding  molecular_function        Os07g0659600
# 1              lipid binding  molecular_function        Os07g0659600
# 2              lipid binding  molecular_function        Os03g0111300
# 3              lipid binding  molecular_function        Os07g0659600
# 4              lipid binding  molecular_function        Os01g0849000
# ...                      ...                 ...                 ...
# 16724            RNA binding  molecular_function        Os02g0622500
# 16725            RNA binding  molecular_function        Os01g0719400
# 16726            RNA binding  molecular_function        Os10g0540800
# 16727            RNA binding  molecular_function        Os02g0622500
# 16728            RNA binding  molecular_function        Os06g0697200
#
#       Gene stable ID_mouse Chromosome/scaffold name_rice  start1 (bp)  \
# 0       ENSMUSG00000020437                           R_7     27800556
# 1       ENSMUSG00000020178                           R_7     27800556
# 2       ENSMUSG00000057933                           R_3       652323
# 3       ENSMUSG00000037379                           R_7     27800556
# 4       ENSMUSG00000037379                           R_1     36484020
# ...                    ...                           ...          ...
# 16724   ENSMUSG00000096520                           R_2     24783201
# 16725   ENSMUSG00000053113                           R_1     29995196
# 16726   ENSMUSG00000096520                          R_10     21091977
# 16727   ENSMUSG00000053113                           R_2     24783201
# 16728   ENSMUSG00000096520                           R_6     29163800
#
#        end1 (bp) Chromosome/scaffold name_mouse  start2 (bp)  end2 (bp)  \
# 0       27802446                           M_11      6456548    6470965
# 1       27802446                           M_10     75152711   75170618
# 2         652798                            M_9     78238300   78263070
# 3       27802446                            M_5     33355528   33375799
# 4       36484818                            M_5     33355528   33375799
# ...          ...                            ...          ...        ...
# 16724   24786542                            M_Y      3771673    3783267
# 16725   29999996                           M_11    117856905  117860873
# 16726   21096586                            M_Y      3771673    3783267
# 16727   24786542                           M_11    117856905  117860873
# 16728   29166676                            M_Y      3771673    3783267
#
#        HN-score(HN5)_rice  HN-score(HN5)_mouse  counts_up  fold_enrichment  \
# 0                      43                   29        147         6.247552
# 1                      43                   17        147         6.247552
# 2                      76                   13        147         6.247552
# 3                      43                   14        147         6.247552
# 4                      49                   14        147         6.247552
# ...                   ...                  ...        ...              ...
# 16724                  75                   15         50         0.178163
# 16725                  51                   17         50         0.178163
# 16726                  60                   15         50         0.178163
# 16727                  75                   17         50         0.178163
# 16728                  58                   15         50         0.178163
#
#             p_value       q_value
# 0      1.084662e-65  7.375700e-65
# 1      1.084662e-65  7.375700e-65
# 2      1.084662e-65  7.375700e-65
# 3      1.084662e-65  7.375700e-65
# 4      1.084662e-65  7.375700e-65
# ...             ...           ...
# 16724  1.000000e+00  1.000000e+00
# 16725  1.000000e+00  1.000000e+00
# 16726  1.000000e+00  1.000000e+00
# 16727  1.000000e+00  1.000000e+00
# 16728  1.000000e+00  1.000000e+00
#
# [16729 rows x 18 columns]
