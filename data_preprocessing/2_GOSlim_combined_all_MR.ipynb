# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
import os
import dask.dataframe as dd

organism1_vs_organism2 = 'MR' # mouse vs rice

# %%
goslim_all_mouse = dd.read_csv('../data/biomart_goslim/biomart_mouse_goslim_R110_domain.tsv', sep='\t',
                               dtype={'Gene stable ID': 'object'}, 
                               low_memory=False)
goslim_all_rice = dd.read_csv('../data/biomart_goslim/biomart_rice_goslim_R56_domain.tsv', sep='\t',
                              dtype={'Gene stable ID': 'object'},
                              low_memory=False)
columns_of_interest = ['Gene stable ID', 'GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain']

goslim_all_mouse_filtered = goslim_all_mouse[columns_of_interest]
goslim_all_rice_filtered = goslim_all_rice[columns_of_interest]

display(goslim_all_mouse_filtered.compute())
display(goslim_all_rice_filtered.compute())
# Out:
#             Gene stable ID GOSlim GOA Accession(s)  \
# 0       ENSMUSG00000064336              GO:0060090
# 1       ENSMUSG00000064336              GO:0003723
# 2       ENSMUSG00000064336              GO:0043226
# 3       ENSMUSG00000064336              GO:0005739
# 4       ENSMUSG00000064337              GO:0005198
# ...                    ...                     ...
# 170875  ENSMUSG00000015335              GO:0036211
# 170876  ENSMUSG00000015335              GO:0023052
# 170877  ENSMUSG00000015335              GO:0048856
# 170878  ENSMUSG00000015335              GO:0034330
# 170879  ENSMUSG00000039686              GO:0030163
#
#                   GOSlim GOA Description       GOSlim_domain
# 0             molecular adaptor activity  molecular_function
# 1                            RNA binding  molecular_function
# 2                              organelle  cellular_component
# 3                          mitochondrion  cellular_component
# 4           structural molecule activity  molecular_function
# ...                                  ...                 ...
# 170875      protein modification process  biological_process
# 170876                         signaling  biological_process
# 170877  anatomical structure development  biological_process
# 170878        cell junction organization  biological_process
# 170879         protein catabolic process  biological_process
#
# [170880 rows x 4 columns]
#        Gene stable ID GOSlim GOA Accession(s)        GOSlim GOA Description  \
# 0        Os01g0100100              GO:0006810                     transport
# 1        Os01g0100100              GO:0008150            biological_process
# 2        Os01g0100100              GO:0009987              cellular process
# 3        Os01g0100100              GO:0003674            molecular_function
# 4        Os01g0100100              GO:0030234     enzyme regulator activity
# ...               ...                     ...                           ...
# 219494     gene-rps19              GO:0003674            molecular_function
# 219495     gene-rps19              GO:0005198  structural molecule activity
# 219496     gene-rps19              GO:0005488                       binding
# 219497     gene-rps19              GO:0003723                   RNA binding
# 219498     gene-rps19              GO:0003676          nucleic acid binding
#
#              GOSlim_domain
# 0       biological_process
# 1       biological_process
# 2       biological_process
# 3       molecular_function
# 4       molecular_function
# ...                    ...
# 219494  molecular_function
# 219495  molecular_function
# 219496  molecular_function
# 219497  molecular_function
# 219498  molecular_function
#
# [219499 rows x 4 columns]

# %%
# merge dataframe based on common column 'GOSlim GOA Accession(s)'
merged_df_goslim = dd.merge(
    goslim_all_mouse_filtered, 
    goslim_all_rice_filtered,
    left_on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'],
    right_on=['GOSlim GOA Accession(s)','GOSlim GOA Description', 'GOSlim_domain'],
    how='inner',
    suffixes=('_rice', '_human')
)

# extract necessary columns
merged_df_goslim = merged_df_goslim[['GOSlim GOA Accession(s)',
                                     'GOSlim GOA Description',
                                     'GOSlim_domain',
                                     'Gene stable ID_human',
                                     'Gene stable ID_rice'
                                     ]]

merged_df_goslim_pd = merged_df_goslim.compute()

# Remove duplicate rows based on specific columns
merged_df_goslim_pd.drop_duplicates(inplace=True)

# for debugging purpose
unique_accessions_r = set(goslim_all_mouse_filtered['GOSlim GOA Accession(s)'].compute().unique())
unique_accessions_h = set(goslim_all_rice_filtered['GOSlim GOA Accession(s)'].compute().unique())
common_accessions = unique_accessions_r.intersection(unique_accessions_h)
unique_accessions_merged = set(merged_df_goslim_pd['GOSlim GOA Accession(s)'].unique())
missing_accessions = common_accessions.difference(unique_accessions_merged)
duplicates = merged_df_goslim_pd.duplicated(subset=['GOSlim GOA Accession(s)','Gene stable ID_rice', 'Gene stable ID_human'], keep=False)
unique_combinations = not duplicates.any()
print(f"Number of common accessions: {len(common_accessions)}")
print(f"Number of missing accessions: {len(missing_accessions)}")
print(f"Missing accessions: {missing_accessions}")
print(f"各'Gene stable ID_rice'と'Gene stable ID_human'の組み合わせはユニークですか？: {unique_combinations}")

merged_df_goslim_pd.to_csv(f"../data/GOSlim_merge_{organism1_vs_organism2}/GOslim_merge_common_goslim_correspondence_all.tsv", sep='\t', index=False)

display(merged_df_goslim_pd)
# Out:
# Number of common accessions: 34
# Number of missing accessions: 0
# Missing accessions: set()
# 各'Gene stable ID_rice'と'Gene stable ID_human'の組み合わせはユニークですか？: True
#           GOSlim GOA Accession(s)            GOSlim GOA Description  \
# 0                      GO:0003723                       RNA binding
# 1                      GO:0003723                       RNA binding
# 2                      GO:0003723                       RNA binding
# 3                      GO:0003723                       RNA binding
# 4                      GO:0003723                       RNA binding
# ...                           ...                               ...
# 183104384              GO:0030312  external encapsulating structure
# 183104385              GO:0030312  external encapsulating structure
# 183104386              GO:0030312  external encapsulating structure
# 183104387              GO:0030312  external encapsulating structure
# 183104388              GO:0030312  external encapsulating structure
#
#                 GOSlim_domain Gene stable ID_human Gene stable ID_rice
# 0          molecular_function         Os01g0100700  ENSMUSG00000064336
# 1          molecular_function         Os01g0101150  ENSMUSG00000064336
# 2          molecular_function         Os01g0101300  ENSMUSG00000064336
# 3          molecular_function         Os01g0101600  ENSMUSG00000064336
# 4          molecular_function         Os01g0118100  ENSMUSG00000064336
# ...                       ...                  ...                 ...
# 183104384  cellular_component         Os12g0514500  ENSMUSG00000026938
# 183104385  cellular_component         Os12g0530100  ENSMUSG00000026938
# 183104386  cellular_component         Os12g0546800  ENSMUSG00000026938
# 183104387  cellular_component         Os12g0563700  ENSMUSG00000026938
# 183104388  cellular_component         Os12g0578400  ENSMUSG00000026938
#
# [183104389 rows x 5 columns]

# %% [markdown]
# ### Extract dataset based on GOslim domain (BP, CC, MF)

# %%
cellular_component = merged_df_goslim_pd[merged_df_goslim_pd['GOSlim_domain'] == 'cellular_component']
molecular_function = merged_df_goslim_pd[merged_df_goslim_pd['GOSlim_domain'] == 'molecular_function']
biological_process = merged_df_goslim_pd[merged_df_goslim_pd['GOSlim_domain'] == 'biological_process']

cellular_component.to_csv(f"../data/GOSlim_merge_{organism1_vs_organism2}/GOslim_merge_common_goslim_correspondence_cc.tsv", sep='\t', index=False)
molecular_function.to_csv(f"../data/GOSlim_merge_{organism1_vs_organism2}/GOslim_merge_common_goslim_correspondence_mf.tsv", sep='\t', index=False)
biological_process.to_csv(f"../data/GOSlim_merge_{organism1_vs_organism2}/GOslim_merge_common_goslim_correspondence_bp.tsv", sep='\t', index=False)

display(cellular_component, molecular_function, biological_process)
# Out:
#           GOSlim GOA Accession(s)            GOSlim GOA Description  \
# 3071712                GO:0005739                     mitochondrion
# 3071713                GO:0005739                     mitochondrion
# 3071714                GO:0005739                     mitochondrion
# 3071715                GO:0005739                     mitochondrion
# 3071716                GO:0005739                     mitochondrion
# ...                           ...                               ...
# 183104384              GO:0030312  external encapsulating structure
# 183104385              GO:0030312  external encapsulating structure
# 183104386              GO:0030312  external encapsulating structure
# 183104387              GO:0030312  external encapsulating structure
# 183104388              GO:0030312  external encapsulating structure
#
#                 GOSlim_domain Gene stable ID_human Gene stable ID_rice
# 3071712    cellular_component         Os01g0105800  ENSMUSG00000064336
# 3071713    cellular_component         Os01g0118000  ENSMUSG00000064336
# 3071714    cellular_component         Os01g0120300  ENSMUSG00000064336
# 3071715    cellular_component         Os01g0120400  ENSMUSG00000064336
# 3071716    cellular_component         Os01g0141600  ENSMUSG00000064336
# ...                       ...                  ...                 ...
# 183104384  cellular_component         Os12g0514500  ENSMUSG00000026938
# 183104385  cellular_component         Os12g0530100  ENSMUSG00000026938
# 183104386  cellular_component         Os12g0546800  ENSMUSG00000026938
# 183104387  cellular_component         Os12g0563700  ENSMUSG00000026938
# 183104388  cellular_component         Os12g0578400  ENSMUSG00000026938
#
# [75584318 rows x 5 columns]
#           GOSlim GOA Accession(s) GOSlim GOA Description       GOSlim_domain  \
# 0                      GO:0003723            RNA binding  molecular_function
# 1                      GO:0003723            RNA binding  molecular_function
# 2                      GO:0003723            RNA binding  molecular_function
# 3                      GO:0003723            RNA binding  molecular_function
# 4                      GO:0003723            RNA binding  molecular_function
# ...                           ...                    ...                 ...
# 182930233              GO:0008289          lipid binding  molecular_function
# 182930234              GO:0008289          lipid binding  molecular_function
# 182930235              GO:0008289          lipid binding  molecular_function
# 182930236              GO:0008289          lipid binding  molecular_function
# 182930237              GO:0008289          lipid binding  molecular_function
#
#           Gene stable ID_human Gene stable ID_rice
# 0                 Os01g0100700  ENSMUSG00000064336
# 1                 Os01g0101150  ENSMUSG00000064336
# 2                 Os01g0101300  ENSMUSG00000064336
# 3                 Os01g0101600  ENSMUSG00000064336
# 4                 Os01g0118100  ENSMUSG00000064336
# ...                        ...                 ...
# 182930233         Os12g0555100  ENSMUSG00000019715
# 182930234         Os12g0555200  ENSMUSG00000019715
# 182930235         Os12g0555300  ENSMUSG00000019715
# 182930236         Os12g0555500  ENSMUSG00000019715
# 182930237         Os12g0612700  ENSMUSG00000019715
#
# [86287151 rows x 5 columns]
#           GOSlim GOA Accession(s)  \
# 63914407               GO:0006091
# 63914408               GO:0006091
# 63914409               GO:0006091
# 63914410               GO:0006091
# 63914411               GO:0006091
# ...                           ...
# 162934448              GO:0005975
# 162934449              GO:0005975
# 162934450              GO:0005975
# 162934451              GO:0005975
# 162934452              GO:0005975
#
#                                    GOSlim GOA Description       GOSlim_domain  \
# 63914407   generation of precursor metabolites and energy  biological_process
# 63914408   generation of precursor metabolites and energy  biological_process
# 63914409   generation of precursor metabolites and energy  biological_process
# 63914410   generation of precursor metabolites and energy  biological_process
# 63914411   generation of precursor metabolites and energy  biological_process
# ...                                                   ...                 ...
# 162934448                  carbohydrate metabolic process  biological_process
# 162934449                  carbohydrate metabolic process  biological_process
# 162934450                  carbohydrate metabolic process  biological_process
# 162934451                  carbohydrate metabolic process  biological_process
# 162934452                  carbohydrate metabolic process  biological_process
#
#           Gene stable ID_human Gene stable ID_rice
# 63914407          Os01g0110700  ENSMUSG00000064341
# 63914408          Os01g0118000  ENSMUSG00000064341
# 63914409          Os01g0147900  ENSMUSG00000064341
# 63914410          Os01g0174900  ENSMUSG00000064341
# 63914411          Os01g0190400  ENSMUSG00000064341
# ...                        ...                 ...
# 162934448         Os12g0616900  ENSMUSG00000027207
# 162934449         Os12g0632700  ENSMUSG00000027207
# 162934450         Os12g0633000  ENSMUSG00000027207
# 162934451         Os12g0641400  ENSMUSG00000027207
# 162934452          gene-orf241  ENSMUSG00000027207
#
# [21232920 rows x 5 columns]
