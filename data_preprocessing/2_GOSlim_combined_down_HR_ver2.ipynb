# %% [markdown]
# ## Discription
#
# ### Background
# Circos plotの描画の処理内で行われている結合をこちらのファイルで行うことを目的に作成しました

# %%
import collections
import csv
import datetime
import os
import pandas as pd
import numpy as np
from collections import Counter

# %%
# output directory
organism1_vs_organism2 = "HR" # human vs rice
direction = "down"
now = datetime.datetime.now()
circos_dir = f'../data/circos_{direction}_{organism1_vs_organism2}_{now.strftime("%y%m")}'
no_annotation = f'../data/{circos_dir}/no_annotation_{direction}'
os.makedirs(circos_dir, exist_ok=True)
os.makedirs(no_annotation, exist_ok=True)

# %% [markdown]
# ## HUMAN_DOWN
#
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#
# 2. Extract GOSlim corresponding to the list of up-regulated genes

# %%
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#organism = "human" (H)
df_h_score = pd.read_csv(f"../data/human_annotation/human_position_{direction}.tsv", sep='\t')
df_h_score_subset = df_h_score[['Gene stable ID', # create a subset
                        'Chromosome/scaffold name', 
                        'start2 (bp)',
                        'end2 (bp)',
                        'HN-score(HN5)']].copy()
df_h_score_subset['Chromosome/scaffold name'] = 'H_' + df_h_score_subset['Chromosome/scaffold name'].astype(str)
df_h_score_subset['organism'] = 'human'# assign the tag

df_h_score_subset.to_csv(f"../data/{circos_dir}/human_position_{direction}_assign.tsv", sep='\t', index=False)

display(df_h_score_subset)
# Out:
#       Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 0    ENSG00000170473                     H_12     55901413   55932618
# 1    ENSG00000184675                      H_X     64185117   64205708
# 2    ENSG00000161653                     H_17     44004622   44009068
# 3    ENSG00000100281                     H_22     35257452   35295807
# 4    ENSG00000132773                      H_1     45340052   45343973
# ..               ...                      ...          ...        ...
# 199  ENSG00000102921                     H_16     48538726   48620148
# 200  ENSG00000179922                     H_19     55620741   55624566
# 201  ENSG00000162526                      H_1     32351521   32364312
# 202  ENSG00000196196                      H_9     35906202   35907136
# 203  ENSG00000124575                      H_6     26234212   26234987
#
#      HN-score(HN5) organism
# 0              -14    human
# 1              -14    human
# 2              -14    human
# 3              -14    human
# 4              -14    human
# ..             ...      ...
# 199            -41    human
# 200            -42    human
# 201            -43    human
# 202            -52    human
# 203            -71    human
#
# [204 rows x 6 columns]

# %%
# 2. Extract GOSlim corresponding to the list of up-regulated genes
goslim_all_human = pd.read_csv('../data/biomart_goslim/biomart_human_goslim_R110_domain.tsv', sep='\t',
                               dtype={'Gene stable ID': 'object'}, 
                               low_memory=False)
columns_of_interest_human = ['Gene stable ID', 
                             'GOSlim GOA Accession(s)', 
                             'GOSlim GOA Description', 
                             'GOSlim_domain']
goslim_all_human_filtered = goslim_all_human[columns_of_interest_human]

extract_df_h_goslim = pd.merge(
    df_h_score_subset, 
    goslim_all_human_filtered, 
    on='Gene stable ID', 
    how='inner'
    )
extract_df_h_goslim = extract_df_h_goslim.drop_duplicates(subset=['Gene stable ID',
                                                                  'GOSlim GOA Accession(s)', 
                                                                  'GOSlim GOA Description'], keep='first').copy()

# Extract genes with no annotations
extract_df_h_goslim_with_indicator = pd.merge(
    df_h_score_subset, 
    goslim_all_human_filtered,
    left_on='Gene stable ID',
    right_on='Gene stable ID',
    how='left',
    indicator=True # add indicator column to show the difference
)

# extract_df_h_goslim_with_indicator
left_only_rows = extract_df_h_goslim_with_indicator[extract_df_h_goslim_with_indicator['_merge'] == 'left_only']

extract_df_h_goslim.to_csv(f"../data/{circos_dir}/human_goslim_{direction}.tsv", sep='\t', index=False)
left_only_rows.to_csv(f"../data/{no_annotation}/human_position_down_no_annotation.tsv", sep='\t', index=False)

display(goslim_all_human_filtered, extract_df_h_goslim, left_only_rows)
# Out:
#          Gene stable ID GOSlim GOA Accession(s)  \
# 0       ENSG00000243485              GO:0031047
# 1       ENSG00000284332              GO:0031047
# 2       ENSG00000186092              GO:0023052
# 3       ENSG00000186092              GO:0060089
# 4       ENSG00000186092              GO:0005886
# ...                 ...                     ...
# 193923  ENSG00000292372              GO:0007010
# 193924  ENSG00000292372              GO:0008092
# 193925  ENSG00000292372              GO:0031410
# 193926  ENSG00000292372              GO:0043226
# 193927  ENSG00000292372              GO:0005768
#
#                GOSlim GOA Description       GOSlim_domain
# 0               gene silencing by RNA  biological_process
# 1               gene silencing by RNA  biological_process
# 2                           signaling  biological_process
# 3       molecular transducer activity  molecular_function
# 4                     plasma membrane  cellular_component
# ...                               ...                 ...
# 193923      cytoskeleton organization  biological_process
# 193924   cytoskeletal protein binding  molecular_function
# 193925            cytoplasmic vesicle  cellular_component
# 193926                      organelle  cellular_component
# 193927                       endosome  cellular_component
#
# [193928 rows x 4 columns]
#        Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 0     ENSG00000170473                     H_12     55901413   55932618
# 1     ENSG00000170473                     H_12     55901413   55932618
# 2     ENSG00000170473                     H_12     55901413   55932618
# 3     ENSG00000170473                     H_12     55901413   55932618
# 4     ENSG00000170473                     H_12     55901413   55932618
# ...               ...                      ...          ...        ...
# 1666  ENSG00000124575                      H_6     26234212   26234987
# 1667  ENSG00000124575                      H_6     26234212   26234987
# 1668  ENSG00000124575                      H_6     26234212   26234987
# 1669  ENSG00000124575                      H_6     26234212   26234987
# 1670  ENSG00000124575                      H_6     26234212   26234987
#
#       HN-score(HN5) organism GOSlim GOA Accession(s)  \
# 0               -14    human              GO:0043226
# 1               -14    human              GO:0005634
# 2               -14    human              GO:0003723
# 3               -14    human              GO:0016071
# 4               -14    human              GO:0005654
# ...             ...      ...                     ...
# 1666            -71    human              GO:0005634
# 1667            -71    human              GO:0003723
# 1668            -71    human              GO:0006310
# 1669            -71    human              GO:0006351
# 1670            -71    human              GO:0006355
#
#                          GOSlim GOA Description       GOSlim_domain
# 0                                     organelle  cellular_component
# 1                                       nucleus  cellular_component
# 2                                   RNA binding  molecular_function
# 3                        mRNA metabolic process  biological_process
# 4                                   nucleoplasm  cellular_component
# ...                                         ...                 ...
# 1666                                    nucleus  cellular_component
# 1667                                RNA binding  molecular_function
# 1668                          DNA recombination  biological_process
# 1669                DNA-templated transcription  biological_process
# 1670  regulation of DNA-templated transcription  biological_process
#
# [1671 rows x 9 columns]
#        Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 406   ENSG00000176092                      H_1     26321698   26360080
# 439   ENSG00000182359                     H_11    106051098  106077459
# 475   ENSG00000234409                     H_22     20148416   20151055
# 503   ENSG00000186118                      H_1     46668855   46673594
# 621   ENSG00000125089                      H_4      8182072    8241803
# 674   ENSG00000187808                      H_X    119758588  119760202
# 743   ENSG00000167183                     H_17     47951967   47957883
# 749   ENSG00000175449                      H_5     95646777   95684773
# 885   ENSG00000179023                      H_1     18480930   18485974
# 936   ENSG00000179476                     H_14     44897275   44907257
# 945   ENSG00000158792                     H_16     89696357   89701705
# 1259  ENSG00000176125                      H_7    100888721  100889715
# 1268  ENSG00000275183                     H_19     54461732   54463778
# 1622  ENSG00000177352                      H_3     49162535   49166331
# 1635  ENSG00000228727                      H_6     31762656   31764850
# 1675  ENSG00000196196                      H_9     35906202   35907136
#
#       HN-score(HN5) organism GOSlim GOA Accession(s) GOSlim GOA Description  \
# 406             -15    human                     NaN                    NaN
# 439             -15    human                     NaN                    NaN
# 475             -15    human                     NaN                    NaN
# 503             -15    human                     NaN                    NaN
# 621             -16    human                     NaN                    NaN
# 674             -16    human                     NaN                    NaN
# 743             -17    human                     NaN                    NaN
# 749             -17    human                     NaN                    NaN
# 885             -18    human                     NaN                    NaN
# 936             -19    human                     NaN                    NaN
# 945             -19    human                     NaN                    NaN
# 1259            -22    human                     NaN                    NaN
# 1268            -22    human                     NaN                    NaN
# 1622            -31    human                     NaN                    NaN
# 1635            -32    human                     NaN                    NaN
# 1675            -52    human                     NaN                    NaN
#
#      GOSlim_domain     _merge
# 406            NaN  left_only
# 439            NaN  left_only
# 475            NaN  left_only
# 503            NaN  left_only
# 621            NaN  left_only
# 674            NaN  left_only
# 743            NaN  left_only
# 749            NaN  left_only
# 885            NaN  left_only
# 936            NaN  left_only
# 945            NaN  left_only
# 1259           NaN  left_only
# 1268           NaN  left_only
# 1622           NaN  left_only
# 1635           NaN  left_only
# 1675           NaN  left_only

# %% [markdown]
# ## RICE_down
#
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#
# 2. Extract GOSlim corresponding to the list of up-regulated genes

# %%
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
df_r_score = pd.read_csv(f'../data/rice_annotation/rice_position_{direction}.tsv', sep='\t')
df_r_score_subset = df_r_score[['Gene stable ID', # create a subset
                        'Chromosome/scaffold name', 
                        'start1 (bp)',
                        'end1 (bp)',
                        'HN-score(HN5)']].copy()
df_r_score_subset['Chromosome/scaffold name'] = 'R_' + df_r_score_subset['Chromosome/scaffold name'].astype(str)
df_r_score_subset['organism'] = 'rice'# assign the tag

df_r_score_subset.to_csv(f"../data/{circos_dir}/rice_position_{direction}_assign.tsv", sep='\t', index=False)

display(df_r_score_subset)
# Out:
#     Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0     Os01g0136300                      R_1      1955181    1955914
# 1     Os05g0588225                      R_5     29307170   29307793
# 2     Os03g0358800                      R_3     13915940   13917546
# 3     Os06g0157900                      R_6      2947702    2948085
# 4     Os11g0439600                     R_11     14390405   14398122
# ..             ...                      ...          ...        ...
# 379   Os01g0952800                      R_1     41971444   41978093
# 380   Os07g0142100                      R_7      2175193    2175719
# 381   Os03g0307200                      R_3     10926469   10927729
# 382   Os07g0142200                      R_7      2176824    2177640
# 383   Os03g0307300                      R_3     10929507   10930895
#
#      HN-score(HN5) organism
# 0              -40     rice
# 1              -40     rice
# 2              -40     rice
# 3              -40     rice
# 4              -40     rice
# ..             ...      ...
# 379           -173     rice
# 380           -178     rice
# 381           -182     rice
# 382           -189     rice
# 383           -196     rice
#
# [384 rows x 6 columns]

# %%
# 2. Extract GOSlim corresponding to the list of up-regulated genes
goslim_all_rice = pd.read_csv('../data/biomart_goslim/biomart_rice_goslim_R56_domain.tsv', sep='\t',
                               dtype={'Gene stable ID': 'object'}, 
                               low_memory=False)
columns_of_interest_rice = ['Gene stable ID',
                            'GOSlim GOA Accession(s)', 
                            'GOSlim GOA Description', 
                            'GOSlim_domain']
goslim_all_rice_filtered = goslim_all_rice[columns_of_interest_rice]

extract_df_r_goslim = pd.merge(
    df_r_score_subset, 
    goslim_all_rice_filtered, 
    on='Gene stable ID', 
    how='inner'
    )

extract_df_r_goslim = extract_df_r_goslim.drop_duplicates(subset=['Gene stable ID',
                                                                    'GOSlim GOA Accession(s)', 
                                                                    'GOSlim GOA Description'], keep='first').copy()

# Extract genes with no annotations
extract_df_r_goslim_with_indicator = pd.merge(
    df_r_score_subset, 
    goslim_all_rice_filtered,
    left_on='Gene stable ID',
    right_on='Gene stable ID',
    how='left',
    indicator=True # add indicator column to show the difference
)

# extract_df_r_goslim_with_indicator
left_only_rows = extract_df_r_goslim_with_indicator[extract_df_r_goslim_with_indicator['_merge'] == 'left_only']

extract_df_r_goslim.to_csv(f"../data/{circos_dir}/rice_goslim_{direction}.tsv", sep='\t', index=False)
left_only_rows.to_csv(f"../data/{no_annotation}/rice_position_{direction}_no_annotation.tsv", sep='\t', index=False)

display(goslim_all_rice_filtered, extract_df_r_goslim, left_only_rows)
# Out:
#        Gene stable ID GOSlim GOA Accession(s)        GOSlim GOA Description  \
# 0        Os01g0100100              GO:0006810                     transport
# 1        Os01g0100100              GO:0008150            biological_process
# 2        Os01g0100100              GO:0009987              cellular process
# 3        Os01g0100100              GO:0003674            molecular_function
# 4        Os01g0100100              GO:0030234     enzyme regulator activity
# ...               ...                     ...                           ...
# 219494     gene-rps19              GO:0003674            molecular_function
# 219495     gene-rps19              GO:0005198  structural molecule activity
# 219496     gene-rps19              GO:0005488                       binding
# 219497     gene-rps19              GO:0003723                   RNA binding
# 219498     gene-rps19              GO:0003676          nucleic acid binding
#
#              GOSlim_domain
# 0       biological_process
# 1       biological_process
# 2       biological_process
# 3       molecular_function
# 4       molecular_function
# ...                    ...
# 219494  molecular_function
# 219495  molecular_function
# 219496  molecular_function
# 219497  molecular_function
# 219498  molecular_function
#
# [219499 rows x 4 columns]
#      Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0      Os03g0358800                      R_3     13915940   13917546
# 1      Os03g0358800                      R_3     13915940   13917546
# 2      Os03g0358800                      R_3     13915940   13917546
# 3      Os03g0358800                      R_3     13915940   13917546
# 4      Os03g0358800                      R_3     13915940   13917546
# ...             ...                      ...          ...        ...
# 2028   Os03g0307300                      R_3     10929507   10930895
# 2029   Os03g0307300                      R_3     10929507   10930895
# 2030   Os03g0307300                      R_3     10929507   10930895
# 2031   Os03g0307300                      R_3     10929507   10930895
# 2032   Os03g0307300                      R_3     10929507   10930895
#
#       HN-score(HN5) organism GOSlim GOA Accession(s)  \
# 0               -40     rice              GO:0005575
# 1               -40     rice              GO:0005622
# 2               -40     rice              GO:0003674
# 3               -40     rice              GO:0003824
# 4               -40     rice              GO:0016740
# ...             ...      ...                     ...
# 2028           -196     rice              GO:0016740
# 2029           -196     rice              GO:0008150
# 2030           -196     rice              GO:0009987
# 2031           -196     rice              GO:0008152
# 2032           -196     rice              GO:0009058
#
#                   GOSlim GOA Description       GOSlim_domain
# 0                     cellular_component  cellular_component
# 1     intracellular anatomical structure  cellular_component
# 2                     molecular_function  molecular_function
# 3                     catalytic activity  molecular_function
# 4                   transferase activity  molecular_function
# ...                                  ...                 ...
# 2028                transferase activity  molecular_function
# 2029                  biological_process  biological_process
# 2030                    cellular process  biological_process
# 2031                   metabolic process  biological_process
# 2032                biosynthetic process  biological_process
#
# [2033 rows x 9 columns]
#      Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0      Os01g0136300                      R_1      1955181    1955914
# 1      Os05g0588225                      R_5     29307170   29307793
# 24     Os07g0600200                      R_7     24487821   24488449
# 25     Os08g0178650                      R_8      4597056    4597381
# 32     Os02g0565150                      R_2     21457944   21458344
# ...             ...                      ...          ...        ...
# 2124   Os01g0647200                      R_1     26086062   26088337
# 2132   Os02g0594166                      R_2     23008659   23011091
# 2133   Os01g0608101                      R_1     24004176   24006793
# 2157   Os07g0142100                      R_7      2175193    2175719
# 2165   Os07g0142200                      R_7      2176824    2177640
#
#       HN-score(HN5) organism GOSlim GOA Accession(s) GOSlim GOA Description  \
# 0               -40     rice                     NaN                    NaN
# 1               -40     rice                     NaN                    NaN
# 24              -40     rice                     NaN                    NaN
# 25              -40     rice                     NaN                    NaN
# 32              -40     rice                     NaN                    NaN
# ...             ...      ...                     ...                    ...
# 2124           -165     rice                     NaN                    NaN
# 2132           -170     rice                     NaN                    NaN
# 2133           -171     rice                     NaN                    NaN
# 2157           -178     rice                     NaN                    NaN
# 2165           -189     rice                     NaN                    NaN
#
#      GOSlim_domain     _merge
# 0              NaN  left_only
# 1              NaN  left_only
# 24             NaN  left_only
# 25             NaN  left_only
# 32             NaN  left_only
# ...            ...        ...
# 2124           NaN  left_only
# 2132           NaN  left_only
# 2133           NaN  left_only
# 2157           NaN  left_only
# 2165           NaN  left_only
#
# [140 rows x 10 columns]

# %% [markdown]
# ## COMBINED_UP( HUMAN_UP + RICE_UP )
#
# 1. chromosome position + gene position + HN-score
#
# 2. GOslim terms corresponding to the list of up-regulated genes

# %%
# 1. chromosome position + gene position + HN-score
combined_df_score = pd.concat([df_h_score_subset, 
                               df_r_score_subset])
combined_df_score.reset_index(drop=True, inplace=True)
combined_df_score['Gene start (bp)'] = combined_df_score['start1 (bp)'].combine_first(combined_df_score['start2 (bp)'])
combined_df_score['Gene end (bp)'] = combined_df_score['end1 (bp)'].combine_first(combined_df_score['end2 (bp)'])
combined_df_score.drop(['start1 (bp)', 'start2 (bp)', 'end1 (bp)', 'end2 (bp)'], axis=1, inplace=True)

combined_df_score.to_csv(f"../data/{circos_dir}/combined_position_{direction}.tsv", sep='\t', index=False)

display(combined_df_score)
# Out:
#       Gene stable ID Chromosome/scaffold name  HN-score(HN5) organism  \
# 0    ENSG00000170473                     H_12            -14    human
# 1    ENSG00000184675                      H_X            -14    human
# 2    ENSG00000161653                     H_17            -14    human
# 3    ENSG00000100281                     H_22            -14    human
# 4    ENSG00000132773                      H_1            -14    human
# ..               ...                      ...            ...      ...
# 583     Os01g0952800                      R_1           -173     rice
# 584     Os07g0142100                      R_7           -178     rice
# 585     Os03g0307200                      R_3           -182     rice
# 586     Os07g0142200                      R_7           -189     rice
# 587     Os03g0307300                      R_3           -196     rice
#
#      Gene start (bp)  Gene end (bp)
# 0         55901413.0     55932618.0
# 1         64185117.0     64205708.0
# 2         44004622.0     44009068.0
# 3         35257452.0     35295807.0
# 4         45340052.0     45343973.0
# ..               ...            ...
# 583       41971444.0     41978093.0
# 584        2175193.0      2175719.0
# 585       10926469.0     10927729.0
# 586        2176824.0      2177640.0
# 587       10929507.0     10930895.0
#
# [588 rows x 6 columns]

# %%
merged_df_goslim = pd.merge(
    extract_df_h_goslim, 
    extract_df_r_goslim, 
    left_on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'],
    right_on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'],
    how='inner',
    suffixes=('_human', '_rice')
)

merged_df_goslim = merged_df_goslim[['GOSlim GOA Accession(s)',
                                     'GOSlim GOA Description',
                                     'GOSlim_domain',
                                     'Gene stable ID_rice',
                                     'Gene stable ID_human',
                                     'Chromosome/scaffold name_rice',
                                     'start1 (bp)',
                                     'end1 (bp)',
                                     'Chromosome/scaffold name_human',
                                     'start2 (bp)',
                                     'end2 (bp)',
                                     'HN-score(HN5)_rice',
                                     'HN-score(HN5)_human']]

# Remove duplicate rows based on specific columns
merged_df_goslim.drop_duplicates(inplace=True)

display(merged_df_goslim)
# Out:
#       GOSlim GOA Accession(s)            GOSlim GOA Description  \
# 0                  GO:0005634                           nucleus
# 1                  GO:0005634                           nucleus
# 2                  GO:0005634                           nucleus
# 3                  GO:0005634                           nucleus
# 4                  GO:0005634                           nucleus
# ...                       ...                               ...
# 18457              GO:0030312  external encapsulating structure
# 18458              GO:0030312  external encapsulating structure
# 18459              GO:0030312  external encapsulating structure
# 18460              GO:0030312  external encapsulating structure
# 18461              GO:0030312  external encapsulating structure
#
#             GOSlim_domain Gene stable ID_rice Gene stable ID_human  \
# 0      cellular_component        Os02g0204400      ENSG00000170473
# 1      cellular_component        Os01g0772100      ENSG00000170473
# 2      cellular_component        Os03g0634400      ENSG00000170473
# 3      cellular_component        Os03g0617500      ENSG00000170473
# 4      cellular_component        Os03g0162200      ENSG00000170473
# ...                   ...                 ...                  ...
# 18457  cellular_component        Os02g0783000      ENSG00000111186
# 18458  cellular_component        Os06g0193200      ENSG00000111186
# 18459  cellular_component        Os09g0472900      ENSG00000111186
# 18460  cellular_component        Os01g0284500      ENSG00000111186
# 18461  cellular_component        Os03g0651800      ENSG00000111186
#
#       Chromosome/scaffold name_rice  start1 (bp)  end1 (bp)  \
# 0                               R_2      5835504    5838694
# 1                               R_1     32592931   32593952
# 2                               R_3     24226372   24227930
# 3                               R_3     23410223   23412753
# 4                               R_3      3371375    3372344
# ...                             ...          ...        ...
# 18457                           R_2     33221378   33223595
# 18458                           R_6      4700512    4703042
# 18459                           R_9     18067436   18068411
# 18460                           R_1     10167946   10168997
# 18461                           R_3     25315697   25317065
#
#       Chromosome/scaffold name_human  start2 (bp)  end2 (bp)  \
# 0                               H_12     55901413   55932618
# 1                               H_12     55901413   55932618
# 2                               H_12     55901413   55932618
# 3                               H_12     55901413   55932618
# 4                               H_12     55901413   55932618
# ...                              ...          ...        ...
# 18457                           H_12      1529891    1647212
# 18458                           H_12      1529891    1647212
# 18459                           H_12      1529891    1647212
# 18460                           H_12      1529891    1647212
# 18461                           H_12      1529891    1647212
#
#        HN-score(HN5)_rice  HN-score(HN5)_human
# 0                     -41                  -14
# 1                     -42                  -14
# 2                     -43                  -14
# 3                     -44                  -14
# 4                     -45                  -14
# ...                   ...                  ...
# 18457                 -45                  -17
# 18458                 -45                  -17
# 18459                 -47                  -17
# 18460                 -52                  -17
# 18461                 -68                  -17
#
# [18462 rows x 13 columns]

# %%
# for debugging purpose
unique_accessions_r = set(extract_df_r_goslim['GOSlim GOA Accession(s)'].unique())
unique_accessions_h = set(extract_df_h_goslim['GOSlim GOA Accession(s)'].unique())
common_accessions = unique_accessions_r.intersection(unique_accessions_h)
unique_accessions_merged = set(merged_df_goslim['GOSlim GOA Accession(s)'].unique())
missing_accessions = common_accessions.difference(unique_accessions_merged)
duplicates = merged_df_goslim.duplicated(subset=['GOSlim GOA Accession(s)', 'Gene stable ID_rice', 'Gene stable ID_human'], keep=False)
unique_combinations = not duplicates.any()
print(f"Number of common accessions: {len(common_accessions)}")
print(f"Number of missing accessions: {len(missing_accessions)}")
print(f"Missing accessions: {missing_accessions}")
print(f"各'Gene stable ID_rice'と'Gene stable ID_human'の組み合わせはユニークですか？: {unique_combinations}")

#Count the occurrences of each 'GOSlim GOA Accession(s)'
accession_counter = Counter(merged_df_goslim['GOSlim GOA Accession(s)'])

#Sort the DataFrame based on the counts
merged_df_goslim['count'] = merged_df_goslim['GOSlim GOA Accession(s)'].map(accession_counter)
merged_df_goslim_sorted = merged_df_goslim.sort_values('count', ascending=False).drop('count', axis=1)
merged_df_goslim_sorted.reset_index(drop=True, inplace=True)
merged_df_goslim_sorted.to_csv(f"../data/{circos_dir}/combined_goslim_{direction}.tsv", sep='\t', index=False)

display(merged_df_goslim_sorted)
# Out:
# Number of common accessions: 26
# Number of missing accessions: 0
# Missing accessions: set()
# 各'Gene stable ID_rice'と'Gene stable ID_human'の組み合わせはユニークですか？: True
#       GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0                  GO:0003824                              catalytic activity
# 1                  GO:0003824                              catalytic activity
# 2                  GO:0003824                              catalytic activity
# 3                  GO:0003824                              catalytic activity
# 4                  GO:0003824                              catalytic activity
# ...                       ...                                             ...
# 18457              GO:0006091  generation of precursor metabolites and energy
# 18458              GO:0030312                external encapsulating structure
# 18459              GO:0005635                                nuclear envelope
# 18460              GO:0005635                                nuclear envelope
# 18461              GO:0005635                                nuclear envelope
#
#             GOSlim_domain Gene stable ID_rice Gene stable ID_human  \
# 0      molecular_function        Os02g0504000      ENSG00000142731
# 1      molecular_function        Os02g0121700      ENSG00000151117
# 2      molecular_function        Os02g0571100      ENSG00000151117
# 3      molecular_function        Os05g0360400      ENSG00000151117
# 4      molecular_function        Os11g0641500      ENSG00000151117
# ...                   ...                 ...                  ...
# 18457  biological_process        Os06g0718400      ENSG00000213689
# 18458  cellular_component        Os03g0651800      ENSG00000111186
# 18459  cellular_component        Os12g0236100      ENSG00000213689
# 18460  cellular_component        Os12g0236100      ENSG00000205808
# 18461  cellular_component        Os12g0236100      ENSG00000151353
#
#       Chromosome/scaffold name_rice  start1 (bp)  end1 (bp)  \
# 0                               R_2     17880882   17886285
# 1                               R_2      1145837    1151052
# 2                               R_2     21841092   21847545
# 3                               R_5     17175702   17176974
# 4                              R_11     25423701   25426045
# ...                             ...          ...        ...
# 18457                           R_6     30528045   30529070
# 18458                           R_3     25315697   25317065
# 18459                          R_12      7441389    7446142
# 18460                          R_12      7441389    7446142
# 18461                          R_12      7441389    7446142
#
#       Chromosome/scaffold name_human  start2 (bp)  end2 (bp)  \
# 0                                H_4    127880893  127899224
# 1                               H_11     18693122   18704785
# 2                               H_11     18693122   18704785
# 3                               H_11     18693122   18704785
# 4                               H_11     18693122   18704785
# ...                              ...          ...        ...
# 18457                            H_3     48465811   48467645
# 18458                           H_12      1529891    1647212
# 18459                            H_3     48465811   48467645
# 18460                            H_9      4662294    4665258
# 18461                            H_2       663877     677406
#
#        HN-score(HN5)_rice  HN-score(HN5)_human
# 0                     -84                  -17
# 1                     -59                  -16
# 2                     -53                  -16
# 3                     -54                  -16
# 4                     -54                  -16
# ...                   ...                  ...
# 18457                 -89                  -28
# 18458                 -68                  -17
# 18459                 -81                  -28
# 18460                 -81                  -18
# 18461                 -81                  -15
#
# [18462 rows x 13 columns]

# %% [markdown]
# ## Merge GOslim terms and line enrichment results

# %%
enrichment = pd.read_csv(f'../data/line_enrichment_{direction}_HR_2311/goslim_correspondence_q_values_{direction}_HR/goslim_correspondence_fold_enrichment_p_q_{direction}.tsv', sep='\t')

merged_df_goslim_sorted["GOSlim"] = merged_df_goslim_sorted['GOSlim GOA Accession(s)'] + ": " + merged_df_goslim_sorted['GOSlim GOA Description']

merged_df_goslim_sorted = merged_df_goslim_sorted[['GOSlim',
                                                    'GOSlim GOA Accession(s)',
                                                    'GOSlim GOA Description',
                                                    'GOSlim_domain',
                                                    'Gene stable ID_rice',
                                                    'Gene stable ID_human',
                                                    'Chromosome/scaffold name_rice',
                                                    'start1 (bp)',
                                                    'end1 (bp)',
                                                    'Chromosome/scaffold name_human',
                                                    'start2 (bp)',
                                                    'end2 (bp)',
                                                    'HN-score(HN5)_rice',
                                                    'HN-score(HN5)_human']]


merged_df_goslim_enrichment = pd.merge(
    merged_df_goslim_sorted,
    enrichment[['GOSlim', f'counts_{direction}', 'fold_enrichment', 'p_value', 'q_value']],
    on='GOSlim',
    how='left'
)
merged_df_goslim_enrichment.sort_values('fold_enrichment', ascending=False, inplace=True)
merged_df_goslim_enrichment.reset_index(drop=True, inplace=True)
merged_df_goslim_enrichment.to_csv(f"../data/{circos_dir}/combined_goslim_enrichment_{direction}.tsv", sep='\t', index=False)

display(enrichment, merged_df_goslim_sorted, merged_df_goslim_enrichment)
# Out:
#                                                GOSlim       GOSlim_domain  \
# 0                                GO:0005764: lysosome  cellular_component
# 1                           GO:0008289: lipid binding  molecular_function
# 2          GO:0005975: carbohydrate metabolic process  biological_process
# 3                    GO:0005576: extracellular region  cellular_component
# 4                 GO:0006629: lipid metabolic process  biological_process
# 5                                 GO:0005773: vacuole  cellular_component
# 6                      GO:0016787: hydrolase activity  molecular_function
# 7                      GO:0003824: catalytic activity  molecular_function
# 8                             GO:0003677: DNA binding  molecular_function
# 9                    GO:0016740: transferase activity  molecular_function
# 10       GO:0140110: transcription regulator activity  molecular_function
# 11                        GO:0005886: plasma membrane  cellular_component
# 12       GO:0048856: anatomical structure development  biological_process
# 13                   GO:0030154: cell differentiation  biological_process
# 14                                GO:0005829: cytosol  cellular_component
# 15                       GO:0005635: nuclear envelope  cellular_component
# 16       GO:0030312: external encapsulating structure  cellular_component
# 17                                GO:0005634: nucleus  cellular_component
# 18           GO:0036211: protein modification process  biological_process
# 19  GO:0006091: generation of precursor metabolite...  biological_process
# 20                   GO:0005215: transporter activity  molecular_function
# 21           GO:0005198: structural molecule activity  molecular_function
# 22                           GO:0005856: cytoskeleton  cellular_component
# 23                          GO:0005739: mitochondrion  cellular_component
# 24                        GO:0005794: Golgi apparatus  cellular_component
# 25                  GO:0005783: endoplasmic reticulum  cellular_component
#
#     counts_down  counts_all  down_ratio  all_ratio  fold_enrichment  \
# 0            21       45237    0.001137   0.000220         5.178879
# 1            64      257535    0.003467   0.001250         2.772388
# 2           153      676139    0.008287   0.003283         2.524444
# 3           870     3845282    0.047124   0.018670         2.524069
# 4           204     1517670    0.011050   0.007369         1.499557
# 5            54      422166    0.002925   0.002050         1.426989
# 6          1107     8674587    0.059961   0.042117         1.423669
# 7          7998    62834292    0.433214   0.305076         1.420021
# 8           672     5819761    0.036399   0.028256         1.288173
# 9          1080    10856023    0.058499   0.052709         1.109847
# 10          200     2256826    0.010833   0.010957         0.988649
# 11         1230    14121523    0.066623   0.068563         0.971704
# 12          590     7216908    0.031958   0.035040         0.912034
# 13           94     1272360    0.005092   0.006178         0.824191
# 14          567     7811118    0.030712   0.037925         0.809804
# 15            3       50592    0.000162   0.000246         0.661530
# 16           12      203467    0.000650   0.000988         0.657957
# 17         2790    50586355    0.151121   0.245609         0.615292
# 18          555    11265607    0.030062   0.054697         0.549602
# 19           12      265631    0.000650   0.001290         0.503979
# 20           84     1929898    0.004550   0.009370         0.485574
# 21           28      650310    0.001517   0.003157         0.480339
# 22           24      725760    0.001300   0.003524         0.368917
# 23           22     1951236    0.001192   0.009474         0.125783
# 24           15     1563150    0.000812   0.007589         0.107053
# 25           13     1919256    0.000704   0.009318         0.075565
#
#           p_value        q_value
# 0    2.405986e-09   1.168622e-08
# 1    1.956956e-12   1.330730e-11
# 2    1.642043e-23   1.395737e-22
# 3   2.046157e-127  3.478467e-126
# 4    2.974814e-08   1.264296e-07
# 5    7.697182e-03   2.617042e-02
# 6    3.160887e-30   3.582339e-29
# 7   2.079914e-294  7.071707e-293
# 8    8.590193e-11   4.867776e-10
# 9    2.787134e-04   1.052917e-03
# 10   5.740091e-01   1.000000e+00
# 11   8.550350e-01   1.000000e+00
# 12   9.899762e-01   1.000000e+00
# 13   9.759711e-01   1.000000e+00
# 14   9.999999e-01   1.000000e+00
# 15   8.303609e-01   1.000000e+00
# 16   9.507781e-01   1.000000e+00
# 17   1.000000e+00   1.000000e+00
# 18   1.000000e+00   1.000000e+00
# 19   9.972028e-01   1.000000e+00
# 20   1.000000e+00   1.000000e+00
# 21   9.999963e-01   1.000000e+00
# 22   1.000000e+00   1.000000e+00
# 23   1.000000e+00   1.000000e+00
# 24   1.000000e+00   1.000000e+00
# 25   1.000000e+00   1.000000e+00
#                                                   GOSlim  \
# 0                         GO:0003824: catalytic activity
# 1                         GO:0003824: catalytic activity
# 2                         GO:0003824: catalytic activity
# 3                         GO:0003824: catalytic activity
# 4                         GO:0003824: catalytic activity
# ...                                                  ...
# 18457  GO:0006091: generation of precursor metabolite...
# 18458       GO:0030312: external encapsulating structure
# 18459                       GO:0005635: nuclear envelope
# 18460                       GO:0005635: nuclear envelope
# 18461                       GO:0005635: nuclear envelope
#
#       GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0                  GO:0003824                              catalytic activity
# 1                  GO:0003824                              catalytic activity
# 2                  GO:0003824                              catalytic activity
# 3                  GO:0003824                              catalytic activity
# 4                  GO:0003824                              catalytic activity
# ...                       ...                                             ...
# 18457              GO:0006091  generation of precursor metabolites and energy
# 18458              GO:0030312                external encapsulating structure
# 18459              GO:0005635                                nuclear envelope
# 18460              GO:0005635                                nuclear envelope
# 18461              GO:0005635                                nuclear envelope
#
#             GOSlim_domain Gene stable ID_rice Gene stable ID_human  \
# 0      molecular_function        Os02g0504000      ENSG00000142731
# 1      molecular_function        Os02g0121700      ENSG00000151117
# 2      molecular_function        Os02g0571100      ENSG00000151117
# 3      molecular_function        Os05g0360400      ENSG00000151117
# 4      molecular_function        Os11g0641500      ENSG00000151117
# ...                   ...                 ...                  ...
# 18457  biological_process        Os06g0718400      ENSG00000213689
# 18458  cellular_component        Os03g0651800      ENSG00000111186
# 18459  cellular_component        Os12g0236100      ENSG00000213689
# 18460  cellular_component        Os12g0236100      ENSG00000205808
# 18461  cellular_component        Os12g0236100      ENSG00000151353
#
#       Chromosome/scaffold name_rice  start1 (bp)  end1 (bp)  \
# 0                               R_2     17880882   17886285
# 1                               R_2      1145837    1151052
# 2                               R_2     21841092   21847545
# 3                               R_5     17175702   17176974
# 4                              R_11     25423701   25426045
# ...                             ...          ...        ...
# 18457                           R_6     30528045   30529070
# 18458                           R_3     25315697   25317065
# 18459                          R_12      7441389    7446142
# 18460                          R_12      7441389    7446142
# 18461                          R_12      7441389    7446142
#
#       Chromosome/scaffold name_human  start2 (bp)  end2 (bp)  \
# 0                                H_4    127880893  127899224
# 1                               H_11     18693122   18704785
# 2                               H_11     18693122   18704785
# 3                               H_11     18693122   18704785
# 4                               H_11     18693122   18704785
# ...                              ...          ...        ...
# 18457                            H_3     48465811   48467645
# 18458                           H_12      1529891    1647212
# 18459                            H_3     48465811   48467645
# 18460                            H_9      4662294    4665258
# 18461                            H_2       663877     677406
#
#        HN-score(HN5)_rice  HN-score(HN5)_human
# 0                     -84                  -17
# 1                     -59                  -16
# 2                     -53                  -16
# 3                     -54                  -16
# 4                     -54                  -16
# ...                   ...                  ...
# 18457                 -89                  -28
# 18458                 -68                  -17
# 18459                 -81                  -28
# 18460                 -81                  -18
# 18461                 -81                  -15
#
# [18462 rows x 14 columns]
#                                   GOSlim GOSlim GOA Accession(s)  \
# 0                   GO:0005764: lysosome              GO:0005764
# 1                   GO:0005764: lysosome              GO:0005764
# 2                   GO:0005764: lysosome              GO:0005764
# 3                   GO:0005764: lysosome              GO:0005764
# 4                   GO:0005764: lysosome              GO:0005764
# ...                                  ...                     ...
# 18457  GO:0005783: endoplasmic reticulum              GO:0005783
# 18458  GO:0005783: endoplasmic reticulum              GO:0005783
# 18459  GO:0005783: endoplasmic reticulum              GO:0005783
# 18460  GO:0005783: endoplasmic reticulum              GO:0005783
# 18461  GO:0005783: endoplasmic reticulum              GO:0005783
#
#       GOSlim GOA Description       GOSlim_domain Gene stable ID_rice  \
# 0                   lysosome  cellular_component        Os01g0613500
# 1                   lysosome  cellular_component        Os01g0971400
# 2                   lysosome  cellular_component        Os02g0715000
# 3                   lysosome  cellular_component        Os01g0613500
# 4                   lysosome  cellular_component        Os01g0613500
# ...                      ...                 ...                 ...
# 18457  endoplasmic reticulum  cellular_component        Os05g0482400
# 18458  endoplasmic reticulum  cellular_component        Os05g0482400
# 18459  endoplasmic reticulum  cellular_component        Os05g0482400
# 18460  endoplasmic reticulum  cellular_component        Os05g0482400
# 18461  endoplasmic reticulum  cellular_component        Os05g0482400
#
#       Gene stable ID_human Chromosome/scaffold name_rice  start1 (bp)  \
# 0          ENSG00000125538                           R_1     24343518
# 1          ENSG00000240857                           R_1     42855657
# 2          ENSG00000068001                           R_2     29667743
# 3          ENSG00000170961                           R_1     24343518
# 4          ENSG00000166189                           R_1     24343518
# ...                    ...                           ...          ...
# 18457      ENSG00000166189                           R_5     23728568
# 18458      ENSG00000111186                           R_5     23728568
# 18459      ENSG00000160678                           R_5     23728568
# 18460      ENSG00000147168                           R_5     23728568
# 18461      ENSG00000175283                           R_5     23728568
#
#        end1 (bp) Chromosome/scaffold name_human  start2 (bp)  end2 (bp)  \
# 0       24345172                            H_2    112829751  112836816
# 1       42857462                            H_2     18554723   18560679
# 2       29669572                            H_3     50317790   50322782
# 3       24345172                            H_8    121612116  121641440
# 4       24345172                           H_10    102065349  102068036
# ...          ...                            ...          ...        ...
# 18457   23738372                           H_10    102065349  102068036
# 18458   23738372                           H_12      1529891    1647212
# 18459   23738372                            H_1    153627926  153632039
# 18460   23738372                            H_X     71107404   71112108
# 18461   23738372                            H_9    128945530  128947603
#
#        HN-score(HN5)_rice  HN-score(HN5)_human  counts_down  fold_enrichment  \
# 0                     -75                  -28           21         5.178879
# 1                     -41                  -15           21         5.178879
# 2                     -41                  -22           21         5.178879
# 3                     -75                  -24           21         5.178879
# 4                     -75                  -36           21         5.178879
# ...                   ...                  ...          ...              ...
# 18457                 -49                  -36           13         0.075565
# 18458                 -49                  -17           13         0.075565
# 18459                 -49                  -15           13         0.075565
# 18460                 -49                  -15           13         0.075565
# 18461                 -49                  -17           13         0.075565
#
#             p_value       q_value
# 0      2.405986e-09  1.168622e-08
# 1      2.405986e-09  1.168622e-08
# 2      2.405986e-09  1.168622e-08
# 3      2.405986e-09  1.168622e-08
# 4      2.405986e-09  1.168622e-08
# ...             ...           ...
# 18457  1.000000e+00  1.000000e+00
# 18458  1.000000e+00  1.000000e+00
# 18459  1.000000e+00  1.000000e+00
# 18460  1.000000e+00  1.000000e+00
# 18461  1.000000e+00  1.000000e+00
#
# [18462 rows x 18 columns]
