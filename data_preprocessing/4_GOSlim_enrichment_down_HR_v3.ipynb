# %%
import pandas as pd
import numpy as np
import datetime
import os
from scipy.stats import fisher_exact
from statsmodels.stats.multitest import multipletests
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import ipywidgets as widgets
from ipywidgets import interact, interactive

# %%
# output directory
direction = "down"
species = "HR"
now = datetime.datetime.now()
line_enrichment = f'../data/line_enrichment_{direction}_{species}_{now.strftime("%y%m")}'
os.makedirs(line_enrichment, exist_ok=True)

# %%
def count_goslim(df, file_name: str):
    unique_gene_pairs = df.drop_duplicates(subset=['GOSlim GOA Accession(s)', 'Gene stable ID_human', 'Gene stable ID_rice'])
    goslim_counts = unique_gene_pairs.groupby(['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain']).size().reset_index(name='counts')
    goslim_counts = goslim_counts.sort_values(by='counts', ascending=False).copy()
    goslim_counts.reset_index(drop=True, inplace=True)
    results_directory = f'../data/{line_enrichment}/goslim_correspondence_counts_{direction}_{species}'
    os.makedirs(results_directory, exist_ok=True)
    goslim_counts.to_csv(f'{results_directory}/{file_name}', sep='\t', index=False)
    return goslim_counts

# %%
merged_df_goslim_pd = pd.read_csv('../data/GOSlim_merge_HR/GOslim_merge_common_goslim_correspondence_all.tsv', 
                                  sep='\t',
                                  low_memory=False)
merged_df_up = pd.read_csv(f'../data/circos_{direction}_{species}_2311/combined_goslim_down.tsv', sep='\t')

display(merged_df_goslim_pd, merged_df_up)
# Out:
#           GOSlim GOA Accession(s)          GOSlim GOA Description  \
# 0                      GO:0005886                 plasma membrane
# 1                      GO:0005886                 plasma membrane
# 2                      GO:0005886                 plasma membrane
# 3                      GO:0005886                 plasma membrane
# 4                      GO:0005886                 plasma membrane
# ...                           ...                             ...
# 205962886              GO:0045182  translation regulator activity
# 205962887              GO:0045182  translation regulator activity
# 205962888              GO:0045182  translation regulator activity
# 205962889              GO:0045182  translation regulator activity
# 205962890              GO:0045182  translation regulator activity
#
#                 GOSlim_domain Gene stable ID_human Gene stable ID_rice
# 0          cellular_component         Os01g0100400     ENSG00000186092
# 1          cellular_component         Os01g0103600     ENSG00000186092
# 2          cellular_component         Os01g0104000     ENSG00000186092
# 3          cellular_component         Os01g0108000     ENSG00000186092
# 4          cellular_component         Os01g0110100     ENSG00000186092
# ...                       ...                  ...                 ...
# 205962886  molecular_function         Os12g0507200     ENSG00000205916
# 205962887  molecular_function         Os12g0541500     ENSG00000205916
# 205962888  molecular_function         Os12g0607100     ENSG00000205916
# 205962889  molecular_function         Os12g0617100     ENSG00000205916
# 205962890  molecular_function            gene-infA     ENSG00000205916
#
# [205962891 rows x 5 columns]
#       GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0                  GO:0003824                              catalytic activity
# 1                  GO:0003824                              catalytic activity
# 2                  GO:0003824                              catalytic activity
# 3                  GO:0003824                              catalytic activity
# 4                  GO:0003824                              catalytic activity
# ...                       ...                                             ...
# 18457              GO:0006091  generation of precursor metabolites and energy
# 18458              GO:0030312                external encapsulating structure
# 18459              GO:0005635                                nuclear envelope
# 18460              GO:0005635                                nuclear envelope
# 18461              GO:0005635                                nuclear envelope
#
#             GOSlim_domain Gene stable ID_rice Gene stable ID_human  \
# 0      molecular_function        Os02g0504000      ENSG00000142731
# 1      molecular_function        Os02g0121700      ENSG00000151117
# 2      molecular_function        Os02g0571100      ENSG00000151117
# 3      molecular_function        Os05g0360400      ENSG00000151117
# 4      molecular_function        Os11g0641500      ENSG00000151117
# ...                   ...                 ...                  ...
# 18457  biological_process        Os06g0718400      ENSG00000213689
# 18458  cellular_component        Os03g0651800      ENSG00000111186
# 18459  cellular_component        Os12g0236100      ENSG00000213689
# 18460  cellular_component        Os12g0236100      ENSG00000205808
# 18461  cellular_component        Os12g0236100      ENSG00000151353
#
#       Chromosome/scaffold name_rice  start1 (bp)  end1 (bp)  \
# 0                               R_2     17880882   17886285
# 1                               R_2      1145837    1151052
# 2                               R_2     21841092   21847545
# 3                               R_5     17175702   17176974
# 4                              R_11     25423701   25426045
# ...                             ...          ...        ...
# 18457                           R_6     30528045   30529070
# 18458                           R_3     25315697   25317065
# 18459                          R_12      7441389    7446142
# 18460                          R_12      7441389    7446142
# 18461                          R_12      7441389    7446142
#
#       Chromosome/scaffold name_human  start2 (bp)  end2 (bp)  \
# 0                                H_4    127880893  127899224
# 1                               H_11     18693122   18704785
# 2                               H_11     18693122   18704785
# 3                               H_11     18693122   18704785
# 4                               H_11     18693122   18704785
# ...                              ...          ...        ...
# 18457                            H_3     48465811   48467645
# 18458                           H_12      1529891    1647212
# 18459                            H_3     48465811   48467645
# 18460                            H_9      4662294    4665258
# 18461                            H_2       663877     677406
#
#        HN-score(HN5)_rice  HN-score(HN5)_human
# 0                     -84                  -17
# 1                     -59                  -16
# 2                     -53                  -16
# 3                     -54                  -16
# 4                     -54                  -16
# ...                   ...                  ...
# 18457                 -89                  -28
# 18458                 -68                  -17
# 18459                 -81                  -28
# 18460                 -81                  -18
# 18461                 -81                  -15
#
# [18462 rows x 13 columns]

# %%
gosilm_correspondence_up_counts = count_goslim(merged_df_up, f'goslim_correspondence_counts_{direction}.tsv')
goslim_correspondence_all_counts = count_goslim(merged_df_goslim_pd, 'goslim_correspondence_counts_all.tsv')

display(gosilm_correspondence_up_counts, goslim_correspondence_all_counts)
# Out:
#    GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0               GO:0003824                              catalytic activity
# 1               GO:0005634                                         nucleus
# 2               GO:0005886                                 plasma membrane
# 3               GO:0016787                              hydrolase activity
# 4               GO:0016740                            transferase activity
# 5               GO:0005576                            extracellular region
# 6               GO:0003677                                     DNA binding
# 7               GO:0048856                anatomical structure development
# 8               GO:0005829                                         cytosol
# 9               GO:0036211                    protein modification process
# 10              GO:0006629                         lipid metabolic process
# 11              GO:0140110                transcription regulator activity
# 12              GO:0005975                  carbohydrate metabolic process
# 13              GO:0030154                            cell differentiation
# 14              GO:0005215                            transporter activity
# 15              GO:0008289                                   lipid binding
# 16              GO:0005773                                         vacuole
# 17              GO:0005198                    structural molecule activity
# 18              GO:0005856                                    cytoskeleton
# 19              GO:0005739                                   mitochondrion
# 20              GO:0005764                                        lysosome
# 21              GO:0005794                                 Golgi apparatus
# 22              GO:0005783                           endoplasmic reticulum
# 23              GO:0006091  generation of precursor metabolites and energy
# 24              GO:0030312                external encapsulating structure
# 25              GO:0005635                                nuclear envelope
#
#          GOSlim_domain  counts
# 0   molecular_function    7998
# 1   cellular_component    2790
# 2   cellular_component    1230
# 3   molecular_function    1107
# 4   molecular_function    1080
# 5   cellular_component     870
# 6   molecular_function     672
# 7   biological_process     590
# 8   cellular_component     567
# 9   biological_process     555
# 10  biological_process     204
# 11  molecular_function     200
# 12  biological_process     153
# 13  biological_process      94
# 14  molecular_function      84
# 15  molecular_function      64
# 16  cellular_component      54
# 17  molecular_function      28
# 18  cellular_component      24
# 19  cellular_component      22
# 20  cellular_component      21
# 21  cellular_component      15
# 22  cellular_component      13
# 23  biological_process      12
# 24  cellular_component      12
# 25  cellular_component       3
#    GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0               GO:0003824                              catalytic activity
# 1               GO:0005634                                         nucleus
# 2               GO:0005886                                 plasma membrane
# 3               GO:0036211                    protein modification process
# 4               GO:0016740                            transferase activity
# 5               GO:0016787                              hydrolase activity
# 6               GO:0005829                                         cytosol
# 7               GO:0048856                anatomical structure development
# 8               GO:0003677                                     DNA binding
# 9               GO:0003723                                     RNA binding
# 10              GO:0005576                            extracellular region
# 11              GO:0140110                transcription regulator activity
# 12              GO:0005739                                   mitochondrion
# 13              GO:0005215                            transporter activity
# 14              GO:0005783                           endoplasmic reticulum
# 15              GO:0005794                                 Golgi apparatus
# 16              GO:0005654                                     nucleoplasm
# 17              GO:0006629                         lipid metabolic process
# 18              GO:0030154                            cell differentiation
# 19              GO:0005856                                    cytoskeleton
# 20              GO:0005975                  carbohydrate metabolic process
# 21              GO:0005198                    structural molecule activity
# 22              GO:0005730                                       nucleolus
# 23              GO:0005773                                         vacuole
# 24              GO:0005768                                        endosome
# 25              GO:0006091  generation of precursor metabolites and energy
# 26              GO:0008289                                   lipid binding
# 27              GO:0005840                                        ribosome
# 28              GO:0030312                external encapsulating structure
# 29              GO:0005635                                nuclear envelope
# 30              GO:0005764                                        lysosome
# 31              GO:0045182                  translation regulator activity
# 32              GO:0005777                                      peroxisome
# 33              GO:0003774                     cytoskeletal motor activity
#
#          GOSlim_domain    counts
# 0   molecular_function  62834292
# 1   cellular_component  50586355
# 2   cellular_component  14121523
# 3   biological_process  11265607
# 4   molecular_function  10856023
# 5   molecular_function   8674587
# 6   cellular_component   7811118
# 7   biological_process   7216908
# 8   molecular_function   5819761
# 9   molecular_function   4482192
# 10  cellular_component   3845282
# 11  molecular_function   2256826
# 12  cellular_component   1951236
# 13  molecular_function   1929898
# 14  cellular_component   1919256
# 15  cellular_component   1563150
# 16  cellular_component   1522420
# 17  biological_process   1517670
# 18  biological_process   1272360
# 19  cellular_component    725760
# 20  biological_process    676139
# 21  molecular_function    650310
# 22  cellular_component    566826
# 23  cellular_component    422166
# 24  cellular_component    342792
# 25  biological_process    265631
# 26  molecular_function    257535
# 27  cellular_component    252420
# 28  cellular_component    203467
# 29  cellular_component     50592
# 30  cellular_component     45237
# 31  molecular_function     30420
# 32  cellular_component     18172
# 33  molecular_function      8960

# %%
# for debugging purpose
total_counts_up = gosilm_correspondence_up_counts['counts'].sum()
total_counts_all = goslim_correspondence_all_counts['counts'].sum()

unique_rows_up = merged_df_up.drop_duplicates(subset=['GOSlim GOA Accession(s)', 'Gene stable ID_human', 'Gene stable ID_rice']).shape[0]
unique_rows_all = merged_df_goslim_pd.drop_duplicates(subset=['GOSlim GOA Accession(s)', 'Gene stable ID_human', 'Gene stable ID_rice']).shape[0]

print(f"Total counts: {unique_rows_all}")
print(f"up counts: {unique_rows_up}")
print(f"Counts match rows: {unique_rows_up == total_counts_up}")
# Out:
# Total counts: 205962891
# up counts: 18462
# Counts match rows: True

# %%
# fold enrichment
def fold_enrichment(df_goslim_up_counts, df_goslim_all_counts, unique_genes_up, unique_genes_all, file_name: str):
    """_summary_
    Args:
        df_goslim_up_counts (dataframe): _description_
        df_goslim_all_counts (dataframe): _description_
        unique_genes_up (): _description_
        unique_genes_all (dataframe): _description_
        file_name (str): _description_

    Returns:
        dataframe : _description_
    """
    merged_df = pd.merge(df_goslim_up_counts, 
                         df_goslim_all_counts,
                         on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'], 
                         how='right', # if there is no match, fill with NaN or 0
                         suffixes=('_down', '_all'))
    
    merged_df['counts_down'] = merged_df['counts_down'].fillna(0)
    merged_df['counts_all'] = merged_df['counts_all'].fillna(0)
    merged_df['down_ratio'] = merged_df['counts_down'] / unique_genes_up
    merged_df['all_ratio'] = merged_df['counts_all'] / unique_genes_all
    merged_df['fold_enrichment'] = merged_df['down_ratio'] / merged_df['all_ratio']
    merged_df.replace([np.inf, -np.inf], np.nan, inplace=True) # inf -> nan
    results_directory = f'../data/{line_enrichment}/goslim_fold_enrichment_correspondence_{direction}_{species}'
    os.makedirs(results_directory, exist_ok=True)
    merged_df.to_csv(f'{results_directory}/{file_name}', sep='\t', index=False)
    
    return merged_df


goslim_correspondence_enrichment = fold_enrichment(gosilm_correspondence_up_counts, 
                                                   goslim_correspondence_all_counts, 
                                                   unique_rows_up, 
                                                   unique_rows_all, 
                                                   f'goslim_correspondence_fold_enrichment_{direction}.tsv')
display(goslim_correspondence_enrichment)
# Out:
#    GOSlim GOA Accession(s)                          GOSlim GOA Description  \
# 0               GO:0003824                              catalytic activity
# 1               GO:0005634                                         nucleus
# 2               GO:0005886                                 plasma membrane
# 3               GO:0036211                    protein modification process
# 4               GO:0016740                            transferase activity
# 5               GO:0016787                              hydrolase activity
# 6               GO:0005829                                         cytosol
# 7               GO:0048856                anatomical structure development
# 8               GO:0003677                                     DNA binding
# 9               GO:0003723                                     RNA binding
# 10              GO:0005576                            extracellular region
# 11              GO:0140110                transcription regulator activity
# 12              GO:0005739                                   mitochondrion
# 13              GO:0005215                            transporter activity
# 14              GO:0005783                           endoplasmic reticulum
# 15              GO:0005794                                 Golgi apparatus
# 16              GO:0005654                                     nucleoplasm
# 17              GO:0006629                         lipid metabolic process
# 18              GO:0030154                            cell differentiation
# 19              GO:0005856                                    cytoskeleton
# 20              GO:0005975                  carbohydrate metabolic process
# 21              GO:0005198                    structural molecule activity
# 22              GO:0005730                                       nucleolus
# 23              GO:0005773                                         vacuole
# 24              GO:0005768                                        endosome
# 25              GO:0006091  generation of precursor metabolites and energy
# 26              GO:0008289                                   lipid binding
# 27              GO:0005840                                        ribosome
# 28              GO:0030312                external encapsulating structure
# 29              GO:0005635                                nuclear envelope
# 30              GO:0005764                                        lysosome
# 31              GO:0045182                  translation regulator activity
# 32              GO:0005777                                      peroxisome
# 33              GO:0003774                     cytoskeletal motor activity
#
#          GOSlim_domain  counts_down  counts_all  down_ratio  all_ratio  \
# 0   molecular_function       7998.0    62834292    0.433214   0.305076
# 1   cellular_component       2790.0    50586355    0.151121   0.245609
# 2   cellular_component       1230.0    14121523    0.066623   0.068563
# 3   biological_process        555.0    11265607    0.030062   0.054697
# 4   molecular_function       1080.0    10856023    0.058499   0.052709
# 5   molecular_function       1107.0     8674587    0.059961   0.042117
# 6   cellular_component        567.0     7811118    0.030712   0.037925
# 7   biological_process        590.0     7216908    0.031958   0.035040
# 8   molecular_function        672.0     5819761    0.036399   0.028256
# 9   molecular_function          0.0     4482192    0.000000   0.021762
# 10  cellular_component        870.0     3845282    0.047124   0.018670
# 11  molecular_function        200.0     2256826    0.010833   0.010957
# 12  cellular_component         22.0     1951236    0.001192   0.009474
# 13  molecular_function         84.0     1929898    0.004550   0.009370
# 14  cellular_component         13.0     1919256    0.000704   0.009318
# 15  cellular_component         15.0     1563150    0.000812   0.007589
# 16  cellular_component          0.0     1522420    0.000000   0.007392
# 17  biological_process        204.0     1517670    0.011050   0.007369
# 18  biological_process         94.0     1272360    0.005092   0.006178
# 19  cellular_component         24.0      725760    0.001300   0.003524
# 20  biological_process        153.0      676139    0.008287   0.003283
# 21  molecular_function         28.0      650310    0.001517   0.003157
# 22  cellular_component          0.0      566826    0.000000   0.002752
# 23  cellular_component         54.0      422166    0.002925   0.002050
# 24  cellular_component          0.0      342792    0.000000   0.001664
# 25  biological_process         12.0      265631    0.000650   0.001290
# 26  molecular_function         64.0      257535    0.003467   0.001250
# 27  cellular_component          0.0      252420    0.000000   0.001226
# 28  cellular_component         12.0      203467    0.000650   0.000988
# 29  cellular_component          3.0       50592    0.000162   0.000246
# 30  cellular_component         21.0       45237    0.001137   0.000220
# 31  molecular_function          0.0       30420    0.000000   0.000148
# 32  cellular_component          0.0       18172    0.000000   0.000088
# 33  molecular_function          0.0        8960    0.000000   0.000044
#
#     fold_enrichment
# 0          1.420021
# 1          0.615292
# 2          0.971704
# 3          0.549602
# 4          1.109847
# 5          1.423669
# 6          0.809804
# 7          0.912034
# 8          1.288173
# 9          0.000000
# 10         2.524069
# 11         0.988649
# 12         0.125783
# 13         0.485574
# 14         0.075565
# 15         0.107053
# 16         0.000000
# 17         1.499557
# 18         0.824191
# 19         0.368917
# 20         2.524444
# 21         0.480339
# 22         0.000000
# 23         1.426989
# 24         0.000000
# 25         0.503979
# 26         2.772388
# 27         0.000000
# 28         0.657957
# 29         0.661530
# 30         5.178879
# 31         0.000000
# 32         0.000000
# 33         0.000000

# %% [markdown]
# ## Q-value

# %%
def calculate_p_q_values(df_enrichment, unique_correspondence_down, unique_correspondence_all, file_name: str):
    p_values = []
    df_enrichment[f'counts_{direction}'] = df_enrichment[f'counts_{direction}'].astype(int) # float(0.0) to int(0)
    for index, row in df_enrichment.iterrows():
        if row[f'counts_{direction}'] == 0:
            p_values.append(1.0)
        else:
            observed_down_correspondence = row[f'counts_{direction}'] # create contingency table
            observed_all_correspondence = row['counts_all']
            observed_not_down_correspondence = observed_all_correspondence - observed_down_correspondence
            total_not_down_correspondence = unique_correspondence_all - unique_correspondence_down
            table = [
            [observed_down_correspondence, unique_correspondence_down - observed_down_correspondence],
            [observed_not_down_correspondence, total_not_down_correspondence - observed_not_down_correspondence]
            ]
            _, p_value = fisher_exact(table, alternative='greater') # Fisher's exact test
            p_values.append(p_value)
    
    _, q_values, _, _ = multipletests(p_values, 
                                      alpha=0.05, 
                                      method='fdr_bh') # Benjamini/Hochberg method
    
    df_enrichment['p_value'] = p_values
    df_enrichment['q_value'] = q_values

    results_directory = f'../data/{line_enrichment}/goslim_correspondence_q_values_{direction}_{species}'
    os.makedirs(results_directory, exist_ok=True)
    df_enrichment['GOSlim'] = df_enrichment['GOSlim GOA Accession(s)'] + ": " + df_enrichment['GOSlim GOA Description']
    cols = df_enrichment.columns.tolist()
    cols = [cols[-1]] + cols[:-1]
    df_enrichment = df_enrichment[cols]
    df_enrichment.drop(['GOSlim GOA Accession(s)', 'GOSlim GOA Description'], axis=1)
    df_enrichment = df_enrichment[df_enrichment[f'counts_{direction}'] != 0]
    df_enrichment = df_enrichment.sort_values(by='fold_enrichment', ascending=False)
    df_enrichment.reset_index(drop=True, inplace=True)
    df_enrichment.to_csv(f'{results_directory}/{file_name}', sep='\t', index=False)

    return df_enrichment

goslim_correspondence_with_p_q = calculate_p_q_values(goslim_correspondence_enrichment.copy(),
                                                      unique_rows_up,
                                                      unique_rows_all, 
                                                      f'goslim_correspondence_fold_enrichment_p_q_{direction}.tsv')


display(goslim_correspondence_with_p_q)
# Out:
#                                                GOSlim GOSlim GOA Accession(s)  \
# 0                                GO:0005764: lysosome              GO:0005764
# 1                           GO:0008289: lipid binding              GO:0008289
# 2          GO:0005975: carbohydrate metabolic process              GO:0005975
# 3                    GO:0005576: extracellular region              GO:0005576
# 4                 GO:0006629: lipid metabolic process              GO:0006629
# 5                                 GO:0005773: vacuole              GO:0005773
# 6                      GO:0016787: hydrolase activity              GO:0016787
# 7                      GO:0003824: catalytic activity              GO:0003824
# 8                             GO:0003677: DNA binding              GO:0003677
# 9                    GO:0016740: transferase activity              GO:0016740
# 10       GO:0140110: transcription regulator activity              GO:0140110
# 11                        GO:0005886: plasma membrane              GO:0005886
# 12       GO:0048856: anatomical structure development              GO:0048856
# 13                   GO:0030154: cell differentiation              GO:0030154
# 14                                GO:0005829: cytosol              GO:0005829
# 15                       GO:0005635: nuclear envelope              GO:0005635
# 16       GO:0030312: external encapsulating structure              GO:0030312
# 17                                GO:0005634: nucleus              GO:0005634
# 18           GO:0036211: protein modification process              GO:0036211
# 19  GO:0006091: generation of precursor metabolite...              GO:0006091
# 20                   GO:0005215: transporter activity              GO:0005215
# 21           GO:0005198: structural molecule activity              GO:0005198
# 22                           GO:0005856: cytoskeleton              GO:0005856
# 23                          GO:0005739: mitochondrion              GO:0005739
# 24                        GO:0005794: Golgi apparatus              GO:0005794
# 25                  GO:0005783: endoplasmic reticulum              GO:0005783
#
#                             GOSlim GOA Description       GOSlim_domain  \
# 0                                         lysosome  cellular_component
# 1                                    lipid binding  molecular_function
# 2                   carbohydrate metabolic process  biological_process
# 3                             extracellular region  cellular_component
# 4                          lipid metabolic process  biological_process
# 5                                          vacuole  cellular_component
# 6                               hydrolase activity  molecular_function
# 7                               catalytic activity  molecular_function
# 8                                      DNA binding  molecular_function
# 9                             transferase activity  molecular_function
# 10                transcription regulator activity  molecular_function
# 11                                 plasma membrane  cellular_component
# 12                anatomical structure development  biological_process
# 13                            cell differentiation  biological_process
# 14                                         cytosol  cellular_component
# 15                                nuclear envelope  cellular_component
# 16                external encapsulating structure  cellular_component
# 17                                         nucleus  cellular_component
# 18                    protein modification process  biological_process
# 19  generation of precursor metabolites and energy  biological_process
# 20                            transporter activity  molecular_function
# 21                    structural molecule activity  molecular_function
# 22                                    cytoskeleton  cellular_component
# 23                                   mitochondrion  cellular_component
# 24                                 Golgi apparatus  cellular_component
# 25                           endoplasmic reticulum  cellular_component
#
#     counts_down  counts_all  down_ratio  all_ratio  fold_enrichment  \
# 0            21       45237    0.001137   0.000220         5.178879
# 1            64      257535    0.003467   0.001250         2.772388
# 2           153      676139    0.008287   0.003283         2.524444
# 3           870     3845282    0.047124   0.018670         2.524069
# 4           204     1517670    0.011050   0.007369         1.499557
# 5            54      422166    0.002925   0.002050         1.426989
# 6          1107     8674587    0.059961   0.042117         1.423669
# 7          7998    62834292    0.433214   0.305076         1.420021
# 8           672     5819761    0.036399   0.028256         1.288173
# 9          1080    10856023    0.058499   0.052709         1.109847
# 10          200     2256826    0.010833   0.010957         0.988649
# 11         1230    14121523    0.066623   0.068563         0.971704
# 12          590     7216908    0.031958   0.035040         0.912034
# 13           94     1272360    0.005092   0.006178         0.824191
# 14          567     7811118    0.030712   0.037925         0.809804
# 15            3       50592    0.000162   0.000246         0.661530
# 16           12      203467    0.000650   0.000988         0.657957
# 17         2790    50586355    0.151121   0.245609         0.615292
# 18          555    11265607    0.030062   0.054697         0.549602
# 19           12      265631    0.000650   0.001290         0.503979
# 20           84     1929898    0.004550   0.009370         0.485574
# 21           28      650310    0.001517   0.003157         0.480339
# 22           24      725760    0.001300   0.003524         0.368917
# 23           22     1951236    0.001192   0.009474         0.125783
# 24           15     1563150    0.000812   0.007589         0.107053
# 25           13     1919256    0.000704   0.009318         0.075565
#
#           p_value        q_value
# 0    2.405986e-09   1.168622e-08
# 1    1.956956e-12   1.330730e-11
# 2    1.642043e-23   1.395737e-22
# 3   2.046157e-127  3.478467e-126
# 4    2.974814e-08   1.264296e-07
# 5    7.697182e-03   2.617042e-02
# 6    3.160887e-30   3.582339e-29
# 7   2.079914e-294  7.071707e-293
# 8    8.590193e-11   4.867776e-10
# 9    2.787134e-04   1.052917e-03
# 10   5.740091e-01   1.000000e+00
# 11   8.550350e-01   1.000000e+00
# 12   9.899762e-01   1.000000e+00
# 13   9.759711e-01   1.000000e+00
# 14   9.999999e-01   1.000000e+00
# 15   8.303609e-01   1.000000e+00
# 16   9.507781e-01   1.000000e+00
# 17   1.000000e+00   1.000000e+00
# 18   1.000000e+00   1.000000e+00
# 19   9.972028e-01   1.000000e+00
# 20   1.000000e+00   1.000000e+00
# 21   9.999963e-01   1.000000e+00
# 22   1.000000e+00   1.000000e+00
# 23   1.000000e+00   1.000000e+00
# 24   1.000000e+00   1.000000e+00
# 25   1.000000e+00   1.000000e+00

# %%
#data preprocessing for plotting
goslim_correspondence_with_p_q.rename(columns={f'counts_{direction}': 'line counts'}, inplace=True)

if 'p_value' in goslim_correspondence_with_p_q.columns:
    goslim_correspondence_with_p_q['-log10(p-value)'] = -np.log10(goslim_correspondence_with_p_q['p_value'])
    
if 'q_value' in goslim_correspondence_with_p_q.columns:
    goslim_correspondence_with_p_q['-log10(q-value)'] = -np.log10(goslim_correspondence_with_p_q['q_value'])


cc = goslim_correspondence_with_p_q.loc[goslim_correspondence_with_p_q['GOSlim_domain'] == 'cellular_component']
bp = goslim_correspondence_with_p_q.loc[goslim_correspondence_with_p_q['GOSlim_domain'] == 'biological_process']
mf = goslim_correspondence_with_p_q.loc[goslim_correspondence_with_p_q['GOSlim_domain'] == 'molecular_function']

cc.reset_index(drop=True, inplace=True)
bp.reset_index(drop=True, inplace=True)
mf.reset_index(drop=True, inplace=True)

display(cc, bp, mf)
# Out:
#                                           GOSlim GOSlim GOA Accession(s)  \
# 0                           GO:0005764: lysosome              GO:0005764
# 1               GO:0005576: extracellular region              GO:0005576
# 2                            GO:0005773: vacuole              GO:0005773
# 3                    GO:0005886: plasma membrane              GO:0005886
# 4                            GO:0005829: cytosol              GO:0005829
# 5                   GO:0005635: nuclear envelope              GO:0005635
# 6   GO:0030312: external encapsulating structure              GO:0030312
# 7                            GO:0005634: nucleus              GO:0005634
# 8                       GO:0005856: cytoskeleton              GO:0005856
# 9                      GO:0005739: mitochondrion              GO:0005739
# 10                   GO:0005794: Golgi apparatus              GO:0005794
# 11             GO:0005783: endoplasmic reticulum              GO:0005783
#
#               GOSlim GOA Description       GOSlim_domain  line counts  \
# 0                           lysosome  cellular_component           21
# 1               extracellular region  cellular_component          870
# 2                            vacuole  cellular_component           54
# 3                    plasma membrane  cellular_component         1230
# 4                            cytosol  cellular_component          567
# 5                   nuclear envelope  cellular_component            3
# 6   external encapsulating structure  cellular_component           12
# 7                            nucleus  cellular_component         2790
# 8                       cytoskeleton  cellular_component           24
# 9                      mitochondrion  cellular_component           22
# 10                   Golgi apparatus  cellular_component           15
# 11             endoplasmic reticulum  cellular_component           13
#
#     counts_all  down_ratio  all_ratio  fold_enrichment        p_value  \
# 0        45237    0.001137   0.000220         5.178879   2.405986e-09
# 1      3845282    0.047124   0.018670         2.524069  2.046157e-127
# 2       422166    0.002925   0.002050         1.426989   7.697182e-03
# 3     14121523    0.066623   0.068563         0.971704   8.550350e-01
# 4      7811118    0.030712   0.037925         0.809804   9.999999e-01
# 5        50592    0.000162   0.000246         0.661530   8.303609e-01
# 6       203467    0.000650   0.000988         0.657957   9.507781e-01
# 7     50586355    0.151121   0.245609         0.615292   1.000000e+00
# 8       725760    0.001300   0.003524         0.368917   1.000000e+00
# 9      1951236    0.001192   0.009474         0.125783   1.000000e+00
# 10     1563150    0.000812   0.007589         0.107053   1.000000e+00
# 11     1919256    0.000704   0.009318         0.075565   1.000000e+00
#
#           q_value  -log10(p-value)  -log10(q-value)
# 0    1.168622e-08     8.618707e+00         7.932326
# 1   3.478467e-126     1.266891e+02       125.458612
# 2    2.617042e-02     2.113668e+00         1.582189
# 3    1.000000e+00     6.801609e-02        -0.000000
# 4    1.000000e+00     2.305136e-08        -0.000000
# 5    1.000000e+00     8.073310e-02        -0.000000
# 6    1.000000e+00     2.192081e-02        -0.000000
# 7    1.000000e+00    -0.000000e+00        -0.000000
# 8    1.000000e+00     6.921371e-10        -0.000000
# 9    1.000000e+00    -0.000000e+00        -0.000000
# 10   1.000000e+00    -0.000000e+00        -0.000000
# 11   1.000000e+00    -0.000000e+00        -0.000000
#                                               GOSlim GOSlim GOA Accession(s)  \
# 0         GO:0005975: carbohydrate metabolic process              GO:0005975
# 1                GO:0006629: lipid metabolic process              GO:0006629
# 2       GO:0048856: anatomical structure development              GO:0048856
# 3                   GO:0030154: cell differentiation              GO:0030154
# 4           GO:0036211: protein modification process              GO:0036211
# 5  GO:0006091: generation of precursor metabolite...              GO:0006091
#
#                            GOSlim GOA Description       GOSlim_domain  \
# 0                  carbohydrate metabolic process  biological_process
# 1                         lipid metabolic process  biological_process
# 2                anatomical structure development  biological_process
# 3                            cell differentiation  biological_process
# 4                    protein modification process  biological_process
# 5  generation of precursor metabolites and energy  biological_process
#
#    line counts  counts_all  down_ratio  all_ratio  fold_enrichment  \
# 0          153      676139    0.008287   0.003283         2.524444
# 1          204     1517670    0.011050   0.007369         1.499557
# 2          590     7216908    0.031958   0.035040         0.912034
# 3           94     1272360    0.005092   0.006178         0.824191
# 4          555    11265607    0.030062   0.054697         0.549602
# 5           12      265631    0.000650   0.001290         0.503979
#
#         p_value       q_value  -log10(p-value)  -log10(q-value)
# 0  1.642043e-23  1.395737e-22        22.784615        21.855197
# 1  2.974814e-08  1.264296e-07         7.526540         6.898151
# 2  9.899762e-01  1.000000e+00         0.004375        -0.000000
# 3  9.759711e-01  1.000000e+00         0.010563        -0.000000
# 4  1.000000e+00  1.000000e+00        -0.000000        -0.000000
# 5  9.972028e-01  1.000000e+00         0.001217        -0.000000
#                                          GOSlim GOSlim GOA Accession(s)  \
# 0                     GO:0008289: lipid binding              GO:0008289
# 1                GO:0016787: hydrolase activity              GO:0016787
# 2                GO:0003824: catalytic activity              GO:0003824
# 3                       GO:0003677: DNA binding              GO:0003677
# 4              GO:0016740: transferase activity              GO:0016740
# 5  GO:0140110: transcription regulator activity              GO:0140110
# 6              GO:0005215: transporter activity              GO:0005215
# 7      GO:0005198: structural molecule activity              GO:0005198
#
#              GOSlim GOA Description       GOSlim_domain  line counts  \
# 0                     lipid binding  molecular_function           64
# 1                hydrolase activity  molecular_function         1107
# 2                catalytic activity  molecular_function         7998
# 3                       DNA binding  molecular_function          672
# 4              transferase activity  molecular_function         1080
# 5  transcription regulator activity  molecular_function          200
# 6              transporter activity  molecular_function           84
# 7      structural molecule activity  molecular_function           28
#
#    counts_all  down_ratio  all_ratio  fold_enrichment        p_value  \
# 0      257535    0.003467   0.001250         2.772388   1.956956e-12
# 1     8674587    0.059961   0.042117         1.423669   3.160887e-30
# 2    62834292    0.433214   0.305076         1.420021  2.079914e-294
# 3     5819761    0.036399   0.028256         1.288173   8.590193e-11
# 4    10856023    0.058499   0.052709         1.109847   2.787134e-04
# 5     2256826    0.010833   0.010957         0.988649   5.740091e-01
# 6     1929898    0.004550   0.009370         0.485574   1.000000e+00
# 7      650310    0.001517   0.003157         0.480339   9.999963e-01
#
#          q_value  -log10(p-value)  -log10(q-value)
# 0   1.330730e-11     1.170842e+01        10.875910
# 1   3.582339e-29     2.950019e+01        28.445833
# 2  7.071707e-293     2.936820e+02       292.150476
# 3   4.867776e-10     1.006600e+01         9.312669
# 4   1.052917e-03     3.554842e+00         2.977606
# 5   1.000000e+00     2.410812e-01        -0.000000
# 6   1.000000e+00     7.039591e-15        -0.000000
# 7   1.000000e+00     1.598255e-06        -0.000000

# %%
# enrichment result plot function
current_fig = None # global variable

def plot_goslim_dotplot_with_lines(data, col1, goslim_col, col2, col3, ylabel_suffix='', width=6, height=9, palette="flare"):

    # 1. figure size
    global current_fig
    figsize = (width, height)
    current_fig, ax = plt.subplots(figsize=figsize)

    # 2. color normalization
    norm = mcolors.Normalize(vmin=data[col3].min(), vmax=data[col3].max())

    # 3.color palette
    color_palette = sns.color_palette(palette, as_cmap=True)

    # 4.plotting
    sns.scatterplot(
        data=data,
        x=col1,
        y=goslim_col,
        size=col2, 
        hue=col3,     
        palette=palette, 
        legend='brief',
        ax=ax
    )
    # 5.lines 
    for index, row in data.iterrows():
        ax.plot([0, row[col1]], [row[goslim_col], row[goslim_col]], color=color_palette(norm(row[col3])), lw=1)
    
    ax.grid(color='b', linestyle=':', linewidth=0.1)
    ax.set_xlabel(col1)
    ylabel_text = 'Common GOSlim Terms' + ('' + ylabel_suffix  if ylabel_suffix else '' )
    ax.set_ylabel(ylabel_text)

    plt.show()

# execute only this function to plot
# plot_goslim_dotplot_with_lines(goslim_correspondence_with_p_q.copy(), 'fold_enrichment', 'GOSlim', 'line counts', 'q_value', ylabel_suffix='') # add copy() to avoid SettingWithCopyWarning
# plot_goslim_dotplot_with_lines(cc.copy(), 'fold_enrichment', 'GOSlim', 'line counts', 'q_value', ylabel_suffix=' (Cellular Component)')
# plot_goslim_dotplot_with_lines(bp.copy(), 'fold_enrichment', 'GOSlim', 'line counts', 'q_value', ylabel_suffix=' (Biological Process)')
# plot_goslim_dotplot_with_lines(mf.copy(), 'fold_enrichment', 'GOSlim', 'line counts', 'q_value', ylabel_suffix=' (Molecular Function)')

# %%
# interactive setting
filename_text = widgets.Text(value='', description='File Name:')
png_directory = f'../data/{line_enrichment}/png'
os.makedirs(png_directory, exist_ok=True)

def save_plot(button):
    global current_fig
    if current_fig:
        filename = filename_text.value
        if filename:  
            current_fig.savefig(f'{png_directory}/{filename}.png', dpi=800, bbox_inches='tight')
        else:
            current_fig.savefig(f'{png_directory}/enrichment_result.png', dpi=800, bbox_inches='tight')


save_button = widgets.Button(description="Save Plot")
save_button.on_click(save_plot)

def interactive_plot(data):
    w = interactive(
        plot_goslim_dotplot_with_lines,
        data=widgets.fixed(data),
        col1=widgets.Dropdown(options= [('fold enrichment', 'fold_enrichment'), 
                                        ('-log10(p-value)', '-log10(p-value)'), 
                                        ('-log10(q-value)', '-log10(q-value)')], 
                                        value='fold_enrichment', 
                                        description='x-axis:'),
        goslim_col=widgets.fixed('GOSlim'),
        col2=widgets.Dropdown(options=data.columns.tolist(), value='line counts', description='size:'),
        col3=widgets.Dropdown(options= [('fold enrichment', 'fold_enrichment'), 
                                        ('-log10(p-value)', '-log10(p-value)'), 
                                        ('-log10(q-value)', '-log10(q-value)')], 
                                        value='-log10(q-value)', 
                                        description='hue:'),
        ylabel_suffix=widgets.Dropdown(
            options=[('', ''), 
                     ('cc', '(Cellular Component)'), 
                     ('bp', '(Biological Process)'), 
                     ('mf', '(Molecular Function)')],
            value='',
            description='y-label suffix:'),
        width=widgets.IntSlider(min=1, max=30, step=1, value=6, description='width:', readout_format='0.0f'),
        height=widgets.IntSlider(min=1, max=30, step=1, value=9, description='height:', readout_format='0.0f'),
        palette=widgets.Dropdown(options=['flare', 'magma', 'viridis'], value='flare', description='color palette:')
        
    )
    display(w, filename_text, save_button)

# %%
interactive_plot(goslim_correspondence_with_p_q.copy())
# Out:
# interactive(children=(Dropdown(description='x-axis:', options=(('fold enrichment', 'fold_enrichment'), ('-log1…
# Text(value='', description='File Name:')
# Button(description='Save Plot', style=ButtonStyle())

# %%
interactive_plot(cc.copy())
# Out:
# interactive(children=(Dropdown(description='x-axis:', options=(('fold enrichment', 'fold_enrichment'), ('-log1…
# Text(value='enrichment_result_down_all', description='File Name:')
# Button(description='Save Plot', style=ButtonStyle())

# %%
interactive_plot(bp.copy())
# Out:
# interactive(children=(Dropdown(description='x-axis:', options=(('fold enrichment', 'fold_enrichment'), ('-log1…
# Text(value='enrichment_result_down_cc', description='File Name:')
# Button(description='Save Plot', style=ButtonStyle())

# %%
interactive_plot(mf.copy())
# Out:
# interactive(children=(Dropdown(description='x-axis:', options=(('fold enrichment', 'fold_enrichment'), ('-log1…
# Text(value='enrichment_result_down_bp', description='File Name:')
# Button(description='Save Plot', style=ButtonStyle())
