# %% [markdown]
# ## discription
#
# Circos plotの描画の処理内で行われている結合をこちらのファイルで行うことを目的に作成しました

# %%
import collections
import csv
import datetime
import os
import pandas as pd
import numpy as np
from collections import Counter

# %%
# output directory
direction = "UP"
now = datetime.datetime.now()
plot_up = f'../data/circos_hr_{direction}_{now.strftime("%y%m")}'
no_annotation = f'../data/{plot_up}/no_annotation_{direction}'
os.makedirs(plot_up, exist_ok=True)
os.makedirs(no_annotation, exist_ok=True)

# %% [markdown]
# ## HUMAN_UP
#
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#
# 2. Extract GOSlim corresponding to the list of up-regulated genes

# %%
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#organism = "human"
df_h_score = pd.read_csv("../data/human_annotation/human_position_up.tsv", sep='\t')
df_h_score_subset = df_h_score[['Gene stable ID', # create a subset
                        'Chromosome/scaffold name', 
                        'start2 (bp)',
                        'end2 (bp)',
                        'HN-score(HN5)']].copy()
df_h_score_subset['Chromosome/scaffold name'] = 'H_' + df_h_score_subset['Chromosome/scaffold name'].astype(str)
df_h_score_subset['organism'] = 'human'# assign the tag

df_h_score_subset.to_csv(f"../data/{plot_up}/human_position_up_assign.tsv", sep='\t', index=False)

display(df_h_score_subset)
# Out:
#       Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 0    ENSG00000173110                      H_1    161524540  161526894
# 1    ENSG00000204389                      H_6     31815543   31817946
# 2    ENSG00000204388                      H_6     31827738   31830254
# 3    ENSG00000132002                     H_19     14514769   14560391
# 4    ENSG00000151929                     H_10    119651380  119677819
# ..               ...                      ...          ...        ...
# 195  ENSG00000187049                     H_11     61392393   61398866
# 196  ENSG00000176381                      H_6    166305300  166308448
# 197  ENSG00000171931                     H_17     18744026   18779349
# 198  ENSG00000125998                     H_20     35285731   35292425
# 199  ENSG00000107742                     H_10     72059034   72089032
#
#      HN-score(HN5) organism
# 0              245    human
# 1              239    human
# 2              231    human
# 3              210    human
# 4              181    human
# ..             ...      ...
# 195             51    human
# 196             51    human
# 197             51    human
# 198             51    human
# 199             51    human
#
# [200 rows x 6 columns]

# %%
# 2. Extract GOSlim corresponding to the list of up-regulated genes
goslim_all_human = pd.read_csv('../data/biomart_goslim/biomart_human_goslim_R110_domain.tsv', sep='\t',
                               dtype={'Gene stable ID': 'object'}, 
                               low_memory=False)
columns_of_interest_human = ['Gene stable ID', 
                             'GOSlim GOA Accession(s)', 
                             'GOSlim GOA Description', 
                             'GOSlim_domain']
goslim_all_human_filtered = goslim_all_human[columns_of_interest_human]

extract_df_h_goslim = pd.merge(
    df_h_score_subset, 
    goslim_all_human_filtered, 
    on='Gene stable ID', 
    how='inner'
    )
extract_df_h_goslim = extract_df_h_goslim.drop_duplicates(subset=['Gene stable ID',
                                                                  'GOSlim GOA Accession(s)', 
                                                                  'GOSlim GOA Description'], keep='first').copy()

# Extract genes with no annotations
extract_df_h_goslim_with_indicator = pd.merge(
    df_h_score_subset, 
    goslim_all_human_filtered,
    left_on='Gene stable ID',
    right_on='Gene stable ID',
    how='left',
    indicator=True # add indicator column to show the difference
)

# extract_df_h_goslim_with_indicator
left_only_rows = extract_df_h_goslim_with_indicator[extract_df_h_goslim_with_indicator['_merge'] == 'left_only']

extract_df_h_goslim.to_csv(f"../data/{plot_up}/human_goslim_{direction}.tsv", sep='\t', index=False)
left_only_rows.to_csv(f"../data/{no_annotation}/human_position_up_no_annotation.tsv", sep='\t', index=False)

display(goslim_all_human_filtered)
display(extract_df_h_goslim)
display(left_only_rows)
# Out:
#          Gene stable ID GOSlim GOA Accession(s)  \
# 0       ENSG00000243485              GO:0031047
# 1       ENSG00000284332              GO:0031047
# 2       ENSG00000186092              GO:0023052
# 3       ENSG00000186092              GO:0060089
# 4       ENSG00000186092              GO:0005886
# ...                 ...                     ...
# 193923  ENSG00000292372              GO:0007010
# 193924  ENSG00000292372              GO:0008092
# 193925  ENSG00000292372              GO:0031410
# 193926  ENSG00000292372              GO:0043226
# 193927  ENSG00000292372              GO:0005768
#
#                GOSlim GOA Description       GOSlim_domain
# 0               gene silencing by RNA  biological_process
# 1               gene silencing by RNA  biological_process
# 2                           signaling  biological_process
# 3       molecular transducer activity  molecular_function
# 4                     plasma membrane  cellular_component
# ...                               ...                 ...
# 193923      cytoskeleton organization  biological_process
# 193924   cytoskeletal protein binding  molecular_function
# 193925            cytoplasmic vesicle  cellular_component
# 193926                      organelle  cellular_component
# 193927                       endosome  cellular_component
#
# [193928 rows x 4 columns]
#        Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 0     ENSG00000173110                      H_1    161524540  161526894
# 1     ENSG00000173110                      H_1    161524540  161526894
# 2     ENSG00000173110                      H_1    161524540  161526894
# 3     ENSG00000173110                      H_1    161524540  161526894
# 4     ENSG00000173110                      H_1    161524540  161526894
# ...               ...                      ...          ...        ...
# 1722  ENSG00000107742                     H_10     72059034   72089032
# 1723  ENSG00000107742                     H_10     72059034   72089032
# 1724  ENSG00000107742                     H_10     72059034   72089032
# 1725  ENSG00000107742                     H_10     72059034   72089032
# 1726  ENSG00000107742                     H_10     72059034   72089032
#
#       HN-score(HN5) organism GOSlim GOA Accession(s)  \
# 0               245    human              GO:0140657
# 1               245    human              GO:0044183
# 2               245    human              GO:0043226
# 3               245    human              GO:0005856
# 4               245    human              GO:0005815
# ...             ...      ...                     ...
# 1722             51    human              GO:0007155
# 1723             51    human              GO:1901135
# 1724             51    human              GO:0036211
# 1725             51    human              GO:0006790
# 1726             51    human              GO:0048870
#
#                          GOSlim GOA Description       GOSlim_domain
# 0                        ATP-dependent activity  molecular_function
# 1                     protein folding chaperone  molecular_function
# 2                                     organelle  cellular_component
# 3                                  cytoskeleton  cellular_component
# 4                 microtubule organizing center  cellular_component
# ...                                         ...                 ...
# 1722                              cell adhesion  biological_process
# 1723  carbohydrate derivative metabolic process  biological_process
# 1724               protein modification process  biological_process
# 1725          sulfur compound metabolic process  biological_process
# 1726                              cell motility  biological_process
#
# [1727 rows x 9 columns]
#        Gene stable ID Chromosome/scaffold name  start2 (bp)  end2 (bp)  \
# 251   ENSG00000182308                      H_4     41981756   41986465
# 323   ENSG00000189030                      H_1    156298624  156299307
# 375   ENSG00000176714                      H_2     27625638   27629012
# 376   ENSG00000181016                      H_7    112480853  112491062
# 435   ENSG00000187944                      H_2    196804417  196809355
# 698   ENSG00000268975                     H_19     40771648   40796943
# 707   ENSG00000249693                      H_4     56530606   56603507
# 747   ENSG00000197520                      H_1    222737202  222751004
# 801   ENSG00000187479                     H_11     43942637   43943878
# 854   ENSG00000241322                     H_17     15565483   15619704
# 906   ENSG00000179363                      H_X    103710909  103714032
# 1169  ENSG00000172771                      H_3    129401321  129428636
# 1364  ENSG00000174776                      H_3    167478684  167653983
# 1396  ENSG00000139597                     H_13     32400723   32428311
# 1592  ENSG00000173261                      H_5    146084313  146105577
# 1624  ENSG00000215274                      H_X     49303646   49319841
# 1672  ENSG00000283361                     H_13    114154691  114223085
# 1682  ENSG00000188959                      H_9    110190048  110208159
# 1693  ENSG00000177459                      H_8     98064522   98093610
# 1697  ENSG00000182013                     H_19     46466491   46471563
# 1732  ENSG00000176381                      H_6    166305300  166308448
#
#       HN-score(HN5) organism GOSlim GOA Accession(s) GOSlim GOA Description  \
# 251             141    human                     NaN                    NaN
# 323             121    human                     NaN                    NaN
# 375             113    human                     NaN                    NaN
# 376             113    human                     NaN                    NaN
# 435             100    human                     NaN                    NaN
# 698              80    human                     NaN                    NaN
# 707              79    human                     NaN                    NaN
# 747              75    human                     NaN                    NaN
# 801              72    human                     NaN                    NaN
# 854              71    human                     NaN                    NaN
# 906              70    human                     NaN                    NaN
# 1169             66    human                     NaN                    NaN
# 1364             59    human                     NaN                    NaN
# 1396             58    human                     NaN                    NaN
# 1592             55    human                     NaN                    NaN
# 1624             54    human                     NaN                    NaN
# 1672             53    human                     NaN                    NaN
# 1682             52    human                     NaN                    NaN
# 1693             52    human                     NaN                    NaN
# 1697             51    human                     NaN                    NaN
# 1732             51    human                     NaN                    NaN
#
#      GOSlim_domain     _merge
# 251            NaN  left_only
# 323            NaN  left_only
# 375            NaN  left_only
# 376            NaN  left_only
# 435            NaN  left_only
# 698            NaN  left_only
# 707            NaN  left_only
# 747            NaN  left_only
# 801            NaN  left_only
# 854            NaN  left_only
# 906            NaN  left_only
# 1169           NaN  left_only
# 1364           NaN  left_only
# 1396           NaN  left_only
# 1592           NaN  left_only
# 1624           NaN  left_only
# 1672           NaN  left_only
# 1682           NaN  left_only
# 1693           NaN  left_only
# 1697           NaN  left_only
# 1732           NaN  left_only

# %% [markdown]
# ## RICE_UP
#
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
#
# 2. Extract GOSlim corresponding to the list of up-regulated genes

# %%
# 1. Create a TSV file to plot genes with high HN-score on the Circos plot
df_r_score = pd.read_csv('../data/rice_annotation/rice_position_up.tsv', sep='\t')
df_r_score_subset = df_r_score[['Gene stable ID', # create a subset
                        'Chromosome/scaffold name', 
                        'start1 (bp)',
                        'end1 (bp)',
                        'HN-score(HN5)']].copy()
df_r_score_subset['Chromosome/scaffold name'] = 'R_' + df_r_score_subset['Chromosome/scaffold name'].astype(str)
df_r_score_subset['organism'] = 'rice'# assign the tag

df_r_score_subset.to_csv(f"../data/{plot_up}/rice_position_up_assign.tsv", sep='\t', index=False)

display(df_r_score_subset)
# Out:
#     Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0     Os04g0107900                      R_4       483234     485978
# 1     Os01g0136100                      R_1      1948773    1949587
# 2     Os02g0259900                      R_2      9021454    9023102
# 3     Os03g0245800                      R_3      7697015    7698027
# 4     Os03g0277300                      R_3      9411494    9416082
# ..             ...                      ...          ...        ...
# 384   Os03g0820400                      R_3     34427704   34428391
# 385   Os10g0328600                     R_10      9212944    9216458
# 386   Os01g0971800                      R_1     42874273   42875515
# 387   Os07g0621600                      R_7     25691906   25692138
# 388   Os04g0639000                      R_4     32476494   32477199
#
#      HN-score(HN5) organism
# 0              253     rice
# 1              246     rice
# 2              238     rice
# 3              237     rice
# 4              236     rice
# ..             ...      ...
# 384             42     rice
# 385             42     rice
# 386             42     rice
# 387             42     rice
# 388             42     rice
#
# [389 rows x 6 columns]

# %%
# 2. Extract GOSlim corresponding to the list of up-regulated genes
goslim_all_rice = pd.read_csv('../data/biomart_goslim/biomart_rice_goslim_R56_domain.tsv', sep='\t',
                               dtype={'Gene stable ID': 'object'}, 
                               low_memory=False)
columns_of_interest_rice = ['Gene stable ID',
                            'GOSlim GOA Accession(s)', 
                            'GOSlim GOA Description', 
                            'GOSlim_domain']
goslim_all_rice_filtered = goslim_all_rice[columns_of_interest_rice]

extract_df_r_goslim = pd.merge(
    df_r_score_subset, 
    goslim_all_rice_filtered, 
    on='Gene stable ID', 
    how='inner'
    )

extract_df_r_goslim = extract_df_r_goslim.drop_duplicates(subset=['Gene stable ID',
                                                                    'GOSlim GOA Accession(s)', 
                                                                    'GOSlim GOA Description'], keep='first').copy()

# Extract genes with no annotations
extract_df_r_goslim_with_indicator = pd.merge(
    df_r_score_subset, 
    goslim_all_rice_filtered,
    left_on='Gene stable ID',
    right_on='Gene stable ID',
    how='left',
    indicator=True # add indicator column to show the difference
)

# extract_df_r_goslim_with_indicator
left_only_rows = extract_df_r_goslim_with_indicator[extract_df_r_goslim_with_indicator['_merge'] == 'left_only']

extract_df_r_goslim.to_csv(f"../data/{plot_up}/rice_goslim_{direction}.tsv", sep='\t', index=False)
left_only_rows.to_csv(f"../data/{no_annotation}/rice_position_up_no_annotation.tsv", sep='\t', index=False)

display(goslim_all_rice_filtered)
display(extract_df_r_goslim)
display(left_only_rows)
# Out:
#        Gene stable ID GOSlim GOA Accession(s)        GOSlim GOA Description  \
# 0        Os01g0100100              GO:0006810                     transport
# 1        Os01g0100100              GO:0008150            biological_process
# 2        Os01g0100100              GO:0009987              cellular process
# 3        Os01g0100100              GO:0003674            molecular_function
# 4        Os01g0100100              GO:0030234     enzyme regulator activity
# ...               ...                     ...                           ...
# 219494     gene-rps19              GO:0003674            molecular_function
# 219495     gene-rps19              GO:0005198  structural molecule activity
# 219496     gene-rps19              GO:0005488                       binding
# 219497     gene-rps19              GO:0003723                   RNA binding
# 219498     gene-rps19              GO:0003676          nucleic acid binding
#
#              GOSlim_domain
# 0       biological_process
# 1       biological_process
# 2       biological_process
# 3       molecular_function
# 4       molecular_function
# ...                    ...
# 219494  molecular_function
# 219495  molecular_function
# 219496  molecular_function
# 219497  molecular_function
# 219498  molecular_function
#
# [219499 rows x 4 columns]
#      Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 0      Os04g0107900                      R_4       483234     485978
# 1      Os04g0107900                      R_4       483234     485978
# 2      Os04g0107900                      R_4       483234     485978
# 3      Os04g0107900                      R_4       483234     485978
# 4      Os04g0107900                      R_4       483234     485978
# ...             ...                      ...          ...        ...
# 2522   Os01g0971800                      R_1     42874273   42875515
# 2523   Os01g0971800                      R_1     42874273   42875515
# 2524   Os01g0971800                      R_1     42874273   42875515
# 2525   Os01g0971800                      R_1     42874273   42875515
# 2526   Os01g0971800                      R_1     42874273   42875515
#
#       HN-score(HN5) organism GOSlim GOA Accession(s)  \
# 0               253     rice              GO:0003674
# 1               253     rice              GO:0005515
# 2               253     rice              GO:0005488
# 3               253     rice              GO:0008150
# 4               253     rice              GO:0006950
# ...             ...      ...                     ...
# 2522             42     rice              GO:0008152
# 2523             42     rice              GO:0009058
# 2524             42     rice              GO:0006139
# 2525             42     rice              GO:0003700
# 2526             42     rice              GO:0140110
#
#                                 GOSlim GOA Description       GOSlim_domain
# 0                                   molecular_function  molecular_function
# 1                                      protein binding  molecular_function
# 2                                              binding  molecular_function
# 3                                   biological_process  biological_process
# 4                                   response to stress  biological_process
# ...                                                ...                 ...
# 2522                                 metabolic process  biological_process
# 2523                              biosynthetic process  biological_process
# 2524  nucleobase-containing compound metabolic process  biological_process
# 2525         DNA-binding transcription factor activity  molecular_function
# 2526                  transcription regulator activity  molecular_function
#
# [2527 rows x 9 columns]
#      Gene stable ID Chromosome/scaffold name  start1 (bp)  end1 (bp)  \
# 172    Os04g0108101                      R_4       485272     485663
# 173    Os01g0184050                      R_1      4449056    4449806
# 229    Os05g0296800                      R_5     13197199   13199560
# 243    Os11g0533400                     R_11     19430389   19431158
# 274    Os04g0578550                      R_4     29163356   29165144
# ...             ...                      ...          ...        ...
# 2588   Os11g0506700                     R_11     18069286   18071596
# 2589   Os03g0254250                      R_3      8134007    8134226
# 2642   Os10g0328600                     R_10      9212944    9216458
# 2657   Os07g0621600                      R_7     25691906   25692138
# 2658   Os04g0639000                      R_4     32476494   32477199
#
#       HN-score(HN5) organism GOSlim GOA Accession(s) GOSlim GOA Description  \
# 172             205     rice                     NaN                    NaN
# 173             205     rice                     NaN                    NaN
# 229             166     rice                     NaN                    NaN
# 243             165     rice                     NaN                    NaN
# 274             158     rice                     NaN                    NaN
# ...             ...      ...                     ...                    ...
# 2588             42     rice                     NaN                    NaN
# 2589             42     rice                     NaN                    NaN
# 2642             42     rice                     NaN                    NaN
# 2657             42     rice                     NaN                    NaN
# 2658             42     rice                     NaN                    NaN
#
#      GOSlim_domain     _merge
# 172            NaN  left_only
# 173            NaN  left_only
# 229            NaN  left_only
# 243            NaN  left_only
# 274            NaN  left_only
# ...            ...        ...
# 2588           NaN  left_only
# 2589           NaN  left_only
# 2642           NaN  left_only
# 2657           NaN  left_only
# 2658           NaN  left_only
#
# [132 rows x 10 columns]

# %% [markdown]
# ## COMBINED_UP( HUMAN_UP + RICE_UP )
#
# 1. chromosome position + gene position + HN-score
#
# 2. GOslim terms corresponding to the list of up-regulated genes

# %%
# 1. chromosome position + gene position + HN-score
combined_df_score = pd.concat([df_h_score_subset, 
                               df_r_score_subset])
combined_df_score.reset_index(drop=True, inplace=True)
combined_df_score['Gene start (bp)'] = combined_df_score['start1 (bp)'].combine_first(combined_df_score['start2 (bp)'])
combined_df_score['Gene end (bp)'] = combined_df_score['end1 (bp)'].combine_first(combined_df_score['end2 (bp)'])
combined_df_score.drop(['start1 (bp)', 'start2 (bp)', 'end1 (bp)', 'end2 (bp)'], axis=1, inplace=True)

combined_df_score.to_csv(f"../data/{plot_up}/combined_position_up.tsv", sep='\t', index=False)

display(combined_df_score)
# Out:
#       Gene stable ID Chromosome/scaffold name  HN-score(HN5) organism  \
# 0    ENSG00000173110                      H_1            245    human
# 1    ENSG00000204389                      H_6            239    human
# 2    ENSG00000204388                      H_6            231    human
# 3    ENSG00000132002                     H_19            210    human
# 4    ENSG00000151929                     H_10            181    human
# ..               ...                      ...            ...      ...
# 584     Os03g0820400                      R_3             42     rice
# 585     Os10g0328600                     R_10             42     rice
# 586     Os01g0971800                      R_1             42     rice
# 587     Os07g0621600                      R_7             42     rice
# 588     Os04g0639000                      R_4             42     rice
#
#      Gene start (bp)  Gene end (bp)
# 0        161524540.0    161526894.0
# 1         31815543.0     31817946.0
# 2         31827738.0     31830254.0
# 3         14514769.0     14560391.0
# 4        119651380.0    119677819.0
# ..               ...            ...
# 584       34427704.0     34428391.0
# 585        9212944.0      9216458.0
# 586       42874273.0     42875515.0
# 587       25691906.0     25692138.0
# 588       32476494.0     32477199.0
#
# [589 rows x 6 columns]

# %%
merged_df_goslim = pd.merge(
    extract_df_h_goslim, 
    extract_df_r_goslim, 
    left_on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'],
    right_on=['GOSlim GOA Accession(s)', 'GOSlim GOA Description', 'GOSlim_domain'],
    how='inner',
    suffixes=('_human', '_rice')
)

merged_df_goslim = merged_df_goslim[['GOSlim GOA Accession(s)',
                                     'GOSlim GOA Description',
                                     'GOSlim_domain',
                                     'Gene stable ID_rice',
                                     'Gene stable ID_human',
                                     'Chromosome/scaffold name_rice',
                                     'start1 (bp)',
                                     'end1 (bp)',
                                     'Chromosome/scaffold name_human',
                                     'start2 (bp)',
                                     'end2 (bp)',
                                     'HN-score(HN5)_rice',
                                     'HN-score(HN5)_human']]

# Remove duplicate rows based on specific columns
merged_df_goslim.drop_duplicates(inplace=True)

display(merged_df_goslim)
# Out:
#       GOSlim GOA Accession(s) GOSlim GOA Description       GOSlim_domain  \
# 0                  GO:0005856           cytoskeleton  cellular_component
# 1                  GO:0005856           cytoskeleton  cellular_component
# 2                  GO:0005856           cytoskeleton  cellular_component
# 3                  GO:0005856           cytoskeleton  cellular_component
# 4                  GO:0005856           cytoskeleton  cellular_component
# ...                       ...                    ...                 ...
# 15167              GO:0008289          lipid binding  molecular_function
# 15168              GO:0008289          lipid binding  molecular_function
# 15169              GO:0008289          lipid binding  molecular_function
# 15170              GO:0008289          lipid binding  molecular_function
# 15171              GO:0005840               ribosome  cellular_component
#
#       Gene stable ID_rice Gene stable ID_human Chromosome/scaffold name_rice  \
# 0            Os01g0257300      ENSG00000173110                           R_1
# 1            Os01g0257300      ENSG00000204389                           R_1
# 2            Os01g0257300      ENSG00000204388                           R_1
# 3            Os01g0257300      ENSG00000151929                           R_1
# 4            Os01g0257300      ENSG00000109846                           R_1
# ...                   ...                  ...                           ...
# 15167        Os04g0438600      ENSG00000174226                           R_4
# 15168        Os08g0546300      ENSG00000174226                           R_8
# 15169        Os01g0849000      ENSG00000174226                           R_1
# 15170        Os07g0659600      ENSG00000174226                           R_7
# 15171        Os11g0303800      ENSG00000112110                          R_11
#
#        start1 (bp)  end1 (bp) Chromosome/scaffold name_human  start2 (bp)  \
# 0          8586157    8586941                            H_1    161524540
# 1          8586157    8586941                            H_6     31815543
# 2          8586157    8586941                            H_6     31827738
# 3          8586157    8586941                           H_10    119651380
# 4          8586157    8586941                           H_11    111908564
# ...            ...        ...                            ...          ...
# 15167     21812159   21816137                            H_8    100572889
# 15168     27364165   27364816                            H_8    100572889
# 15169     36484020   36484818                            H_8    100572889
# 15170     27800556   27802446                            H_8    100572889
# 15171     11436951   11446262                            H_6    159789812
#
#        end2 (bp)  HN-score(HN5)_rice  HN-score(HN5)_human
# 0      161526894                  45                  245
# 1       31817946                  45                  239
# 2       31830254                  45                  231
# 3      119677819                  45                  181
# 4      111923722                  45                  173
# ...          ...                 ...                  ...
# 15167  100663415                  56                   51
# 15168  100663415                  54                   51
# 15169  100663415                  49                   51
# 15170  100663415                  43                   51
# 15171  159798436                  65                   63
#
# [15172 rows x 13 columns]

# %%
# for debugging purpose
unique_accessions_r = set(extract_df_r_goslim['GOSlim GOA Accession(s)'].unique())
unique_accessions_h = set(extract_df_h_goslim['GOSlim GOA Accession(s)'].unique())
common_accessions = unique_accessions_r.intersection(unique_accessions_h)
unique_accessions_merged = set(merged_df_goslim['GOSlim GOA Accession(s)'].unique())
missing_accessions = common_accessions.difference(unique_accessions_merged)
duplicates = merged_df_goslim.duplicated(subset=['GOSlim GOA Accession(s)', 'Gene stable ID_rice', 'Gene stable ID_human'], keep=False)
unique_combinations = not duplicates.any()
print(f"Number of common accessions: {len(common_accessions)}")
print(f"Number of missing accessions: {len(missing_accessions)}")
print(f"Missing accessions: {missing_accessions}")
print(f"各'Gene stable ID_rice'と'Gene stable ID_human'の組み合わせはユニークですか？: {unique_combinations}")

#Count the occurrences of each 'GOSlim GOA Accession(s)'
accession_counter = Counter(merged_df_goslim['GOSlim GOA Accession(s)'])

#Sort the DataFrame based on the counts
merged_df_goslim['count'] = merged_df_goslim['GOSlim GOA Accession(s)'].map(accession_counter)
merged_df_goslim_sorted = merged_df_goslim.sort_values('count', ascending=False).drop('count', axis=1)
merged_df_goslim_sorted.reset_index(drop=True, inplace=True)
merged_df_goslim_sorted.to_csv(f"../data/{plot_up}/combined_goslim_{direction}.tsv", sep='\t', index=False)

display(merged_df_goslim_sorted)
# Out:
# Number of common accessions: 29
# Number of missing accessions: 0
# Missing accessions: set()
# 各'Gene stable ID_rice'と'Gene stable ID_human'の組み合わせはユニークですか？: True
#       GOSlim GOA Accession(s)          GOSlim GOA Description  \
# 0                  GO:0003824              catalytic activity
# 1                  GO:0003824              catalytic activity
# 2                  GO:0003824              catalytic activity
# 3                  GO:0003824              catalytic activity
# 4                  GO:0003824              catalytic activity
# ...                       ...                             ...
# 15167              GO:0005198    structural molecule activity
# 15168              GO:0005777                      peroxisome
# 15169              GO:0005777                      peroxisome
# 15170              GO:0045182  translation regulator activity
# 15171              GO:0005840                        ribosome
#
#             GOSlim_domain Gene stable ID_rice Gene stable ID_human  \
# 0      molecular_function        Os04g0167875      ENSG00000178297
# 1      molecular_function        Os05g0135400      ENSG00000143199
# 2      molecular_function        Os02g0164000      ENSG00000143199
# 3      molecular_function        Os08g0473900      ENSG00000143199
# 4      molecular_function        Os09g0315700      ENSG00000143199
# ...                   ...                 ...                  ...
# 15167  molecular_function        Os01g0105800      ENSG00000184697
# 15168  cellular_component        Os07g0529000      ENSG00000165507
# 15169  cellular_component        Os06g0253100      ENSG00000165507
# 15170  molecular_function        Os05g0373900      ENSG00000183655
# 15171  cellular_component        Os11g0303800      ENSG00000112110
#
#       Chromosome/scaffold name_rice  start1 (bp)  end1 (bp)  \
# 0                               R_4      4644736    4644996
# 1                               R_5      2073613    2075302
# 2                               R_2      3441185    3446850
# 3                               R_8     23341289   23343299
# 4                               R_9      8692296    8697399
# ...                             ...          ...        ...
# 15167                           R_1       306871     308842
# 15168                           R_7     20691213   20693521
# 15169                           R_6      7940956    7941680
# 15170                           R_5     18016742   18020353
# 15171                          R_11     11436951   11446262
#
#       Chromosome/scaffold name_human  start2 (bp)  end2 (bp)  \
# 0                               H_19      2360238    2426261
# 1                                H_1    167809386  167914215
# 2                                H_1    167809386  167914215
# 3                                H_1    167809386  167914215
# 4                                H_1    167809386  167914215
# ...                              ...          ...        ...
# 15167                           H_16      3014712    3020071
# 15168                           H_10     44970981   44978809
# 15169                           H_10     44970981   44978809
# 15170                           H_15     85759326   85794925
# 15171                            H_6    159789812  159798436
#
#        HN-score(HN5)_rice  HN-score(HN5)_human
# 0                      57                   72
# 1                      61                   97
# 2                      48                   97
# 3                      48                   97
# 4                      49                   97
# ...                   ...                  ...
# 15167                  53                   65
# 15168                  59                   70
# 15169                 129                   70
# 15170                  42                   74
# 15171                  65                   63
#
# [15172 rows x 13 columns]

# %% [markdown]
# ## Merge GOslim terms and line enrichment results

# %%
enrichment = pd.read_csv('../data/goslim_correspondence_q_values/goslim_correspondence_fold_enrichment_p_q.tsv', sep='\t')

merged_df_goslim_sorted["GOSlim"] = merged_df_goslim_sorted['GOSlim GOA Accession(s)'] + ": " + merged_df_goslim_sorted['GOSlim GOA Description']

merged_df_goslim_sorted = merged_df_goslim_sorted[['GOSlim',
                                                    'GOSlim GOA Accession(s)',
                                                    'GOSlim GOA Description',
                                                    'GOSlim_domain',
                                                    'Gene stable ID_rice',
                                                    'Gene stable ID_human',
                                                    'Chromosome/scaffold name_rice',
                                                    'start1 (bp)',
                                                    'end1 (bp)',
                                                    'Chromosome/scaffold name_human',
                                                    'start2 (bp)',
                                                    'end2 (bp)',
                                                    'HN-score(HN5)_rice',
                                                    'HN-score(HN5)_human']]


merged_df_goslim_enrichment = pd.merge(
    merged_df_goslim_sorted,
    enrichment[['GOSlim', 'fold_enrichment', 'p_value', 'q_value']],
    on='GOSlim',
    how='left'
)
merged_df_goslim_enrichment.sort_values('fold_enrichment', ascending=False, inplace=True)
merged_df_goslim_enrichment.reset_index(drop=True, inplace=True)
merged_df_goslim_enrichment.to_csv(f"../data/{plot_up}/combined_goslim_enrichment_{direction}.tsv", sep='\t', index=False)

display(enrichment)
display(merged_df_goslim_sorted)
display(merged_df_goslim_enrichment)
# Out:
#                                                GOSlim  counts_up  counts_all  \
# 0                   GO:0005783: endoplasmic reticulum        588     1919256
# 1   GO:0006091: generation of precursor metabolite...         55      265631
# 2                           GO:0008289: lipid binding         49      257535
# 3        GO:0140110: transcription regulator activity        396     2256826
# 4                                 GO:0005829: cytosol       1248     7811118
# 5                    GO:0005576: extracellular region        600     3845282
# 6                           GO:0005739: mitochondrion        280     1951236
# 7          GO:0005975: carbohydrate metabolic process         84      676139
# 8        GO:0048856: anatomical structure development        819     7216908
# 9                              GO:0005777: peroxisome          2       18172
# 10                     GO:0016787: hydrolase activity        912     8674587
# 11                            GO:0003677: DNA binding        546     5819761
# 12                                GO:0005773: vacuole         32      422166
# 13                                GO:0005634: nucleus       3550    50586355
# 14                GO:0006629: lipid metabolic process        102     1517670
# 15                     GO:0003824: catalytic activity       4136    62834292
# 16                            GO:0005654: nucleoplasm         80     1522420
# 17                        GO:0005886: plasma membrane        676    14121523
# 18                   GO:0005215: transporter activity         80     1929898
# 19                           GO:0005856: cytoskeleton         30      725760
# 20                   GO:0030154: cell differentiation         49     1272360
# 21                            GO:0003723: RNA binding        170     4482192
# 22           GO:0036211: protein modification process        418    11265607
# 23         GO:0045182: translation regulator activity          1       30420
# 24                        GO:0005794: Golgi apparatus         39     1563150
# 25                              GO:0005730: nucleolus         13      566826
# 26                   GO:0016740: transferase activity        204    10856023
# 27           GO:0005198: structural molecule activity         12      650310
# 28                               GO:0005840: ribosome          1      252420
#
#     up_ratio  all_ratio  fold_enrichment        p_value        q_value
# 0   0.038756   0.009318         4.159016  2.539107e-175  8.632965e-174
# 1   0.003625   0.001290         2.810801   3.966800e-11   1.685890e-10
# 2   0.003230   0.001250         2.582890   6.223319e-09   2.351032e-08
# 3   0.026101   0.010957         2.382008   1.889550e-52   1.606117e-51
# 4   0.082257   0.037925         2.168940  8.805413e-137  1.496920e-135
# 5   0.039547   0.018670         2.118211   9.704598e-62   1.099854e-60
# 6   0.018455   0.009474         1.948024   3.221263e-24   1.564614e-23
# 7   0.005537   0.003283         1.686512   5.992973e-06   1.852373e-05
# 8   0.053981   0.035040         1.540561   2.844564e-32   1.934304e-31
# 9   0.000132   0.000088         1.494078   3.868057e-01   1.000000e+00
# 10  0.060111   0.042117         1.427224   1.506186e-25   8.535052e-25
# 11  0.035987   0.028256         1.273602   1.870129e-08   6.358439e-08
# 12  0.002109   0.002050         1.028994   4.594621e-01   1.000000e+00
# 13  0.233984   0.245609         0.952667   9.996001e-01   1.000000e+00
# 14  0.006723   0.007369         0.912366   8.357564e-01   1.000000e+00
# 15  0.272607   0.305076         0.893573   1.000000e+00   1.000000e+00
# 16  0.005273   0.007392         0.713348   9.994202e-01   1.000000e+00
# 17  0.044556   0.068563         0.649847   1.000000e+00   1.000000e+00
# 18  0.005273   0.009370         0.562732   1.000000e+00   1.000000e+00
# 19  0.001977   0.003524         0.561144   9.998176e-01   1.000000e+00
# 20  0.003230   0.006178         0.522796   9.999999e-01   1.000000e+00
# 21  0.011205   0.021762         0.514878   1.000000e+00   1.000000e+00
# 22  0.027551   0.054697         0.503695   1.000000e+00   1.000000e+00
# 23  0.000066   0.000148         0.446259   8.936585e-01   1.000000e+00
# 24  0.002571   0.007589         0.338696   1.000000e+00   1.000000e+00
# 25  0.000857   0.002752         0.311343   9.999999e-01   1.000000e+00
# 26  0.013446   0.052709         0.255097   1.000000e+00   1.000000e+00
# 27  0.000791   0.003157         0.250500   1.000000e+00   1.000000e+00
# 28  0.000066   0.001226         0.053780   1.000000e+00   1.000000e+00
#                                            GOSlim GOSlim GOA Accession(s)  \
# 0                  GO:0003824: catalytic activity              GO:0003824
# 1                  GO:0003824: catalytic activity              GO:0003824
# 2                  GO:0003824: catalytic activity              GO:0003824
# 3                  GO:0003824: catalytic activity              GO:0003824
# 4                  GO:0003824: catalytic activity              GO:0003824
# ...                                           ...                     ...
# 15167    GO:0005198: structural molecule activity              GO:0005198
# 15168                      GO:0005777: peroxisome              GO:0005777
# 15169                      GO:0005777: peroxisome              GO:0005777
# 15170  GO:0045182: translation regulator activity              GO:0045182
# 15171                        GO:0005840: ribosome              GO:0005840
#
#                GOSlim GOA Description       GOSlim_domain Gene stable ID_rice  \
# 0                  catalytic activity  molecular_function        Os04g0167875
# 1                  catalytic activity  molecular_function        Os05g0135400
# 2                  catalytic activity  molecular_function        Os02g0164000
# 3                  catalytic activity  molecular_function        Os08g0473900
# 4                  catalytic activity  molecular_function        Os09g0315700
# ...                               ...                 ...                 ...
# 15167    structural molecule activity  molecular_function        Os01g0105800
# 15168                      peroxisome  cellular_component        Os07g0529000
# 15169                      peroxisome  cellular_component        Os06g0253100
# 15170  translation regulator activity  molecular_function        Os05g0373900
# 15171                        ribosome  cellular_component        Os11g0303800
#
#       Gene stable ID_human Chromosome/scaffold name_rice  start1 (bp)  \
# 0          ENSG00000178297                           R_4      4644736
# 1          ENSG00000143199                           R_5      2073613
# 2          ENSG00000143199                           R_2      3441185
# 3          ENSG00000143199                           R_8     23341289
# 4          ENSG00000143199                           R_9      8692296
# ...                    ...                           ...          ...
# 15167      ENSG00000184697                           R_1       306871
# 15168      ENSG00000165507                           R_7     20691213
# 15169      ENSG00000165507                           R_6      7940956
# 15170      ENSG00000183655                           R_5     18016742
# 15171      ENSG00000112110                          R_11     11436951
#
#        end1 (bp) Chromosome/scaffold name_human  start2 (bp)  end2 (bp)  \
# 0        4644996                           H_19      2360238    2426261
# 1        2075302                            H_1    167809386  167914215
# 2        3446850                            H_1    167809386  167914215
# 3       23343299                            H_1    167809386  167914215
# 4        8697399                            H_1    167809386  167914215
# ...          ...                            ...          ...        ...
# 15167     308842                           H_16      3014712    3020071
# 15168   20693521                           H_10     44970981   44978809
# 15169    7941680                           H_10     44970981   44978809
# 15170   18020353                           H_15     85759326   85794925
# 15171   11446262                            H_6    159789812  159798436
#
#        HN-score(HN5)_rice  HN-score(HN5)_human
# 0                      57                   72
# 1                      61                   97
# 2                      48                   97
# 3                      48                   97
# 4                      49                   97
# ...                   ...                  ...
# 15167                  53                   65
# 15168                  59                   70
# 15169                 129                   70
# 15170                  42                   74
# 15171                  65                   63
#
# [15172 rows x 14 columns]
#                                          GOSlim GOSlim GOA Accession(s)  \
# 0             GO:0005783: endoplasmic reticulum              GO:0005783
# 1             GO:0005783: endoplasmic reticulum              GO:0005783
# 2             GO:0005783: endoplasmic reticulum              GO:0005783
# 3             GO:0005783: endoplasmic reticulum              GO:0005783
# 4             GO:0005783: endoplasmic reticulum              GO:0005783
# ...                                         ...                     ...
# 15167  GO:0005198: structural molecule activity              GO:0005198
# 15168  GO:0005198: structural molecule activity              GO:0005198
# 15169  GO:0005198: structural molecule activity              GO:0005198
# 15170  GO:0005198: structural molecule activity              GO:0005198
# 15171                      GO:0005840: ribosome              GO:0005840
#
#              GOSlim GOA Description       GOSlim_domain Gene stable ID_rice  \
# 0             endoplasmic reticulum  cellular_component        Os03g0822700
# 1             endoplasmic reticulum  cellular_component        Os03g0263700
# 2             endoplasmic reticulum  cellular_component        Os06g0593100
# 3             endoplasmic reticulum  cellular_component        Os08g0442200
# 4             endoplasmic reticulum  cellular_component        Os03g0263700
# ...                             ...                 ...                 ...
# 15167  structural molecule activity  molecular_function        Os01g0105800
# 15168  structural molecule activity  molecular_function        Os03g0276700
# 15169  structural molecule activity  molecular_function        Os03g0276700
# 15170  structural molecule activity  molecular_function        Os01g0105800
# 15171                      ribosome  cellular_component        Os11g0303800
#
#       Gene stable ID_human Chromosome/scaffold name_rice  start1 (bp)  \
# 0          ENSG00000160963                           R_3     34536280
# 1          ENSG00000170345                           R_3      8668092
# 2          ENSG00000204388                           R_6     23303671
# 3          ENSG00000204388                           R_8     21549721
# 4          ENSG00000204388                           R_3      8668092
# ...                    ...                           ...          ...
# 15167      ENSG00000109846                           R_1       306871
# 15168      ENSG00000109846                           R_3      9375984
# 15169      ENSG00000112110                           R_3      9375984
# 15170      ENSG00000112110                           R_1       306871
# 15171      ENSG00000112110                          R_11     11436951
#
#        end1 (bp) Chromosome/scaffold name_human  start2 (bp)  end2 (bp)  \
# 0       34539296                            H_7    101362875  101559024
# 1        8671028                           H_14     75278826   75282230
# 2       23306966                            H_6     31827738   31830254
# 3       21551326                            H_6     31827738   31830254
# 4        8671028                            H_6     31827738   31830254
# ...          ...                            ...          ...        ...
# 15167     308842                           H_11    111908564  111923722
# 15168    9377688                           H_11    111908564  111923722
# 15169    9377688                            H_6    159789812  159798436
# 15170     308842                            H_6    159789812  159798436
# 15171   11446262                            H_6    159789812  159798436
#
#        HN-score(HN5)_rice  HN-score(HN5)_human  fold_enrichment  \
# 0                      50                   67         4.159016
# 1                      48                  165         4.159016
# 2                      48                  231         4.159016
# 3                      48                  231         4.159016
# 4                      48                  231         4.159016
# ...                   ...                  ...              ...
# 15167                  53                  173         0.250500
# 15168                  99                  173         0.250500
# 15169                  99                   63         0.250500
# 15170                  53                   63         0.250500
# 15171                  65                   63         0.053780
#
#              p_value        q_value
# 0      2.539107e-175  8.632965e-174
# 1      2.539107e-175  8.632965e-174
# 2      2.539107e-175  8.632965e-174
# 3      2.539107e-175  8.632965e-174
# 4      2.539107e-175  8.632965e-174
# ...              ...            ...
# 15167   1.000000e+00   1.000000e+00
# 15168   1.000000e+00   1.000000e+00
# 15169   1.000000e+00   1.000000e+00
# 15170   1.000000e+00   1.000000e+00
# 15171   1.000000e+00   1.000000e+00
#
# [15172 rows x 17 columns]
