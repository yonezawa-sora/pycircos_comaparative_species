# %%
import pandas as pd

# %%
# human HN-score data
# https://doi.org/10.6084/m9.figshare.23944935.v2
df = pd.read_csv("../data/HN-score_human/HN-score_human_all.csv", sep=",")
total_lines = len(df)

# Upregulated genes
df_up = pd.read_csv("../data/HN-score_human/HN5_genes_up_human.tsv", sep="\t") #fix 

# Downregulated genes
df_down = pd.read_csv("../data/HN-score_human/HN5_genes_down_human.tsv", sep="\t")

display(df)
display(df_up)
display(df_down)
# Out:
#       GeneName  up5  dn5  unchange5  all  HN5
# 0        HSPA6  247    2         73  322  245
# 1       HSPA1A  240    1         81  322  239
# 2       HSPA1B  233    2         87  322  231
# 3       DNAJB1  212    2        108  322  210
# 4         BAG3  182    1        139  322  181
# ...        ...  ...  ...        ...  ...  ...
# 19700    N4BP1    3   44        275  322  -41
# 19701   ZNF784    8   50        264  322  -42
# 19702    TSSK3   28   71        223  322  -43
# 19703    HRCT1    7   59        256  322  -52
# 19704     H1-3   10   81        231  322  -71
#
# [19705 rows x 6 columns]
#     GeneName  up5  dn5  unchange5  all  HN5
# 0      HSPA6  247    2         73  322  245
# 1     HSPA1A  240    1         81  322  239
# 2     HSPA1B  233    2         87  322  231
# 3     DNAJB1  212    2        108  322  210
# 4       BAG3  182    1        139  322  181
# ..       ...  ...  ...        ...  ...  ...
# 195   FBXW10   52    1        269  322   51
# 196   SPOCK2   52    1        269  322   51
# 197     SBSN   53    2        267  322   51
# 198   PNMA8A   53    2        267  322   51
# 199    SNX31   61   10        251  322   51
#
# [200 rows x 6 columns]
#      GeneName  up5  dn5  unchange5  all  HN5
# 0        E2F8    5   19        298  322  -14
# 1       TRIB3    5   19        298  322  -14
# 2     TSNARE1   11   25        286  322  -14
# 3       CLCF1    4   18        300  322  -14
# 4    PRAMEF17    2   16        304  322  -14
# ..        ...  ...  ...        ...  ...  ...
# 199     N4BP1    3   44        275  322  -41
# 200    ZNF784    8   50        264  322  -42
# 201     TSSK3   28   71        223  322  -43
# 202     HRCT1    7   59        256  322  -52
# 203      H1-3   10   81        231  322  -71
#
# [204 rows x 6 columns]

# %% [markdown]
# ## Convert the gene names to Ensemble gene IDs

# %%
# Get ensemble gene ID from gProfiler UP 1%
df2 = pd.read_csv("../data/gprofiler/gProfiler_hsapiens_2023-11-5 14-34-25.csv", sep=",")
df2_ID = df2[["initial_alias", "converted_alias", "name"]]

# check duplicates
duplicates = df2_ID[df2_ID.duplicated(subset=["initial_alias"], keep=False)]

merged_df_up = pd.merge(  df_up, 
                          df2_ID, 
                          left_on="GeneName", 
                          right_on="initial_alias", 
                          how="inner")

gene_names_up = set(df_up['GeneName'])
gene_names_merged = set(merged_df_up['GeneName'])
missing_gene_names = gene_names_up - gene_names_merged
missing_rows = df_up[df_up['GeneName'].isin(missing_gene_names)]
print(missing_rows)

UP = merged_df_up[["converted_alias", "HN5", "name"]].copy()
UP.rename(columns={'HN5': 'HN-score(HN5)'}, inplace=True)

merged_df_down = pd.merge(df_down,
                           df2_ID,
                            left_on="GeneName",
                            right_on="initial_alias",
                            how="inner")

DOWN = merged_df_down[["converted_alias", "HN5", "name"]].copy()
DOWN.rename(columns={'HN5': 'HN-score(HN5)'}, inplace=True)

COMBINED = pd.concat(
    [UP, DOWN],
    ignore_index=True
)

display(df2_ID)
display(duplicates)
display(UP)
display(DOWN)
display(COMBINED)
# Out:
# Empty DataFrame
# Columns: [GeneName, up5, dn5, unchange5, all, HN5]
# Index: []
#     initial_alias  converted_alias     name
# 0            ACCS  ENSG00000110455     ACCS
# 1          ACTRT3  ENSG00000184378   ACTRT3
# 2          ADCY10  ENSG00000143199   ADCY10
# 3          ADGRF1  ENSG00000153292   ADGRF1
# 4         ADORA2A  ENSG00000128271  ADORA2A
# ..            ...              ...      ...
# 399        ZNF624  ENSG00000197566   ZNF624
# 400        ZNF627  ENSG00000198551   ZNF627
# 401        ZNF775  ENSG00000196456   ZNF775
# 402        ZNF784  ENSG00000179922   ZNF784
# 403        ZNF792  ENSG00000180884   ZNF792
#
# [404 rows x 3 columns]
# Empty DataFrame
# Columns: [initial_alias, converted_alias, name]
# Index: []
#      converted_alias  HN-score(HN5)    name
# 0    ENSG00000173110            245   HSPA6
# 1    ENSG00000204389            239  HSPA1A
# 2    ENSG00000204388            231  HSPA1B
# 3    ENSG00000132002            210  DNAJB1
# 4    ENSG00000151929            181    BAG3
# ..               ...            ...     ...
# 195  ENSG00000171931             51  FBXW10
# 196  ENSG00000107742             51  SPOCK2
# 197  ENSG00000189001             51    SBSN
# 198  ENSG00000182013             51  PNMA8A
# 199  ENSG00000174226             51   SNX31
#
# [200 rows x 3 columns]
#      converted_alias  HN-score(HN5)      name
# 0    ENSG00000129173            -14      E2F8
# 1    ENSG00000101255            -14     TRIB3
# 2    ENSG00000171045            -14   TSNARE1
# 3    ENSG00000175505            -14     CLCF1
# 4    ENSG00000204479            -14  PRAMEF17
# ..               ...            ...       ...
# 199  ENSG00000102921            -41     N4BP1
# 200  ENSG00000179922            -42    ZNF784
# 201  ENSG00000162526            -43     TSSK3
# 202  ENSG00000196196            -52     HRCT1
# 203  ENSG00000124575            -71      H1-3
#
# [204 rows x 3 columns]
#      converted_alias  HN-score(HN5)    name
# 0    ENSG00000173110            245   HSPA6
# 1    ENSG00000204389            239  HSPA1A
# 2    ENSG00000204388            231  HSPA1B
# 3    ENSG00000132002            210  DNAJB1
# 4    ENSG00000151929            181    BAG3
# ..               ...            ...     ...
# 399  ENSG00000102921            -41   N4BP1
# 400  ENSG00000179922            -42  ZNF784
# 401  ENSG00000162526            -43   TSSK3
# 402  ENSG00000196196            -52   HRCT1
# 403  ENSG00000124575            -71    H1-3
#
# [404 rows x 3 columns]

# %% [markdown]
# ## merge the Ensembl biomart data (position)
#
# - For drawing Circos plot

# %%
df_ensembl_position = pd.read_csv("../data/biomart_goslim/biomart_human_position_R110.tsv", sep="\t")

# 1. merged all data
merged_df_position = pd.merge(
    df_ensembl_position,
    COMBINED,
    left_on="Gene stable ID",
    right_on="converted_alias",
    how="inner"
)
merged_df_position = merged_df_position.drop(columns=['converted_alias'])
merged_df_position = merged_df_position.sort_values(by='HN-score(HN5)', ascending=False).copy()
merged_df_position.to_csv("../data/human_annotation/human_position_all.tsv", sep="\t" , index=False)

# 2. merged up genes data
merged_df_position_up = pd.merge(
    df_ensembl_position,
    UP,
    left_on="Gene stable ID",
    right_on="converted_alias",
    how="inner"
)
merged_df_position_up = merged_df_position_up.drop(columns=['converted_alias'])
merged_df_position_up = merged_df_position_up.sort_values(by='HN-score(HN5)', ascending=False).copy()
merged_df_position_up.to_csv("../data/human_annotation/human_position_up.tsv", sep="\t", index=False)

# 3. merged down genes data
merged_df_position_down = pd.merge(
    df_ensembl_position,
    DOWN,
    left_on="Gene stable ID",
    right_on="converted_alias",
    how="inner"
)
merged_df_position_down = merged_df_position_down.drop(columns=['converted_alias'])
merged_df_position_down = merged_df_position_down.sort_values(by='HN-score(HN5)', ascending=False).copy()
merged_df_position_down.to_csv("../data/human_annotation/human_position_down.tsv", sep="\t", index=False)

display(df_ensembl_position)
display(merged_df_position)
display(merged_df_position_up)
display(merged_df_position_down)
# Out:
#         Gene stable ID Chromosome/scaffold name  Gene start (bp)  \
# 0      ENSG00000210049                       MT              577
# 1      ENSG00000211459                       MT              648
# 2      ENSG00000210077                       MT             1602
# 3      ENSG00000210082                       MT             1671
# 4      ENSG00000209082                       MT             3230
# ...                ...                      ...              ...
# 70111  ENSG00000236500                        1         15614643
# 70112  ENSG00000197312                        1         15617458
# 70113  ENSG00000215695                        1         15659713
# 70114  ENSG00000271742                        1         15682873
# 70115  ENSG00000116786                        1         15684320
#
#        Gene end (bp)  Strand
# 0                647       1
# 1               1601       1
# 2               1670       1
# 3               3229       1
# 4               3304       1
# ...              ...     ...
# 70111       15614867      -1
# 70112       15669044       1
# 70113       15662033       1
# 70114       15683128      -1
# 70115       15734769       1
#
# [70116 rows x 5 columns]
#       Gene stable ID Chromosome/scaffold name  Gene start (bp)  Gene end (bp)  \
# 294  ENSG00000173110                        1        161524540      161526894
# 155  ENSG00000204389                        6         31815543       31817946
# 156  ENSG00000204388                        6         31827738       31830254
# 203  ENSG00000132002                       19         14514769       14560391
# 88   ENSG00000151929                       10        119651380      119677819
# ..               ...                      ...              ...            ...
# 37   ENSG00000102921                       16         48538726       48620148
# 160  ENSG00000179922                       19         55620741       55624566
# 317  ENSG00000162526                        1         32351521       32364312
# 66   ENSG00000196196                        9         35906202       35907136
# 195  ENSG00000124575                        6         26234212       26234987
#
#      Strand  HN-score(HN5)    name
# 294       1            245   HSPA6
# 155       1            239  HSPA1A
# 156       1            231  HSPA1B
# 203      -1            210  DNAJB1
# 88        1            181    BAG3
# ..      ...            ...     ...
# 37       -1            -41   N4BP1
# 160      -1            -42  ZNF784
# 317       1            -43   TSSK3
# 66        1            -52   HRCT1
# 195      -1            -71    H1-3
#
# [404 rows x 7 columns]
#       Gene stable ID Chromosome/scaffold name  Gene start (bp)  Gene end (bp)  \
# 143  ENSG00000173110                        1        161524540      161526894
# 74   ENSG00000204389                        6         31815543       31817946
# 75   ENSG00000204388                        6         31827738       31830254
# 97   ENSG00000132002                       19         14514769       14560391
# 38   ENSG00000151929                       10        119651380      119677819
# ..               ...                      ...              ...            ...
# 157  ENSG00000187049                       11         61392393       61398866
# 52   ENSG00000176381                        6        166305300      166308448
# 51   ENSG00000171931                       17         18744026       18779349
# 7    ENSG00000125998                       20         35285731       35292425
# 145  ENSG00000107742                       10         72059034       72089032
#
#      Strand  HN-score(HN5)     name
# 143       1            245    HSPA6
# 74        1            239   HSPA1A
# 75        1            231   HSPA1B
# 97       -1            210   DNAJB1
# 38        1            181     BAG3
# ..      ...            ...      ...
# 157       1             51  TMEM216
# 52       -1             51    PRR18
# 51        1             51   FBXW10
# 7        -1             51   FAM83C
# 145      -1             51   SPOCK2
#
# [200 rows x 7 columns]
#       Gene stable ID Chromosome/scaffold name  Gene start (bp)  Gene end (bp)  \
# 164  ENSG00000170473                       12         55901413       55932618
# 19   ENSG00000184675                        X         64185117       64205708
# 124  ENSG00000161653                       17         44004622       44009068
# 23   ENSG00000100281                       22         35257452       35295807
# 126  ENSG00000132773                        1         45340052       45343973
# ..               ...                      ...              ...            ...
# 18   ENSG00000102921                       16         48538726       48620148
# 82   ENSG00000179922                       19         55620741       55624566
# 165  ENSG00000162526                        1         32351521       32364312
# 34   ENSG00000196196                        9         35906202       35907136
# 100  ENSG00000124575                        6         26234212       26234987
#
#      Strand  HN-score(HN5)    name
# 164      -1            -14    PYM1
# 19       -1            -14   AMER1
# 124       1            -14    NAGS
# 23        1            -14  HMGXB4
# 126       1            -14    TOE1
# ..      ...            ...     ...
# 18       -1            -41   N4BP1
# 82       -1            -42  ZNF784
# 165       1            -43   TSSK3
# 34        1            -52   HRCT1
# 100      -1            -71    H1-3
#
# [204 rows x 7 columns]

# %% [markdown]
# ## merge the Ensembl biomart data (GOslim)
#
# - For exexution of GO enrichment analysis

# %%
df_ensembl = pd.read_csv("../data/biomart_goslim/biomart_human_goslim_R110.tsv", sep="\t")
df_ensembl_uniq = df_ensembl.drop_duplicates(subset=['Gene stable ID', 'GOSlim GOA Accession(s)', 'GOSlim GOA Description'], keep='first').copy()
df_ensembl_uniq.rename(columns={'start2 (bp)': 'Gene start(bp)'}, inplace=True)
df_ensembl_uniq.rename(columns={'end2 (bp)': 'Gene end(bp)'}, inplace=True)

# 1. merge all data
merged_df = pd.merge(df_ensembl_uniq,COMBINED,
                        left_on="Gene stable ID",
                        right_on="converted_alias",
                     how="inner")

merged_df = merged_df.drop(columns=['converted_alias'])
merged_df = merged_df.sort_values(by='HN-score(HN5)', ascending=False).copy()
merged_df.to_csv("../data/human_annotation/human_annotation.tsv", sep="\t" , index=False)
merged_df

# 2. merge UP data
merged_df_up = pd.merge(df_ensembl_uniq,UP,
                        left_on="Gene stable ID",
                        right_on="converted_alias",
                     how="inner")

merged_df_up = merged_df_up.drop(columns=['converted_alias'])
merged_df_up = merged_df_up.sort_values(by='HN-score(HN5)', ascending=False).copy()
merged_df_up.to_csv("../data/human_annotation/human_annotation_up.tsv", sep="\t" , index=False)

# 3. merge DOWN data
merged_df_down = pd.merge(df_ensembl_uniq,DOWN,
                        left_on="Gene stable ID",
                        right_on="converted_alias",
                     how="inner")

merged_df_down = merged_df_down.drop(columns=['converted_alias'])
merged_df_down = merged_df_down.sort_values(by='HN-score(HN5)', ascending=False).copy()
merged_df_down.to_csv("../data/human_annotation/human_annotation_down.tsv", sep="\t", index=False)

display(df_ensembl_uniq)
display(merged_df)
display(merged_df_up)
display(merged_df_down)
# Out:
# /tmp/ipykernel_20691/2250984159.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ensembl = pd.read_csv("../data/biomart_goslim/biomart_human_goslim_R110.tsv", sep="\t")
#          Gene stable ID Chromosome/scaffold name  Gene start(bp)  \
# 0       ENSG00000243485                        1           29554
# 1       ENSG00000284332                        1           30366
# 2       ENSG00000186092                        1           65419
# 3       ENSG00000186092                        1           65419
# 4       ENSG00000186092                        1           65419
# ...                 ...                      ...             ...
# 581396  ENSG00000292372                        Y        57207346
# 581397  ENSG00000292372                        Y        57207346
# 581398  ENSG00000292372                        Y        57207346
# 581399  ENSG00000292372                        Y        57207346
# 581400  ENSG00000292372                        Y        57207346
#
#         Gene end(bp) GOSlim GOA Accession(s)         GOSlim GOA Description
# 0              31109              GO:0031047          gene silencing by RNA
# 1              30503              GO:0031047          gene silencing by RNA
# 2              71585              GO:0023052                      signaling
# 3              71585              GO:0060089  molecular transducer activity
# 4              71585              GO:0005886                plasma membrane
# ...              ...                     ...                            ...
# 581396      57212230              GO:0007010      cytoskeleton organization
# 581397      57212230              GO:0008092   cytoskeletal protein binding
# 581398      57212230              GO:0031410            cytoplasmic vesicle
# 581399      57212230              GO:0043226                      organelle
# 581400      57212230              GO:0005768                       endosome
#
# [193928 rows x 6 columns]
#       Gene stable ID Chromosome/scaffold name  Gene start(bp)  Gene end(bp)  \
# 211  ENSG00000173110                        1       161524540     161526894
# 217  ENSG00000173110                        1       161524540     161526894
# 223  ENSG00000173110                        1       161524540     161526894
# 221  ENSG00000173110                        1       161524540     161526894
# 220  ENSG00000173110                        1       161524540     161526894
# ..               ...                      ...             ...           ...
# 907  ENSG00000124575                        6        26234212      26234987
# 906  ENSG00000124575                        6        26234212      26234987
# 905  ENSG00000124575                        6        26234212      26234987
# 904  ENSG00000124575                        6        26234212      26234987
# 903  ENSG00000124575                        6        26234212      26234987
#
#     GOSlim GOA Accession(s)               GOSlim GOA Description  \
# 211              GO:0140657               ATP-dependent activity
# 217              GO:0005634                              nucleus
# 223              GO:0031410                  cytoplasmic vesicle
# 221              GO:0003824                   catalytic activity
# 220              GO:0005615                  extracellular space
# ..                      ...                                  ...
# 907              GO:0065003  protein-containing complex assembly
# 906              GO:0005694                           chromosome
# 905              GO:0043226                            organelle
# 904              GO:0005198         structural molecule activity
# 903              GO:0003677                          DNA binding
#
#      HN-score(HN5)   name
# 211            245  HSPA6
# 217            245  HSPA6
# 223            245  HSPA6
# 221            245  HSPA6
# 220            245  HSPA6
# ..             ...    ...
# 907            -71   H1-3
# 906            -71   H1-3
# 905            -71   H1-3
# 904            -71   H1-3
# 903            -71   H1-3
#
# [3398 rows x 8 columns]
#        Gene stable ID Chromosome/scaffold name  Gene start(bp)  Gene end(bp)  \
# 59    ENSG00000173110                        1       161524540     161526894
# 57    ENSG00000173110                        1       161524540     161526894
# 49    ENSG00000173110                        1       161524540     161526894
# 51    ENSG00000173110                        1       161524540     161526894
# 52    ENSG00000173110                        1       161524540     161526894
# ...               ...                      ...             ...           ...
# 1689  ENSG00000184205                        X        53082367      53088540
# 1690  ENSG00000184205                        X        53082367      53088540
# 1691  ENSG00000184205                        X        53082367      53088540
# 1692  ENSG00000184205                        X        53082367      53088540
# 760   ENSG00000174226                        8       100572889     100663415
#
#      GOSlim GOA Accession(s)  GOSlim GOA Description  HN-score(HN5)    name
# 59                GO:0003824      catalytic activity            245   HSPA6
# 57                GO:0005576    extracellular region            245   HSPA6
# 49                GO:0140657  ATP-dependent activity            245   HSPA6
# 51                GO:0043226               organelle            245   HSPA6
# 52                GO:0005856            cytoskeleton            245   HSPA6
# ...                      ...                     ...            ...     ...
# 1689              GO:0005730               nucleolus             51  TSPYL2
# 1690              GO:0023052               signaling             51  TSPYL2
# 1691              GO:0042393         histone binding             51  TSPYL2
# 1692              GO:0005694              chromosome             51  TSPYL2
# 760               GO:0008289           lipid binding             51   SNX31
#
# [1727 rows x 8 columns]
#       Gene stable ID Chromosome/scaffold name  Gene start(bp)  Gene end(bp)  \
# 0    ENSG00000204479                        1        13389632      13392629
# 476  ENSG00000112984                        5       138178719     138187723
# 474  ENSG00000112984                        5       138178719     138187723
# 473  ENSG00000112984                        5       138178719     138187723
# 472  ENSG00000112984                        5       138178719     138187723
# ..               ...                      ...             ...           ...
# 544  ENSG00000124575                        6        26234212      26234987
# 543  ENSG00000124575                        6        26234212      26234987
# 542  ENSG00000124575                        6        26234212      26234987
# 541  ENSG00000124575                        6        26234212      26234987
# 551  ENSG00000124575                        6        26234212      26234987
#
#     GOSlim GOA Accession(s)                     GOSlim GOA Description  \
# 0                GO:0012501                      programmed cell death
# 476              GO:0043226                                  organelle
# 474              GO:0003774                cytoskeletal motor activity
# 473              GO:0140657                     ATP-dependent activity
# 472              GO:0008092               cytoskeletal protein binding
# ..                      ...                                        ...
# 544              GO:0005694                                 chromosome
# 543              GO:0043226                                  organelle
# 542              GO:0005198               structural molecule activity
# 541              GO:0003677                                DNA binding
# 551              GO:0006355  regulation of DNA-templated transcription
#
#      HN-score(HN5)      name
# 0              -14  PRAMEF17
# 476            -14    KIF20A
# 474            -14    KIF20A
# 473            -14    KIF20A
# 472            -14    KIF20A
# ..             ...       ...
# 544            -71      H1-3
# 543            -71      H1-3
# 542            -71      H1-3
# 541            -71      H1-3
# 551            -71      H1-3
#
# [1671 rows x 8 columns]
